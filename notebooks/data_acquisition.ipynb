# %%
import requests
from bs4 import BeautifulSoup
url = 'https://cwlagos.com/'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
import pickle

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
soup.title.name
# Out:
# 'title'

# %%
soup.findAll('a')
# Out:
# [<a href="https://cwlagos.com/">Cities</a>,
#  <a href="http://cwlagos.com">Lagos</a>,
#  <a href="https://cwlagos.com/cwre-dubai-offer/" target="_blank">Dubai</a>,
#  <a href="http://theresidenceabuja.com/" target="_blank">Abuja</a>,
#  <a href="#">Ghana (Coming Soon)</a>,
#  <a href="https://cwlagos.com/about/">About</a>,
#  <a href="https://cwlagos.com/meet-our-team/">Meet Our Team</a>,
#  <a href="#">Awards</a>,
#  <a href="https://cwlagos.com/listings/">Listings</a>,
#  <a href="https://shortstays.cwlagos.com" target="_blank">Short Stays</a>,
#  <a href="https://cwlagos.com/new-development/">New Developments</a>,
#  <a href="https://cwlagos.com/blog/">Blog</a>,
#  <a href="https://cwlagos.com/contact/">Contact us</a>,
#  <a class="btn btn-theme btn-submit" href="https://cwlagos.com/submission/"><i class="flaticon-plus button-icon"></i>Submit Property</a>,
#  <a class="btn btn-showmenu btn-theme" href="#navbar-offcanvas">
#  <i class="fas fa-bars"></i>
#  </a>,
# ...

# %%
# storing the dataset in a pickle file

with open('soup_object.pkl', 'wb') as file:
    pickle.dump(soup, file)
