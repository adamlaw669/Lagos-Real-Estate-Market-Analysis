# %%
import requests
from bs4 import BeautifulSoup
import pickle
import pandas as pd
import time

# %%
url = 'https://cwlagos.com/'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
soup.title.name
# Out:
# 'title'

# %%
# storing the dataset in a pickle file to preserve the data

with open('soup_object.pkl', 'wb') as file:
    pickle.dump(soup, file)

# %%
with open('/Users/mac/Projects/Data Science projects/Lagos-Real-Estate-Market-Analysis/data/raw/soup_object.pkl', 'rb') as file:
    loaded_soup = pickle.load(file)

# %%
# storing the HTML content in a separate file to preview the content
with open('page_content.html', 'w', encoding='utf-8') as file:
    file.write(loaded_soup.prettify())

# %%
with open('/Users/mac/Projects/Data Science projects/Lagos-Real-Estate-Market-Analysis/data/raw/page_content.html', 'rb') as file:
    loaded_soup = BeautifulSoup(file)

# %%
""" 
After insp[ecting the HTML structure of the cwlagos page, I see that the homepage listings are not structured in a way that allows for easy extraction of property details.
I will focus on scraping the individual location pages instead.
"""

# %% [markdown]
# # Scraping the individual location  pages

# %% [markdown]
# ## Ikoyi

# %% [markdown]
# #### scraping pages

# %%
url = 'https://cwlagos.com/property-location/ikoyi/'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
# storing the soup object in an html file
with open('../data/raw/ikoyi_page_content.html', 'w', encoding='utf-8') as file:
    file.write(soup.prettify())

# %%
# scraping a different page of the Ikoyi location
url = 'https://cwlagos.com/property-location/ikoyi/page/15/'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
with open('../data/raw/ikoyi_page_content_15.html', 'w', encoding='utf-8') as file:
    file.write(soup.prettify())

# %% [markdown]
# #### loading the scraped pages

# %%
with open('/Users/mac/Projects/Data Science projects/Lagos-Real-Estate-Market-Analysis/data/raw/ikoyi_page_content.html', 'rb') as file:
    loaded_soup = BeautifulSoup(file)

# %% [markdown]
# ### understanding how to navigate the soup object

# %%
loaded_soup.contents[0]
# Out:
# 'html'

# %%
len(loaded_soup.contents)
# Out:
# 5

# %%
loaded_soup.contents[0]
# Out:
# 'html'

# %%
loaded_soup.head
# Out:
# <head>
# <script data-no-optimize="1">
#    var litespeed_docref=sessionStorage.getItem("litespeed_docref");litespeed_docref&&(Object.defineProperty(document,"referrer",{get:function(){return litespeed_docref}}),sessionStorage.removeItem("litespeed_docref"));
#   </script>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=0" name="viewport"/>
# <link href="//gmpg.org/xfn/11" rel="profile"/>
# <title>
#     ikoyi - CW Real Estate
#    </title>
# <style>
#     #wpadminbar #wp-admin-bar-wccp_free_top_button .ab-icon:before {
# content: "\f160";
# color: #02CA02;
# top: 3px;
# }
# #wpadminbar #wp-admin-bar-wccp_free_top_button .ab-icon {
# transform: rotate(45deg);
# }
#    </style>
# <style>
#     img:is([sizes="auto" i], [sizes^="auto," i]) { contain-intrinsic-size: 3000px 1500px }
#    </style>
# <meta content="max-image-preview:large" name="robots"/>
# <link href="https://cwlagos.com/property-location/ikoyi/" rel="canonical"/>
# <link href="https://cwlagos.com/property-location/ikoyi/page/2/" rel="next"/>
# <meta content="All in One SEO (AIOSEO) 4.9.0" name="generator"/>
# <script class="aioseo-schema" type="application/ld+json">
#      {"@context":"https:\/\/schema.org","@graph":[{"@type":"BreadcrumbList","@id":"https:\/\/cwlagos.com\/property-location\/ikoyi\/#breadcrumblist","itemListElement":[{"@type":"ListItem","@id":"https:\/\/cwlagos.com#listItem","position":1,"name":"Home","item":"https:\/\/cwlagos.com","nextItem":{"@type":"ListItem","@id":"https:\/\/cwlagos.com\/property-location\/ikoyi\/#listItem","name":"ikoyi"}},{"@type":"ListItem","@id":"https:\/\/cwlagos.com\/property-location\/ikoyi\/#listItem","position":2,"name":"ikoyi","previousItem":{"@type":"ListItem","@id":"https:\/\/cwlagos.com#listItem","name":"Home"}}]},{"@type":"CollectionPage","@id":"https:\/\/cwlagos.com\/property-location\/ikoyi\/#collectionpage","url":"https:\/\/cwlagos.com\/property-location\/ikoyi\/","name":"ikoyi - CW Real Estate","inLanguage":"en-US","isPartOf":{"@id":"https:\/\/cwlagos.com\/#website"},"breadcrumb":{"@id":"https:\/\/cwlagos.com\/property-location\/ikoyi\/#breadcrumblist"}},{"@type":"Organization","@id":"https:\/\/cwlagos.com\/#organization","name":"CW Real Estate","description":"Buy Sell & Lease Luxury Real Estate in Lagos & Abuja","url":"https:\/\/cwlagos.com\/"},{"@type":"WebSite","@id":"https:\/\/cwlagos.com\/#website","url":"https:\/\/cwlagos.com\/","name":"CW Real Estate","description":"Buy Sell & Lease Luxury Real Estate in Lagos & Abuja","inLanguage":"en-US","publisher":{"@id":"https:\/\/cwlagos.com\/#organization"}}]}
#     </script>
# <link href="//www.googletagmanager.com" rel="dns-prefetch"/>
# <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
# <link href="https://cwlagos.com/feed/" rel="alternate" title="CW Real Estate » Feed" type="application/rss+xml"/>
# <link href="https://cwlagos.com/comments/feed/" rel="alternate" title="CW Real Estate » Comments Feed" type="application/rss+xml"/>
# <link href="https://cwlagos.com/property-location/ikoyi/feed/" rel="alternate" title="CW Real Estate » ikoyi Location Feed" type="application/rss+xml"/>
# <script async="" data-cfasync="false" data-wpfc-render="false" src="//www.googletagmanager.com/gtag/js?id=G-GRSLLSSX6D" type="text/javascript">
# </script>
# <script data-cfasync="false" data-wpfc-render="false" type="text/javascript">
#      var mi_version = '9.9.0';
# var mi_track_user = true;
# var mi_no_track_reason = '';
# var MonsterInsightsDefaultLocations = {"page_location":"https:\/\/cwlagos.com\/property-location\/ikoyi\/","page_referrer":"https:\/\/cwlagos.com\/property_location-sitemap.xml"};
# if ( typeof MonsterInsightsPrivacyGuardFilter === 'function' ) {
# var MonsterInsightsLocations = (typeof MonsterInsightsExcludeQuery === 'object') ? MonsterInsightsPrivacyGuardFilter( MonsterInsightsExcludeQuery ) : MonsterInsightsPrivacyGuardFilter( MonsterInsightsDefaultLocations );
# } else {
# var MonsterInsightsLocations = (typeof MonsterInsightsExcludeQuery === 'object') ? MonsterInsightsExcludeQuery : MonsterInsightsDefaultLocations;
# }
# var disableStrs = [
# 'ga-disable-G-GRSLLSSX6D',
# ];
# /* Function to detect opted out users */
# function __gtagTrackerIsOptedOut() {
# for (var index = 0; index < disableStrs.length; index++) {
# if (document.cookie.indexOf(disableStrs[index] + '=true') > -1) {
# return true;
# }
# }
# return false;
# }
# /* Disable tracking if the opt-out cookie exists. */
# if (__gtagTrackerIsOptedOut()) {
# for (var index = 0; index < disableStrs.length; index++) {
# window[disableStrs[index]] = true;
# }
# }
# /* Opt-out function */
# function __gtagTrackerOptout() {
# for (var index = 0; index < disableStrs.length; index++) {
# document.cookie = disableStrs[index] + '=true; expires=Thu, 31 Dec 2099 23:59:59 UTC; path=/';
# window[disableStrs[index]] = true;
# }
# }
# if ('undefined' === typeof gaOptout) {
# function gaOptout() {
# __gtagTrackerOptout();
# }
# }
# window.dataLayer = window.dataLayer || [];
# window.MonsterInsightsDualTracker = {
# helpers: {},
# trackers: {},
# };
# if (mi_track_user) {
# function __gtagDataLayer() {
# dataLayer.push(arguments);
# }
# function __gtagTracker(type, name, parameters) {
# if (!parameters) {
# parameters = {};
# }
# if (parameters.send_to) {
# __gtagDataLayer.apply(null, arguments);
# return;
# }
# if (type === 'event') {
# parameters.send_to = monsterinsights_frontend.v4_id;
# var hookName = name;
# if (typeof parameters['event_category'] !== 'undefined') {
# hookName = parameters['event_category'] + ':' + name;
# }
# if (typeof MonsterInsightsDualTracker.trackers[hookName] !== 'undefined') {
# MonsterInsightsDualTracker.trackers[hookName](parameters);
# } else {
# __gtagDataLayer('event', name, parameters);
# }
# } else {
# __gtagDataLayer.apply(null, arguments);
# }
# }
# __gtagTracker('js', new Date());
# __gtagTracker('set', {
# 'developer_id.dZGIzZG': true,
# });
# if ( MonsterInsightsLocations.page_location ) {
# __gtagTracker('set', MonsterInsightsLocations);
# }
# __gtagTracker('config', 'G-GRSLLSSX6D', {"forceSSL":"true","link_attribution":"true"} );
# window.gtag = __gtagTracker;										(function () {
# /* https://developers.google.com/analytics/devguides/collection/analyticsjs/ */
# /* ga and __gaTracker compatibility shim. */
# var noopfn = function () {
# return null;
# };
# var newtracker = function () {
# return new Tracker();
# };
# var Tracker = function () {
# return null;
# };
# var p = Tracker.prototype;
# p.get = noopfn;
# p.set = noopfn;
# p.send = function () {
# var args = Array.prototype.slice.call(arguments);
# args.unshift('send');
# __gaTracker.apply(null, args);
# };
# var __gaTracker = function () {
# var len = arguments.length;
# if (len === 0) {
# return;
# }
# var f = arguments[len - 1];
# if (typeof f !== 'object' || f === null || typeof f.hitCallback !== 'function') {
# if ('send' === arguments[0]) {
# var hitConverted, hitObject = false, action;
# if ('event' === arguments[1]) {
# if ('undefined' !== typeof arguments[3]) {
# hitObject = {
# 'eventAction': arguments[3],
# 'eventCategory': arguments[2],
# 'eventLabel': arguments[4],
# 'value': arguments[5] ? arguments[5] : 1,
# }
# }
# }
# if ('pageview' === arguments[1]) {
# if ('undefined' !== typeof arguments[2]) {
# hitObject = {
# 'eventAction': 'page_view',
# 'page_path': arguments[2],
# }
# }
# }
# if (typeof arguments[2] === 'object') {
# hitObject = arguments[2];
# }
# if (typeof arguments[5] === 'object') {
# Object.assign(hitObject, arguments[5]);
# }
# if ('undefined' !== typeof arguments[1].hitType) {
# hitObject = arguments[1];
# if ('pageview' === hitObject.hitType) {
# hitObject.eventAction = 'page_view';
# }
# }
# if (hitObject) {
# action = 'timing' === arguments[1].hitType ? 'timing_complete' : hitObject.eventAction;
# hitConverted = mapArgs(hitObject);
# __gtagTracker('event', action, hitConverted);
# }
# }
# return;
# }
# function mapArgs(args) {
# var arg, hit = {};
# var gaMap = {
# 'eventCategory': 'event_category',
# 'eventAction': 'event_action',
# 'eventLabel': 'event_label',
# 'eventValue': 'event_value',
# 'nonInteraction': 'non_interaction',
# 'timingCategory': 'event_category',
# 'timingVar': 'name',
# 'timingValue': 'value',
# 'timingLabel': 'event_label',
# 'page': 'page_path',
# 'location': 'page_location',
# 'title': 'page_title',
# 'referrer' : 'page_referrer',
# };
# for (arg in args) {
# if (!(!args.hasOwnProperty(arg) || !gaMap.hasOwnProperty(arg))) {
# hit[gaMap[arg]] = args[arg];
# } else {
# hit[arg] = args[arg];
# }
# }
# return hit;
# }
# try {
# f.hitCallback();
# } catch (ex) {
# }
# };
# __gaTracker.create = newtracker;
# __gaTracker.getByName = newtracker;
# __gaTracker.getAll = function () {
# return [];
# };
# __gaTracker.remove = noopfn;
# __gaTracker.loaded = true;
# window['__gaTracker'] = __gaTracker;
# })();
# } else {
# console.log("");
# (function () {
# function __gtagTracker() {
# return null;
# }
# window['__gtagTracker'] = __gtagTracker;
# window['gtag'] = __gtagTracker;
# })();
# }
#     </script>
# <!-- <link data-optimized="1" rel='stylesheet' id='wp-block-library-css' href='https://cwlagos.com/wp-content/litespeed/css/99f435bbd50e48b11eec4159c718451c.css?ver=8451c' type='text/css' media='all' /> -->
# <link href="//cwlagos.com/wp-content/cache/wpfc-minified/112uxjgb/e86xb.css" media="all" rel="stylesheet" type="text/css"/>
# <style id="wp-block-library-theme-inline-css" type="text/css">
#      .wp-block-audio :where(figcaption){color:#555;font-size:13px;text-align:center}.is-dark-theme .wp-block-audio :where(figcaption){color:#ffffffa6}.wp-block-audio{margin:0 0 1em}.wp-block-code{border:1px solid #ccc;border-radius:4px;font-family:Menlo,Consolas,monaco,monospace;padding:.8em 1em}.wp-block-embed :where(figcaption){color:#555;font-size:13px;text-align:center}.is-dark-theme .wp-block-embed :where(figcaption){color:#ffffffa6}.wp-block-embed{margin:0 0 1em}.blocks-gallery-caption{color:#555;font-size:13px;text-align:center}.is-dark-theme .blocks-gallery-caption{color:#ffffffa6}:root :where(.wp-block-image figcaption){color:#555;font-size:13px;text-align:center}.is-dark-theme :root :where(.wp-block-image figcaption){color:#ffffffa6}.wp-block-image{margin:0 0 1em}.wp-block-pullquote{border-bottom:4px solid;border-top:4px solid;color:currentColor;margin-bottom:1.75em}.wp-block-pullquote cite,.wp-block-pullquote footer,.wp-block-pullquote__citation{color:currentColor;font-size:.8125em;font-style:normal;text-transform:uppercase}.wp-block-quote{border-left:.25em solid;margin:0 0 1.75em;padding-left:1em}.wp-block-quote cite,.wp-block-quote footer{color:currentColor;font-size:.8125em;font-style:normal;position:relative}.wp-block-quote:where(.has-text-align-right){border-left:none;border-right:.25em solid;padding-left:0;padding-right:1em}.wp-block-quote:where(.has-text-align-center){border:none;padding-left:0}.wp-block-quote.is-large,.wp-block-quote.is-style-large,.wp-block-quote:where(.is-style-plain){border:none}.wp-block-search .wp-block-search__label{font-weight:700}.wp-block-search__button{border:1px solid #ccc;padding:.375em .625em}:where(.wp-block-group.has-background){padding:1.25em 2.375em}.wp-block-separator.has-css-opacity{opacity:.4}.wp-block-separator{border:none;border-bottom:2px solid;margin-left:auto;margin-right:auto}.wp-block-separator.has-alpha-channel-opacity{opacity:1}.wp-block-separator:not(.is-style-wide):not(.is-style-dots){width:100px}.wp-block-separator.has-background:not(.is-style-dots){border-bottom:none;height:1px}.wp-block-separator.has-background:not(.is-style-wide):not(.is-style-dots){height:2px}.wp-block-table{margin:0 0 1em}.wp-block-table td,.wp-block-table th{word-break:normal}.wp-block-table :where(figcaption){color:#555;font-size:13px;text-align:center}.is-dark-theme .wp-block-table :where(figcaption){color:#ffffffa6}.wp-block-video :where(figcaption){color:#555;font-size:13px;text-align:center}.is-dark-theme .wp-block-video :where(figcaption){color:#ffffffa6}.wp-block-video{margin:0 0 1em}:root :where(.wp-block-template-part.has-background){margin-bottom:0;margin-top:0;padding:1.25em 2.375em}
#     </style>
# <style id="classic-theme-styles-inline-css" type="text/css">
#      /*! This file is auto-generated */
# .wp-block-button__link{color:#fff;background-color:#32373c;border-radius:9999px;box-shadow:none;text-decoration:none;padding:calc(.667em + 2px) calc(1.333em + 2px);font-size:1.125em}.wp-block-file__button{background:#32373c;color:#fff;text-decoration:none}
#     </style>
# <!-- <link data-optimized="1" rel='stylesheet' id='aioseo/css/src/vue/standalone/blocks/table-of-contents/global.scss-css' href='https://cwlagos.com/wp-content/litespeed/css/45d39c502628d320858cde908343dca2.css?ver=3dca2' type='text/css' media='all' /> -->
# <!-- <link data-optimized="1" rel='stylesheet' id='wp-call-btn-guten-blocks-style-css' href='https://cwlagos.com/wp-content/litespeed/css/f2ddc865dc89c205366e3f7d9b086e54.css?ver=86e54' type='text/css' media='all' /> -->
# <link href="//cwlagos.com/wp-content/cache/wpfc-minified/eiyomqfy/g0tvv.css" media="all" rel="stylesheet" type="text/css"/>
# <style id="filebird-block-filebird-gallery-style-inline-css" type="text/css">
#      ul.filebird-block-filebird-gallery{margin:auto!important;padding:0!important;width:100%}ul.filebird-block-filebird-gallery.layout-grid{display:grid;grid-gap:20px;align-items:stretch;grid-template-columns:repeat(var(--columns),1fr);justify-items:stretch}ul.filebird-block-filebird-gallery.layout-grid li img{border:1px solid #ccc;box-shadow:2px 2px 6px 0 rgba(0,0,0,.3);height:100%;max-width:100%;-o-object-fit:cover;object-fit:cover;width:100%}ul.filebird-block-filebird-gallery.layout-masonry{-moz-column-count:var(--columns);-moz-column-gap:var(--space);column-gap:var(--space);-moz-column-width:var(--min-width);columns:var(--min-width) var(--columns);display:block;overflow:auto}ul.filebird-block-filebird-gallery.layout-masonry li{margin-bottom:var(--space)}ul.filebird-block-filebird-gallery li{list-style:none}ul.filebird-block-filebird-gallery li figure{height:100%;margin:0;padding:0;position:relative;width:100%}ul.filebird-block-filebird-gallery li figure figcaption{background:linear-gradient(0deg,rgba(0,0,0,.7),rgba(0,0,0,.3) 70%,transparent);bottom:0;box-sizing:border-box;color:#fff;font-size:.8em;margin:0;max-height:100%;overflow:auto;padding:3em .77em .7em;position:absolute;text-align:center;width:100%;z-index:2}ul.filebird-block-filebird-gallery li figure figcaption a{color:inherit}
#     </style>
# <!-- <link data-optimized="1" rel='stylesheet' id='nta-css-popup-css' href='https://cwlagos.com/wp-content/litespeed/css/40948b74b69cb811c340eacf51d65834.css?ver=65834' type='text/css' media='all' /> -->
# <link href="//cwlagos.com/wp-content/cache/wpfc-minified/m1gp28wr/e86es.css" media="all" rel="stylesheet" type="text/css"/>
# <style id="global-styles-inline-css" type="text/css">
#      :root{--wp--preset--aspect-ratio--square: 1;--wp--preset--aspect-ratio--4-3: 4/3;--wp--preset--aspect-ratio--3-4: 3/4;--wp--preset--aspect-ratio--3-2: 3/2;--wp--preset--aspect-ratio--2-3: 2/3;--wp--preset--aspect-ratio--16-9: 16/9;--wp--preset--aspect-ratio--9-16: 9/16;--wp--preset--color--black: #000000;--wp--preset--color--cyan-bluish-gray: #abb8c3;--wp--preset--color--white: #ffffff;--wp--preset--color--pale-pink: #f78da7;--wp--preset--color--vivid-red: #cf2e2e;--wp--preset--color--luminous-vivid-orange: #ff6900;--wp--preset--color--luminous-vivid-amber: #fcb900;--wp--preset--color--light-green-cyan: #7bdcb5;--wp--preset--color--vivid-green-cyan: #00d084;--wp--preset--color--pale-cyan-blue: #8ed1fc;--wp--preset--color--vivid-cyan-blue: #0693e3;--wp--preset--color--vivid-purple: #9b51e0;--wp--preset--gradient--vivid-cyan-blue-to-vivid-purple: linear-gradient(135deg,rgba(6,147,227,1) 0%,rgb(155,81,224) 100%);--wp--preset--gradient--light-green-cyan-to-vivid-green-cyan: linear-gradient(135deg,rgb(122,220,180) 0%,rgb(0,208,130) 100%);--wp--preset--gradient--luminous-vivid-amber-to-luminous-vivid-orange: linear-gradient(135deg,rgba(252,185,0,1) 0%,rgba(255,105,0,1) 100%);--wp--preset--gradient--luminous-vivid-orange-to-vivid-red: linear-gradient(135deg,rgba(255,105,0,1) 0%,rgb(207,46,46) 100%);--wp--preset--gradient--very-light-gray-to-cyan-bluish-gray: linear-gradient(135deg,rgb(238,238,238) 0%,rgb(169,184,195) 100%);--wp--preset--gradient--cool-to-warm-spectrum: linear-gradient(135deg,rgb(74,234,220) 0%,rgb(151,120,209) 20%,rgb(207,42,186) 40%,rgb(238,44,130) 60%,rgb(251,105,98) 80%,rgb(254,248,76) 100%);--wp--preset--gradient--blush-light-purple: linear-gradient(135deg,rgb(255,206,236) 0%,rgb(152,150,240) 100%);--wp--preset--gradient--blush-bordeaux: linear-gradient(135deg,rgb(254,205,165) 0%,rgb(254,45,45) 50%,rgb(107,0,62) 100%);--wp--preset--gradient--luminous-dusk: linear-gradient(135deg,rgb(255,203,112) 0%,rgb(199,81,192) 50%,rgb(65,88,208) 100%);--wp--preset--gradient--pale-ocean: linear-gradient(135deg,rgb(255,245,203) 0%,rgb(182,227,212) 50%,rgb(51,167,181) 100%);--wp--preset--gradient--electric-grass: linear-gradient(135deg,rgb(202,248,128) 0%,rgb(113,206,126) 100%);--wp--preset--gradient--midnight: linear-gradient(135deg,rgb(2,3,129) 0%,rgb(40,116,252) 100%);--wp--preset--font-size--small: 13px;--wp--preset--font-size--medium: 20px;--wp--preset--font-size--large: 36px;--wp--preset--font-size--x-large: 42px;--wp--preset--spacing--20: 0.44rem;--wp--preset--spacing--30: 0.67rem;--wp--preset--spacing--40: 1rem;--wp--preset--spacing--50: 1.5rem;--wp--preset--spacing--60: 2.25rem;--wp--preset--spacing--70: 3.38rem;--wp--preset--spacing--80: 5.06rem;--wp--preset--shadow--natural: 6px 6px 9px rgba(0, 0, 0, 0.2);--wp--preset--shadow--deep: 12px 12px 50px rgba(0, 0, 0, 0.4);--wp--preset--shadow--sharp: 6px 6px 0px rgba(0, 0, 0, 0.2);--wp--preset--shadow--outlined: 6px 6px 0px -3px rgba(255, 255, 255, 1), 6px 6px rgba(0, 0, 0, 1);--wp--preset--shadow--crisp: 6px 6px 0px rgba(0, 0, 0, 1);}:where(.is-layout-flex){gap: 0.5em;}:where(.is-layout-grid){gap: 0.5em;}body .is-layout-flex{display: flex;}.is-layout-flex{flex-wrap: wrap;align-items: center;}.is-layout-flex > :is(*, div){margin: 0;}body .is-layout-grid{display: grid;}.is-layout-grid > :is(*, div){margin: 0;}:where(.wp-block-columns.is-layout-flex){gap: 2em;}:where(.wp-block-columns.is-layout-grid){gap: 2em;}:where(.wp-block-post-template.is-layout-flex){gap: 1.25em;}:where(.wp-block-post-template.is-layout-grid){gap: 1.25em;}.has-black-color{color: var(--wp--preset--color--black) !important;}.has-cyan-bluish-gray-color{color: var(--wp--preset--color--cyan-bluish-gray) !important;}.has-white-color{color: var(--wp--preset--color--white) !important;}.has-pale-pink-color{color: var(--wp--preset--color--pale-pink) !important;}.has-vivid-red-color{color: var(--wp--preset--color--vivid-red) !important;}.has-luminous-vivid-orange-color{color: var(--wp--preset--color--luminous ...
# :where(.wp-block-post-template.is-layout-flex){gap: 1.25em;}:where(.wp-block-post-template.is-layout-grid){gap: 1.25em;}
# :where(.wp-block-columns.is-layout-flex){gap: 2em;}:where(.wp-block-columns.is-layout-grid){gap: 2em;}
# :root :where(.wp-block-pullquote){font-size: 1.5em;line-height: 1.6;}
#     </style>
# <!-- <link data-optimized="1" rel='stylesheet' id='pb_animate-css' href='https://cwlagos.com/wp-content/litespeed/css/7b071bf6745ffed1302524e8af995bf7.css?ver=95bf7' type='text/css' media='all' /> -->
# <!-- <link data-optimized="1" rel='stylesheet' id='tooltipy-default-style-css' href='https://cwlagos.com/wp-content/litespeed/css/6c117f7fb28596cac6557d29f24e298d.css?ver=e298d' type='text/css' media='all' /> -->
# <!-- <link data-optimized="1" rel='stylesheet' id='mediaelement-css' href='https://cwlagos.com/wp-content/litespeed/css/5ae6bb0ea2f12169c87b1bca23ebde01.css?ver=bde01' type='text/css' media='all' /> -->
# <!-- <link data-optimized="1" rel='stylesheet' id='wp-mediaelement-css' href='https://cwlagos.com/wp-content/litespeed/css/52924b4509898659b546aee6665cec2f.css?ver=cec2f' type='text/css' media='all' /> -->
# <!-- <link data-optimized="1" rel='stylesheet' id='contact-form-7-css' href='https://cwlagos.com/wp-content/litespeed/css/e9c6264e515acafdeb6b5db01fcfbe2d.css?ver=fbe2d' type='text/css' media='all' /> -->
# <!-- <link data-optimized="1" rel='stylesheet' id='popb_admin_top_menu_styles_csm-css' href='https://cwlagos.com/wp-content/litespeed/css/4576cbd82ce8ffff420d7b19e975cdc2.css?ver=5cdc2' type='text/css' media='all' /> -->
# <!-- <link data-optimized="1" rel='stylesheet' id='bodhi-svgs-attachment-css' href='https://cwlagos.com/wp-content/litespeed/css/d46cc545ec7e161f02ba220c25a4ef93.css?ver=4ef93' type='text/css' media='all' /> -->
# <!-- <link data-optimized="1" rel='stylesheet' id='magnific-css' href='https://cwlagos.com/wp-content/litespeed/css/a96d1a879fbb529b4ca14b8c27f3a1e2.css?ver=3a1e2' type='text/css' media='all' /> -->
# <!-- <link data-optimized="1" rel='stylesheet' id='wpb-ea-bootstrap-grid-css' href='https://cwlagos.com/wp-content/litespeed/css/415a2868f31f83f5f95120e78290ec69.css?ver=0ec69' type='text/css' media='' /> -->
# <!-- <link data-optimized="1" rel='stylesheet' id='wpb-ea-owl-carousel-css' href='https://cwlagos.com/wp-content/litespeed/css/88d0a88b6c6a100bf02959f1458cd821.css?ver=cd821' type='text/css' media='' /> -->
# <!-- <link data-optimized="1" rel='stylesheet' id='fancybox-css' href='https://cwlagos.com/wp-content/litespeed/css/dcb7a0252b1d31d0ab75504c63052f52.css?ver=52f52' type='text/css' media='' /> -->
# <!-- <link data-optimized="1" rel='stylesheet' id='wpb-lineicons-css-css' href='https://cwlagos.com/wp-content/litespeed/css/60466fb7ba65dd85b3c523e397a907cd.css?ver=907cd' type='text/css' media='' /> -->
# <!-- <link data-optimized="1" rel='stylesheet' id='wpb_ea_main_css-css' href='https://cwlagos.com/wp-content/litespeed/css/2480029976d60405bbb5033f4357de4c.css?ver=7de4c' type='text/css' media='' /> -->
# <link href="//cwlagos.com/wp-content/cache/wpfc-minified/l1n6uarg/e86es.css" media="all" rel="stylesheet" type="text/css"/>
# <style id="wpb_ea_main_css-inline-css" type="text/css">
#      .wpb-ea-team-member .social-buttons,
# .wpb-ea-service-box-image .wpb-ea-service-box-btn:hover {
# background: #3878ff;
# }
# .wpb-ea-service-box-icon .wpb-ea-service-box-btn:hover {
# color: #3878ff;
# }
# .wpb-ea-service-box-image .wpb-ea-service-box-btn:hover {
# border-color: #3878ff;
# }
#     </style>
# <!-- <link data-optimized="1" rel='stylesheet' id='academy-child-main-css-main.CpzgpkPv-css' href='https://cwlagos.com/wp-content/litespeed/css/8ea4daca623fd88ce3b9d5b2408e22e5.css?ver=e22e5' type='text/css' media='all' /> -->
# <!-- <link data-optimized="1" rel='stylesheet' id='leaflet-css' href='https://cwlagos.com/wp-content/litespeed/css/0bbcdc12692f347cf1f4f9e46aef6547.css?ver=f6547' type='text/css' media='all' /> -->
# <!-- <link data-optimized="1" rel='stylesheet' id='dashicons-css' href='https://cwlagos.com/wp-content/litespeed/css/742132cab0cfb67b18794b8ac79c9853.css?ver=c9853' type='text/css' media='all' /> -->
# <!-- <link data-optimized="1" rel='stylesheet' id='ekit-widget-styles-css' href='https://cwlagos.com/wp-content/litespeed/css/ea26b9f07105373ac1143a51bed69125.css?ver=69125' type='text/css' media='all' /> -->
# <!-- <link data-optimized="1" rel='stylesheet' id='ekit-responsive-css' href='https://cwlagos.com/wp-content/litespeed/css/72c5101afed760bc38446515c511bca6.css?ver=1bca6' type='text/css' media='all' /> -->
# <!-- <link data-optimized="1" rel='stylesheet' id='elementor-frontend-css' href='https://cwlagos.com/wp-content/litespeed/css/b2860eb128b2b87f81bfc153aef4308d.css?ver=4308d' type='text/css' media='all' /> -->
# <!-- <link data-optimized="1" rel='stylesheet' id='eael-general-css' href='https://cwlagos.com/wp-content/litespeed/css/aa228e9719416259802f163589f2a599.css?ver=2a599' type='text/css' media='all' /> -->
# <link href="//cwlagos.com/wp-content/cache/wpfc-minified/14q7sy8y/e86xb.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/css?family=Nunito:300,400,600,700,800,900&amp;subset=latin%2Clatin-ext&amp;display=swap" id="homeo-theme-fonts-css" media="all" rel="stylesheet" type="text/css"/>
# <!-- <link data-optimized="1" rel='stylesheet' id='all-awesome-css' href='https://cwlagos.com/wp-content/litespeed/css/07c7f0925a1d5d2f44f339a954120415.css?ver=20415' type='text/css' media='all' /> -->
# <!-- <link data-optimized="1" rel='stylesheet' id='flaticon-css' href='https://cwlagos.com/wp-content/litespeed/css/fd2dd2f1eddf2e95fa69d79576a8f406.css?ver=8f406' type='text/css' media='all' /> -->
# <!-- <link data-optimized="1" rel='stylesheet' id='themify-icons-css' href='https://cwlagos.com/wp-content/litespeed/css/defbc5f6c4a3b681159b2428523f912b.css?ver=f912b' type='text/css' media='all' /> -->
# <!-- <link data-optimized="1" rel='stylesheet' id='animate-css' href='https://cwlagos.com/wp-content/litespeed/css/09148e76587443aaf36638ab7cc2fe10.css?ver=2fe10' type='text/css' media='all' /> -->
# <!-- <link data-optimized="1" rel='stylesheet' id='bootstrap-css' href='https://cwlagos.com/wp-content/litespeed/css/e5005387d8aa24ab91dc9b7160b57cea.css?ver=57cea' type='text/css' media='all' /> -->
# <!-- <link data-optimized="1" rel='stylesheet' id='slick-css' href='https://cwlagos.com/wp-content/litespeed/css/bc8154bd5d940a03ac3423a308a5a5e8.css?ver=5a5e8' type='text/css' media='all' /> -->
# <!-- <link data-optimized="1" rel='stylesheet' id='magnific-popup-css' href='https://cwlagos.com/wp-content/litespeed/css/dd9652b64d97ff6fe8a0cb99523fb157.css?ver=fb157' type='text/css' media='all' /> -->
# <!-- <link data-optimized="1" rel='stylesheet' id='perfect-scrollbar-css' href='https://cwlagos.com/wp-content/litespeed/css/d7cdaa4fe3d7ca0d81ebd9adb5867251.css?ver=67251' type='text/css' media='all' /> -->
# <!-- <link data-optimized="1" rel='stylesheet' id='jquery-mmenu-css' href='https://cwlagos.com/wp-content/litespeed/css/c7fd263e562d16e0b68060104ea63b6a.css?ver=63b6a' type='text/css' media='all' /> -->
# <!-- <link data-optimized="1" rel='stylesheet' id='homeo-template-css' href='https://cwlagos.com/wp-content/litespeed/css/434d220bf3abcf74746329a075d807b9.css?ver=807b9' type='text/css' media='all' /> -->
# <!-- <link data-optimized="1" rel='stylesheet' id='homeo-style-css' href='https://cwlagos.com/wp-content/litespeed/css/5523c922f039c3ae2c44f1e9aff54c86.css?ver=54c86' type='text/css' media='all' /> -->
# <!-- <link data-optimized="1" rel='stylesheet' id='ecs-styles-css' href='https://cwlagos.com/wp-content/litespeed/css/e6b38f5d6f9124c3760dd187dee700d1.css?ver=700d1' type='text/css' media='all' /> -->
# <link href="//cwlagos.com/wp-content/cache/wpfc-minified/jzs0rlih/e86xb.css" media="all" rel="stylesheet" type="text/css"/>
# <script src="//cwlagos.com/wp-content/cache/wpfc-minified/lxu66r7m/e86es.js" type="text/javascript">
# </script>
# <!-- <script type="text/javascript" src="https://cwlagos.com/wp-includes/js/jquery/jquery.min.js" id="jquery-core-js"></script> -->
# <!-- <script data-optimized="1" type="text/javascript" src="https://cwlagos.com/wp-content/litespeed/js/634223ccf288ff2305fb2fb08880f5a5.js?ver=0f5a5" id="jquery-migrate-js" defer data-deferred="1"></script> -->
# <!-- <script data-optimized="1" type="text/javascript" src="https://cwlagos.com/wp-content/litespeed/js/b4ff083dba99d6b5ad0084f2c1f9b8ae.js?ver=9b8ae" id="bodhi-dompurify-library-js" defer data-deferred="1"></script> -->
# <!-- <script type="text/javascript" src="https://cwlagos.com/wp-content/plugins/google-analytics-for-wordpress/assets/js/frontend-gtag.min.js" id="monsterinsights-frontend-script-js" data-wp-strategy="async" defer data-deferred="1"></script> -->
# <script data-cfasync="false" data-wpfc-render="false" id="monsterinsights-frontend-script-js-extra" type="text/javascript">
#      /*  */
# var monsterinsights_frontend = {"js_events_tracking":"true","download_extensions":"doc,pdf,ppt,zip,xls,docx,pptx,xlsx","inbound_paths":"[{\"path\":\"\\\/go\\\/\",\"label\":\"affiliate\"},{\"path\":\"\\\/recommend\\\/\",\"label\":\"affiliate\"}]","home_url":"https:\/\/cwlagos.com","hash_tracking":"false","v4_id":"G-GRSLLSSX6D"};/*  */
#     </script>
# <script defer="" id="ays-pb-js-extra" src="data:text/javascript;base64,..." type="text/javascript">
# </script>
# <script src="//cwlagos.com/wp-content/cache/wpfc-minified/2yfzregh/e86es.js" type="text/javascript">
# </script>
# <!-- <script data-optimized="1" type="text/javascript" src="https://cwlagos.com/wp-content/litespeed/js/d4005717f10b0dd531a7662b8b3c51f6.js?ver=c51f6" id="ays-pb-js" defer data-deferred="1"></script> -->
# <script defer="" id="bodhi_svg_inline-js-extra" src="..." type="text/javascript">
# </script>
# <script src="//cwlagos.com/wp-content/cache/wpfc-minified/243q6e6w/e86es.js" type="text/javascript">
# </script>
# <!-- <script data-optimized="1" type="text/javascript" src="https://cwlagos.com/wp-content/litespeed/js/8e5497961a918e48f93dfdc9e9c59a16.js?ver=59a16" id="bodhi_svg_inline-js" defer data-deferred="1"></script> -->
# <script defer="" id="bodhi_svg_inline-js-after" src="..." type="text/javascript">
# </script>
# <script src="//cwlagos.com/wp-content/cache/wpfc-minified/kyl1mvbp/e86es.js" type="text/javascript">
# </script>
# <!-- <script data-optimized="1" type="text/javascript" src="https://cwlagos.com/wp-content/litespeed/js/2957943a6f188dd46e082fdfa24bf265.js?ver=bf265" id="chart-js" defer data-deferred="1"></script> -->
# <script data-deferred="1" defer="" id="google_gtagjs-js" src="https://www.googletagmanager.com/gtag/js?id=G-9KS0FF94M2" type="text/javascript">
# </script>
# <script defer="" id="google_gtagjs-js-after" src="..." type="text/javascript">
# </script>
# <script defer="" id="ecs_ajax_load-js-extra" src="data:text/javascript;base64,..." type="text/javascript">
# </script>
# <script src="//cwlagos.com/wp-content/cache/wpfc-minified/qx2nuejz/e86es.js" type="text/javascript">
# </script>
# <!-- <script data-optimized="1" type="text/javascript" src="https://cwlagos.com/wp-content/litespeed/js/418dfaefe5250c0cbe6bae0113206c7b.js?ver=06c7b" id="ecs_ajax_load-js" defer data-deferred="1"></script> -->
# <!-- <script data-optimized="1" type="text/javascript" src="https://cwlagos.com/wp-content/litespeed/js/b02b2e59285f7b5f011eee3c1ec644fa.js?ver=644fa" id="ecs-script-js" defer data-deferred="1"></script> -->
# <link href="https://cwlagos.com/wp-json/" rel="https://api.w.org/"/>
# <link href="https://cwlagos.com/wp-json/wp/v2/property_location/133" rel="alternate" title="JSON" type="application/json"/>
# <link href="https://cwlagos.com/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
# <meta content="WordPress 6.8.3" name="generator"/>
# <meta content="Redux 4.1.24" name="framework"/>
# <script defer="" src="...">
# </script>
# <style>
#      /*for alt images tooltips*/
# .bluet_tooltip_alt{
# color: #ffffff  !important;
# background-color: #5eaa0d  !important;
# }
# .bluet_block_to_show{
# max-width: 400px;
# }
# .bluet_block_container{
# color: #ffffff  !important;
# background: #5eaa0d  !important;
# box-shadow: 0px 0px 10px #717171  !important;
# font-size:14px  !important;
# }
# img.bluet_tooltip {
# /*border: none;
# width:14px;*/
# }
# .kttg_arrow_show_bottom:after{
# border-bottom-color: #5eaa0d;
# }
# .kttg_arrow_show_top:after{
# border-top-color: #5eaa0d;
# }
# .kttg_arrow_show_right:after{
# border-top-color: #5eaa0d;
# }
# .kttg_arrow_show_left:after{
# border-top-color: #5eaa0d;
# }
# @media screen and (max-width:400px){
# .bluet_hide_tooltip_button{
# color: #ffffff  !important;
# /*background-color: #5eaa0d  !important;*/
# }
# }
#     </style>
# <script src="//cwlagos.com/wp-content/cache/wpfc-minified/e2zyf170/e86es.js" type="text/javascript">
# </script>
# <!-- <script data-optimized="1" type="text/javascript" src="https://cwlagos.com/wp-content/litespeed/js/b07ae455080977fa550c81455af00d15.js?ver=00d15" defer data-deferred="1"></script> -->
# <style id="essential-blocks-global-styles">
#      :root {
# --eb-global-primary-color: #101828;
# --eb-global-secondary-color: #475467;
# --eb-global-tertiary-color: #98A2B3;
# --eb-global-text-color: #475467;
# --eb-global-heading-color: #1D2939;
# --eb-global-link-color: #444CE7;
# --eb-global-background-color: #F9FAFB;
# --eb-global-button-text-color: #FFFFFF;
# --eb-global-button-background-color: #101828;
# --eb-gradient-primary-color: linear-gradient(90deg, hsla(259, 84%, 78%, 1) 0%, hsla(206, 67%, 75%, 1) 100%);
# --eb-gradient-secondary-color: linear-gradient(90deg, hsla(18, 76%, 85%, 1) 0%, hsla(203, 69%, 84%, 1) 100%);
# --eb-gradient-tertiary-color: linear-gradient(90deg, hsla(248, 21%, 15%, 1) 0%, hsla(250, 14%, 61%, 1) 100%);
# --eb-gradient-background-color: linear-gradient(90deg, rgb(250, 250, 250) 0%, rgb(233, 233, 233) 49%, rgb(244, 243, 243) 100%);
# --eb-tablet-breakpoint: 1024px;
# --eb-mobile-breakpoint: 767px;
# }
#     </style>
# <meta content="Site Kit by Google 1.165.0" name="generator"/>
# <meta content="jf7nvg7845x02t4teljjl60wq7npob" name="facebook-domain-verification"/>
# <script defer="" id="mcjs" src="...">
# </script>
# <meta content="e3mI9fVkoDx42AzaP5aRMar_PCNpT0fQuLJQ52bGumk" name="google-site-verification"/>
# <script defer="" src="data:text/javascript;base64,...">
# </script>
# <noscript>
# <img alt="Facebook Pixel" height="1" src="https://www.facebook.com/tr?id=256980996786739&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
# </noscript>
# <script defer="" id="wpcp_disable_selection" src="data:text/javascript;base64,..." type="text/javascript">
# </script>
# <script defer="" id="wpcp_disable_Right_Click" src="..." type="text/javascript">
# </script>
# <style>
#      .unselectable
# {
# -moz-user-select:none;
# -webkit-user-select:none;
# cursor: default;
# }
# html
# {
# -webkit-touch-callout: none;
# -webkit-user-select: none;
# -khtml-user-select: none;
# -moz-user-select: none;
# -ms-user-select: none;
# user-select: none;
# -webkit-tap-highlight-color: rgba(0,0,0,0);
# }
#     </style>
# <script defer="" id="wpcp_css_disable_selection" src="..." type="text/javascript">
# </script>
# <meta content="Elementor 3.33.0; features: additional_custom_breakpoints; settings: css_print_method-internal, google_font-enabled, font_display-auto" name="generator"/>
# <style type="text/css">
#      .recentcomments a{display:inline !important;padding:0 !important;margin:0 !important;}
#     </style>
# <style>
#      .e-con.e-parent:nth-of-type(n+4):not(.e-lazyloaded):not(.e-no-lazyload),
# .e-con.e-parent:nth-of-type(n+4):not(.e-lazyloaded):not(.e-no-lazyload) * {
# background-image: none !important;
# }
# @media screen and (max-height: 1024px) {
# .e-con.e-parent:nth-of-type(n+3):not(.e-lazyloaded):not(.e-no-lazyload),
# .e-con.e-parent:nth-of-type(n+3):not(.e-lazyloaded):not(.e-no-lazyload) * {
# background-image: none !important;
# }
# }
# @media screen and (max-height: 640px) {
# .e-con.e-parent:nth-of-type(n+2):not(.e-lazyloaded):not(.e-no-lazyload),
# .e-con.e-parent:nth-of-type(n+2):not(.e-lazyloaded):not(.e-no-lazyload) * {
# background-image: none !important;
# }
# }
#     </style>
# <link href="https://cwlagos.com/wp-content/uploads/2021/09/cropped-favicon-cw-2-32x32.png" rel="icon" sizes="32x32"/>
# <link href="https://cwlagos.com/wp-content/uploads/2021/09/cropped-favicon-cw-2-192x192.png" rel="icon" sizes="192x192"/>
# <link href="https://cwlagos.com/wp-content/uploads/2021/09/cropped-favicon-cw-2-180x180.png" rel="apple-touch-icon"/>
# <meta content="https://cwlagos.com/wp-content/uploads/2021/09/cropped-favicon-cw-2-270x270.png" name="msapplication-TileImage"/>
# <script data-deferred="1" defer="" src="https://www.googletagmanager.com/gtag/js?id=G-9KS0FF94M2">
# </script>
# <script defer="" src="...">
# </script>
# </head>

# %%
loaded_soup.findAll('section')
# Out:
# [<section class="elementor-section elementor-top-section elementor-element elementor-element-b0d1715 elementor-section-content-middle elementor-section-boxed elementor-section-height-default elementor-section-height-default" data-element_type="section" data-id="b0d1715" data-settings='{"background_background":"classic"}'>
#  <div class="elementor-container elementor-column-gap-default">
#  <div class="elementor-column elementor-col-50 elementor-top-column elementor-element elementor-element-c0ddf24" data-element_type="column" data-id="c0ddf24">
#  <div class="elementor-widget-wrap elementor-element-populated">
#  <div class="elementor-element elementor-element-42f998e elementor-widget elementor-widget-apus_element_logo" data-element_type="widget" data-id="42f998e" data-widget_type="apus_element_logo.default">
#  <div class="elementor-widget-container">
#  <div class="logo">
#  <a href="https://cwlagos.com/">
#  <span class="logo-main">
#  <img alt="" class="attachment-full size-full wp-image-14442" decoding="async" fetchpriority="high" height="348" src="https://cwlagos.com/wp-content/uploads/2022/01/Website-Logo.svg" width="1293"/>
#  </span>
#  </a>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="elementor-column elementor-col-50 elementor-top-column elementor-element elementor-element-bafb47f" data-element_type="column" data-id="bafb47f">
#  <div class="elementor-widget-wrap elementor-element-populated">
#  <div class="elementor-element elementor-element-df9c6b1 elementor-widget__width-auto elementor-widget elementor-widget-apus_element_primary_menu" data-element_type="widget" data-id="df9c6b1" data-widget_type="apus_element_primary_menu.default">
#  <div class="elementor-widget-container">
#  <div class="main-menu">
#  <nav class="apus-megamenu slide animate navbar" data-duration="400" role="navigation">
#  <div class="collapse navbar-collapse no-padding">
#  <ul class="nav navbar-nav megamenu effect2" id="primary-menu">
#  <li class="dropdown menu-item-3206 aligned-left">
#  <a class="dropdown-toggle" data-hover="dropdown" data-toggle="dropdown" href="https://cwlagos.com/">
#                   Cities
#                   <b class="caret">
#  </b>
#  </a>
#  <ul class="dropdown-menu">
#  <li class="menu-item-13142 aligned-left">
#  <a href="http://cwlagos.com">
#                     Lagos
#                    </a>
#  </li>
#  <li class="menu-item-29058 aligned-left">
#  <a href="https://cwlagos.com/cwre-dubai-offer/" target="_blank">
#                     Dubai
#                    </a>
#  </li>
#  <li class="menu-item-13140 aligned-left">
#  <a href="http://theresidenceabuja.com/" target="_blank">
#                     Abuja
#                    </a>
#  </li>
#  <li class="menu-item-13141 aligned-left">
#  <a href="#">
#                     Ghana (Coming Soon)
#                    </a>
#  </li>
#  </ul>
#  </li>
#  <li class="dropdown menu-item-3207 aligned-left">
#  <a class="dropdown-toggle" data-hover="dropdown" data-toggle="dropdown" href="https://cwlagos.com/about/">
#                   About
#                   <b class="caret">
#  </b>
#  </a>
#  <ul class="dropdown-menu">
#  <li class="menu-item-3296 aligned-left">
#  <a href="https://cwlagos.com/meet-our-team/">
#                     Meet Our Team
#                    </a>
#  </li>
#  <li class="menu-item-3297 aligned-left">
#  <a href="#">
#                     Awards
#                    </a>
#  </li>
#  </ul>
#  </li>
#  <li class="menu-item-3209 aligned-left">
#  <a href="https://cwlagos.com/listings/">
#                   Listings
#                  </a>
#  </li>
#  <li class="menu-item-8630 aligned-left">
#  <a href="https://shortstays.cwlagos.com" target="_blank">
#                   Short Stays
#                  </a>
#  </li>
#  <li class="menu-item-3210 aligned-left">
#  <a href="https://cwlagos.com/new-development/">
#                   New Developments
#                  </a>
#  </li>
#  <li class="menu-item-3211 aligned-left">
#  <a href="https://cwlagos.com/blog/">
#                   Blog
#                  </a>
#  </li>
#  <li class="menu-item-3212 aligned-left">
#  <a href="https://cwlagos.com/contact/">
#                   Contact us
#                  </a>
#  </li>
#  </ul>
#  </div>
#  </nav>
#  </div>
#  </div>
#  </div>
#  <div class="elementor-element elementor-element-e1a7e2b elementor-widget__width-auto elementor-hidden-desktop elementor-hidden-tablet elementor-hidden-mobile elementor-widget elementor-widget-apus_element_user_info" data-element_type="widget" data-id="e1a7e2b" data-widget_type="apus_element_user_info.default">
#  <div class="elementor-widget-container">
#  <div class="top-wrapper-menu not-login">
#  <span class="login-icon">
#  <i class="flaticon-user">
#  </i>
#  </span>
#  <a class="btn-login apus-user-login" href="#apus_login_forgot_form" title="Login">
#               Login
#              </a>
#  <span class="space text-link">
#               /
#              </span>
#  <a class="btn-login register apus-user-register" href="#apus_register_form" title="Register">
#               Register
#              </a>
#  <div class="apus_login_register_form mfp-hide" data-effect="fadeIn" id="apus_login_forgot_form">
#  <div class="form-login-register-inner">
#  <div class="row">
#  <div class="col-sm-6 hidden-xs banner-image">
#  <div class="image-wrapper">
#  <img alt="" class="attachment-full size-full unveil-image" data-sizes="(max-width: 390px) 100vw, 390px" data-src="https://cwlagos.com/wp-content/uploads/2020/02/bg-login.jpg" data-srcset="https://cwlagos.com/wp-content/uploads/2020/02/bg-login.jpg 390w, https://cwlagos.com/wp-content/uploads/2020/02/bg-login-217x300.jpg 217w" height="540" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 390 540'%2F%3E" width="390"/>
#  </div>
#  </div>
#  <div class="col-sm-6 col-xs-12">
#  <div class="inner-right">
#  <h3 class="title">
#                    Login
#                   </h3>
#  <div class="login-form-wrapper">
#  <div class="form-container box-white-dashboard form-login-register-inner" id="login-form-wrapper">
#  <form action="https://cwlagos.com/" class="login-form" method="post">
#  <div class="wrapper-social-login">
#  <div class="inner-social">
#  <div class="facebook-login-btn-wrapper">
#  <a class="facebook-login-btn" href="https://www.facebook.com/v2.10/dialog/oauth?client_id=1&amp;state=43addc8a56c91eeabf7fc60447169cb9&amp;response_type=code&amp;sdk=php-sdk-5.6.1&amp;redirect_uri=https%3A%2F%2Fcwlagos.com%2Fwp-admin%2Fadmin-ajax.php%3Faction%3Dwp_realestate_facebook_login&amp;scope=email">
#  <i class="fab fa-facebook-f">
#  </i>
#  <span>
#                           Login with Facebook
#                          </span>
#  </a>
#  </div>
#  <div class="google-login-btn-wrapper">
#  <a class="google-login-btn" href="https://accounts.google.com/o/oauth2/auth?response_type=code&amp;redirect_uri=https%3A%2F%2Fcwlagos.com%2F&amp;client_id=1&amp;scope=email&amp;access_type=online&amp;approval_prompt=auto">
#  <i class="fab fa-google">
#  </i>
#  <span>
#                           Login with Google
#                          </span>
#  </a>
#  </div>
#  <div class="line-header">
#  <span>
#                          or
#                         </span>
#  </div>
#  </div>
#  </div>
#  <div class="form-group">
#  <i class="flaticon-user">
#  </i>
#  <label class="hidden" for="username_or_email">
#                        Username Or Email
#                       </label>
#  <sup class="required-field">
#                        *
#                       </sup>
#  <input autocomplete="off" class="form-control" id="username_or_email" name="username" placeholder="Enter username or email" type="text"/>
#  </div>
#  <div class="form-group">
#  <i class="flaticon-password">
#  </i>
#  <label class="hidden" for="login_password">
#                        Password
#                       </label>
#  <sup class="required-field">
#                        *
#                       </sup>
#  <input class="password required form-control" id="login_password" name="password" placeholder="Enter Password" type="password"/>
#  </div>
#  <div class="row space-15">
#  <div class="col-sm-6">
#  <label for="user-remember-field">
#  <input id="user-remember-field" name="remember" type="checkbox" value="true"/>
#                         Keep me signed in
#                        </label>
#  </div>
#  <div class="col-sm-6 text-right">
#  <a class="back-link" href="#forgot-password-form-wrapper" title="Forgot Password">
#                         Lost Your Password?
#                        </a>
#  </div>
#  </div>
#  <div class="form-group no-margin">
#  <input class="btn btn-theme btn-block" name="submit" type="submit" value="Login"/>
#  <div class="register-info">
#                         Don't you have an account?
#                         <a class="apus-user-register" href="#apus_register_form">
#                          Register
#                         </a>
#  </div>
#  </div>
#  <input id="security_login" name="security_login" type="hidden" value="8f3854784d"/>
#  <input name="_wp_http_referer" type="hidden" value="/property-location/ikoyi/"/>
#  </form>
#  </div>
#  <div class="form-container" id="forgot-password-form-wrapper">
#  <form action="https://cwlagos.com/secure-login/?action=lostpassword" class="forgotpassword-form" method="post" name="forgotpasswordform">
#  <h3>
#                       Reset Password
#                      </h3>
#  <div class="lostpassword-fields">
#  <div class="form-group">
#  <label for="lostpassword_username">
#                         Username or E-mail
#                        </label>
#  <sup class="required-field">
#                         *
#                        </sup>
#  <input class="user_login form-control" id="lostpassword_username" name="user_login" placeholder="Enter Username or E-mail" type="text"/>
#  </div>
#  <input id="security_lostpassword" name="security_lostpassword" type="hidden" value="1da962d83d"/>
#  <input name="_wp_http_referer" type="hidden" value="/property-location/ikoyi/"/>
#  <div class="form-group">
#  <input class="btn btn-theme btn-block" name="wp-submit" tabindex="100" type="submit" value="Get New Password"/>
#  <input class="btn btn-danger btn-block btn-cancel" tabindex="101" type="button" value="Cancel"/>
#  </div>
#  </div>
#  <div class="lostpassword-link">
#  <a class="back-link" href="#login-form-wrapper">
#                        Back To Login
#                       </a>
#  </div>
#  </form>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="apus_login_register_form mfp-hide" data-effect="fadeIn" id="apus_register_form">
#  <div class="form-login-register-inner">
#  <div class="row">
#  <div class="col-sm-6 hidden-xs banner-image">
#  <div class="image-wrapper">
#  <img alt="" class="attachment-full size-full unveil-image" data-sizes="(max-width: 390px) 100vw, 390px" data-src="https://cwlagos.com/wp-content/uploads/2020/02/bg-register.jpg" data-srcset="https://cwlagos.com/wp-content/uploads/2020/02/bg-register.jpg 390w, https://cwlagos.com/wp-content/uploads/2020/02/bg-register-177x300.jpg 177w" height="660" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 390 660'%2F%3E" width="390"/>
#  </div>
#  </div>
#  <div class="col-sm-6 col-xs-12">
#  <div class="inner-right">
#  <h3 class="title">
#                    Register
#                   </h3>
#  <div class="register-form-wrapper">
#  <div class="container-form">
#  <form class="register-form box-white-dashboard form-login-register-inner" method="post" name="registerForm">
#  <div class="form-group">
#  <i class="flaticon-user">
#  </i>
#  <input class="form-control" id="register-username" name="username" placeholder="User Name" type="text"/>
#  </div>
#  <div class="form-group">
#  <i class="flaticon-envelope">
#  </i>
#  <input class="form-control" id="register-email" name="email" placeholder="Email" type="text"/>
#  </div>
#  <div class="form-group">
#  <i class="flaticon-password">
#  </i>
#  <input class="form-control" id="password" name="password" placeholder="Password" type="password"/>
#  </div>
#  <div class="form-group">
#  <i class="flaticon-password">
#  </i>
#  <input class="form-control" id="confirmpassword" name="confirmpassword" placeholder="Re-enter Password" type="password"/>
#  </div>
#  <div class="form-group">
#  <i class="flaticon-user-1">
#  </i>
#  <select class="form-control" name="role">
#  <option value="">
#                         Select Role
#                        </option>
#  <option value="subscriber">
#                         User
#                        </option>
#  <option value="wp_realestate_agent">
#                         Agent
#                        </option>
#  <option value="wp_realestate_agency">
#                         Agency
#                        </option>
#  </select>
#  </div>
#  <input id="security_register" name="security_register" type="hidden" value="d3da6b20df"/>
#  <input name="_wp_http_referer" type="hidden" value="/property-location/ikoyi/"/>
#  <div class="form-group no-margin">
#  <button class="btn btn-theme btn-block" name="submitRegister" type="submit">
#                          Sign Up
#                         </button>
#  </div>
#  </form>
#  <div class="login-info">
#                      Already have an account?
#                      <a class="apus-user-login" href="#apus_login_forgot_form">
#                       Login
#                      </a>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="elementor-element elementor-element-979f336 elementor-widget__width-auto elementor-hidden-desktop elementor-hidden-tablet elementor-hidden-mobile elementor-widget elementor-widget-apus_element_submit_btn" data-element_type="widget" data-id="979f336" data-widget_type="apus_element_submit_btn.default">
#  <div class="elementor-widget-container">
#  <div class="widget-submit-btn">
#  <a class="btn-submit btn user-login-form" href="https://cwlagos.com/submission/">
#  <span class="flaticon-plus button-icon">
#  </span>
#               Submit Property
#              </a>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </section>,
#  <section class="inner layout-type-default" id="main-container">
#  <section class="breadcrumb-page apus-breadscrumb vertical" id="apus-breadscrumb">
#  <div class="container">
#  <div class="wrapper-breads flex-middle-sm">
#  <div class="wrapper-breads-inner">
#  <div class="left-inner">
#  <ol class="breadcrumb">
#  <li>
#  <a href="https://cwlagos.com">
#               Home
#              </a>
#  </li>
#  <li>
#  <a href="https://cwlagos.com/property-location/ikoyi/">
#               Properties
#              </a>
#  </li>
#  <li>
#  <span class="active">
#               ikoyi
#              </span>
#  </li>
#  </ol>
#  </div>
#  <div class="breadscrumb-inner clearfix">
#  <h2 class="bread-title">
#             ikoyi
#            </h2>
#  </div>
#  </div>
#  <div class="ali-right">
#  <div class="flex-middle">
#  <div class="saved-search-form-btn">
#  <a class="btn-saved-search" href="#saved-search-form-btn-wrapper">
#  <i class="flaticon-heart">
#  </i>
#              Save Search
#             </a>
#  </div>
#  <div class="saved-search-form-wrapper mfp-hide" data-effect="fadeIn" id="saved-search-form-btn-wrapper">
#  <form action="" class="saved-search-form" method="get">
#  <div class="form-group">
#  <label for="saved_search_title">
#                Title
#               </label>
#  <input class="form-control" id="saved_search_title" name="name" placeholder="Title" type="text"/>
#  </div>
#  <div class="form-group">
#  <label for="saved_search_email_frequency">
#                Email Frequency
#               </label>
#  <div class="wrapper-select">
#  <select class="form-control" id="saved_search_email_frequency" name="email_frequency">
#  <option value="daily">
#                  Daily
#                 </option>
#  <option value="weekly">
#                  Weekly
#                 </option>
#  <option value="fortnightly">
#                  Fortnightly
#                 </option>
#  <option value="monthly">
#                  Monthly
#                 </option>
#  <option value="biannually">
#                  Biannually
#                 </option>
#  <option value="annually">
#                  Annually
#                 </option>
#  </select>
#  </div>
#  </div>
#  <input id="nonce" name="nonce" type="hidden" value="407535f681"/>
#  <input name="_wp_http_referer" type="hidden" value="/property-location/ikoyi/"/>
#  <div class="form-group no-margin">
#  <button class="button btn btn-theme">
#                  Save
#                 </button>
#  </div>
#  </form>
#  </div>
#  <div class="properties-display-mode-wrapper">
#  <form action="https://cwlagos.com/property-location/ikoyi/" class="properties-display-mode" method="get">
#  <div class="inner">
#  <label for="filter-display-mode-grid">
#  <input checked="checked" id="filter-display-mode-grid" name="filter-display-mode" type="radio" value="grid"/>
#  <i class="flaticon-menu">
#  </i>
#  </label>
#  <label for="filter-display-mode-list">
#  <input id="filter-display-mode-list" name="filter-display-mode" type="radio" value="list"/>
#  <i class="flaticon-menu-1">
#  </i>
#  </label>
#  </div>
#  </form>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </section>
#  <div class="main-content container inner">
#  <a class="mobile-sidebar-btn hidden-lg hidden-md btn-right" href="javascript:void(0)">
#  <i class="ti-menu-alt">
#  </i>
#  </a>
#  <div class="mobile-sidebar-panel-overlay">
#  </div>
#  <div class="row">
#  <div class="col-sm-12 col-md-8 col-lg-8 col-sm-12 col-xs-12" id="main-content">
#  <main class="site-main layout-type-default" id="main" role="main">
#  <div class="properties-listing-wrapper main-items-wrapper" data-display_mode="grid">
#  <div class="properties-ordering-wrapper">
#  <div class="results-count">
#              Showing
#              <span class="first">
#               1
#              </span>
#              –
#              <span class="last">
#               15
#              </span>
#              of 367 results
#             </div>
#  <div class="properties-ordering">
#  <form action="https://cwlagos.com/property-location/ikoyi/" class="properties-ordering" method="get">
#  <div class="label">
#                Sort by:
#               </div>
#  <select class="orderby" data-placeholder="Sort by" name="filter-orderby">
#  <option selected="selected" value="menu_order">
#                 Default
#                </option>
#  <option value="newest">
#                 Newest
#                </option>
#  <option value="oldest">
#                 Oldest
#                </option>
#  <option value="price-lowest">
#                 Lowest Price
#                </option>
#  <option value="price-highest">
#                 Highest Price
#                </option>
#  <option value="random">
#                 Random
#                </option>
#  </select>
#  <input name="paged" type="hidden" value="1"/>
#  </form>
#  </div>
#  </div>
#  <div class="properties-wrapper items-wrapper clearfix">
#  <div class="row">
#  <div class="col-sm-6 col-md-4 col-ct-12 col-xs-12 lg-clearfix md-clearfix sm-clearfix">
#  <article class="map-item property-grid property-item post-86590 property type-property status-publish has-post-thumbnail hentry property_type-maisonette property_location-ikoyi property_location-old-ikoyi property_status-for-rent property_label-available-for-rent" data-images='["https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/07\/Untitled-design-31-2-850x550.png","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/07\/WhatsApp-Image-2025-07-17-at-18.17.32_fc21f349-810x550.jpg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/07\/WhatsApp-Image-2025-07-17-at-18.17.33_65469cbc-810x550.jpg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/07\/WhatsApp-Image-2025-07-17-at-18.17.33_b626ba97-810x550.jpg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/07\/WhatsApp-Image-2025-07-17-at-18.17.34_153770b9-810x550.jpg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/07\/WhatsApp-Image-2025-07-17-at-18.17.34_f43f614b-810x550.jpg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/07\/WhatsApp-Image-2025-07-17-at-18.17.35_2d868fc5-810x550.jpg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/07\/WhatsApp-Image-2025-07-17-at-18.17.35_3abfb231-810x550.jpg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/07\/WhatsApp-Image-2025-07-17-at-18.17.36_68cd999f-810x550.jpg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/07\/WhatsApp-Image-2025-07-17-at-18.17.36_85b118a2-810x550.jpg"]' data-img="https://cwlagos.com/wp-content/uploads/2025/07/Untitled-design-31-2-850x550.png" data-latitude="" data-longitude="">
#  <div class="top-info">
#  <div class="property-thumbnail-wrapper flex-middle justify-content-center">
#  <div class="image-thumbnail">
#  <a class="property-image" href="https://cwlagos.com/property/2-bedroom-maisonette-bq-in-ikoyi/">
#  <div class="image-wrapper">
#  <img alt="" class="attachment-homeo-property-grid size-homeo-property-grid unveil-image" data-src="https://cwlagos.com/wp-content/uploads/2025/07/Untitled-design-31-2-850x550.png" height="550" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 850 550'%2F%3E" width="850"/>
#  </div>
#  </a>
#  </div>
#  <div class="top-label">
#  <a class="status-property-label" href="https://cwlagos.com/property-status/for-rent/" style="">
#                    For Rent
#                   </a>
#  <span class="featured-property">
#                    Featured
#                   </span>
#  <a class="label-property-label" href="https://cwlagos.com/property-label/available-for-rent/" style="">
#                    Available for rent
#                   </a>
#  </div>
#  <div class="bottom-label flex-middle">
#  <div class="property-price">
#  <span class="suffix">
#                     NGN
#                    </span>
#  <span class="price-text">
#                     35,000,000
#                    </span>
#  </div>
#  <div class="ali-right">
#  <a class="btn-add-property-favorite" data-nonce="db292f5b35" data-property_id="86590" data-toggle="tooltip" href="javascript:void(0)" title="Add Favorite">
#  <i class="flaticon-heart">
#  </i>
#  </a>
#  <a class="btn-add-property-compare" data-nonce="c27294dbde" data-property_id="86590" data-toggle="tooltip" href="javascript:void(0)" title="Add Compare">
#  <i class="flaticon-transfer-1">
#  </i>
#  </a>
#  </div>
#  </div>
#  </div>
#  <div class="property-information">
#  <div class="property-type">
#  <div class="property-type with-no-title">
#  <a class="type-property" href="https://cwlagos.com/property-type/maisonette/" style="">
#                     Maisonette
#                    </a>
#  </div>
#  </div>
#  <h2 class="property-title">
#  <a href="https://cwlagos.com/property/2-bedroom-maisonette-bq-in-ikoyi/" rel="bookmark">
#                    2 Bedroom Maisonette + BQ in Ikoyi
#                   </a>
#  </h2>
#  <div class="property-location with-icon">
#  <i class="flaticon-maps-and-flags">
#  </i>
#  <a href="//maps.google.com/maps?q=Ikoyi&amp;zoom=14&amp;size=512x512&amp;maptype=roadmap&amp;sensor=false" target="_blank">
#                    Ikoyi
#                   </a>
#  </div>
#  <div class="property-metas flex-middle flex-wrap">
#  <div class="property-meta with-icon-title">
#  <div class="property-meta">
#  <span class="title-meta">
#                      Beds:
#                     </span>
#                     2
#                    </div>
#  </div>
#  <div class="property-meta with-icon-title">
#  <div class="property-meta">
#  <span class="title-meta">
#                      Baths:
#                     </span>
#                     2
#                    </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="property-metas-bottom flex-middle">
#  <div class="avatar-wrapper flex-middle">
#  <div class="avatar-img">
#  <img alt="" class="avatar avatar-80 photo" decoding="async" height="80" src="https://cwlagos.com/wp-content/litespeed/avatar/2febfac1abd2c64e29ecbd5fa4e1f537.jpg?ver=1762990271" srcset="https://cwlagos.com/wp-content/litespeed/avatar/daabec60c064015bab133694a2557064.jpg?ver=1762990282 2x" width="80"/>
#  </div>
#  <div class="name-author">
#                   admin-cw
#                  </div>
#  </div>
#  <div class="ali-right">
#  <div class="property-postdate">
#                   4 months ago
#                  </div>
#  </div>
#  </div>
#  </article>
#  </div>
#  <div class="col-sm-6 col-md-4 col-ct-12 col-xs-12">
#  <article class="map-item property-grid property-item post-81041 property type-property status-publish has-post-thumbnail hentry property_type-apartment property_location-ikoyi property_status-for-rent property_label-available-for-rent property_amenity-24hrs-power property_amenity-30kva-generator property_amenity-5kva-inverter property_amenity-balcony property_amenity-bq property_amenity-car-park property_amenity-cctv property_amenity-children-playground property_amenity-fitted-bathrooms property_amenity-fitted-kitchen property_amenity-fully-furnished property_amenity-gated-estate property_amenity-gym property_amenity-home-automation property_amenity-home-entertainment-unit property_amenity-jacuzzi property_amenity-maids-room property_amenity-rooftop-terrace property_amenity-swimming-pool property_amenity-walk-in-closet property_amenity-wifi property_material-brick property_material-concrete property_material-marble property_material-wood" data-images='["https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/Group-2-1-3-850x550.png","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/Group-2-1-3-850x550.png","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/Group-2-66-850x550.png","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-19-at-11.46.22-2-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-19-at-11.46.22-1-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-19-at-11.46.22-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-19-at-11.46.21-1-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-19-at-11.46.21-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-19-at-11.46.20-1-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-19-at-11.46.20-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-19-at-11.46.19-1-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-19-at-11.46.19-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-19-at-11.46.18-1-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-19-at-11.46.18-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-19-at-11.46.17-1-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-19-at-11.46.17-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-19-at-11.46.16-1-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-19-at-11.46.16-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-19-at-11.46.15-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-19-at-11.45.49-850x550.jpeg"]' data-img="https://cwlagos.com/wp-content/uploads/2025/03/Group-2-1-3-850x550.png" data-latitude="6.4523431" data-longitude="3.4280523">
#  <div class="top-info">
#  <div class="property-thumbnail-wrapper flex-middle justify-content-center">
#  <div class="image-thumbnail">
#  <a class="property-image" href="https://cwlagos.com/property/4-bedroom-furnished-apartment-bq/">
#  <div class="image-wrapper">
#  <img alt="" class="attachment-homeo-property-grid size-homeo-property-grid unveil-image" data-src="https://cwlagos.com/wp-content/uploads/2025/03/Group-2-1-3-850x550.png" height="550" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 850 550'%2F%3E" width="850"/>
#  </div>
#  </a>
#  </div>
#  <div class="top-label">
#  <a class="status-property-label" href="https://cwlagos.com/property-status/for-rent/" style="">
#                    For Rent
#                   </a>
#  <span class="featured-property">
#                    Featured
#                   </span>
#  <a class="label-property-label" href="https://cwlagos.com/property-label/available-for-rent/" style="">
#                    Available for rent
#                   </a>
#  </div>
#  <div class="bottom-label flex-middle">
#  <div class="property-price">
#                    #35,000,000
#                   </div>
#  <div class="ali-right">
#  <a class="btn-add-property-favorite" data-nonce="db292f5b35" data-property_id="81041" data-toggle="tooltip" href="javascript:void(0)" title="Add Favorite">
#  <i class="flaticon-heart">
#  </i>
#  </a>
#  <a class="btn-add-property-compare" data-nonce="c27294dbde" data-property_id="81041" data-toggle="tooltip" href="javascript:void(0)" title="Add Compare">
#  <i class="flaticon-transfer-1">
#  </i>
#  </a>
#  </div>
#  </div>
#  </div>
#  <div class="property-information">
#  <div class="property-type">
#  <div class="property-type with-no-title">
#  <a class="type-property" href="https://cwlagos.com/property-type/apartment/" style="">
#                     Apartment
#                    </a>
#  </div>
#  </div>
#  <h2 class="property-title">
#  <a href="https://cwlagos.com/property/4-bedroom-furnished-apartment-bq/" rel="bookmark">
#                    4 Bedroom Furnished Apartment + BQ
#                   </a>
#  </h2>
#  <div class="property-location with-icon">
#  <i class="flaticon-maps-and-flags">
#  </i>
#  <a href="//maps.google.com/maps?q=Ikoyi%2C+Lagos.&amp;zoom=14&amp;size=512x512&amp;maptype=roadmap&amp;sensor=false" target="_blank">
#                    Ikoyi, Lagos.
#                   </a>
#  </div>
#  <div class="property-metas flex-middle flex-wrap">
#  <div class="property-meta with-icon-title">
#  <div class="property-meta">
#  <span class="title-meta">
#                      Beds:
#                     </span>
#                     4
#                    </div>
#  </div>
#  <div class="property-meta with-icon-title">
#  <div class="property-meta">
#  <span class="title-meta">
#                      Baths:
#                     </span>
#                     4
#                    </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="property-metas-bottom flex-middle">
#  <div class="avatar-wrapper flex-middle">
#  <div class="avatar-img">
#  <img alt="" class="avatar avatar-80 photo" decoding="async" height="80" src="https://cwlagos.com/wp-content/litespeed/avatar/2febfac1abd2c64e29ecbd5fa4e1f537.jpg?ver=1762990271" srcset="https://cwlagos.com/wp-content/litespeed/avatar/daabec60c064015bab133694a2557064.jpg?ver=1762990282 2x" width="80"/>
#  </div>
#  <div class="name-author">
#                   admin-cw
#                  </div>
#  </div>
#  <div class="ali-right">
#  <div class="property-postdate">
#                   8 months ago
#                  </div>
#  </div>
#  </div>
#  </article>
#  </div>
#  <div class="col-sm-6 col-md-4 col-ct-12 col-xs-12 sm-clearfix">
#  <article class="map-item property-grid property-item post-80951 property type-property status-publish has-post-thumbnail hentry property_type-maisonette property_location-ikoyi property_status-for-sale property_label-available-for-sale property_amenity-24hrs-power property_amenity-30kva-generator property_amenity-5kva-inverter property_amenity-balcony property_amenity-bq property_amenity-car-park property_amenity-cctv property_amenity-children-playground property_amenity-fitted-bathrooms property_amenity-fitted-kitchen property_amenity-fully-furnished property_amenity-gated-estate property_amenity-golf-course-view property_amenity-gym property_amenity-home-automation property_amenity-home-entertainment-unit property_amenity-jacuzzi property_amenity-maids-room property_amenity-private-elevator property_amenity-rooftop-terrace property_amenity-study property_amenity-swimming-pool property_amenity-walk-in-closet property_amenity-wifi property_material-brick property_material-concrete property_material-marble property_material-wood" data-images='["https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/Group-2-63-850x550.png","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/Group-2-63-850x550.png","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-26-at-07.03.20-2-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-26-at-07.03.20-1-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-26-at-07.03.20-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-26-at-07.03.19-5-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-26-at-07.03.19-4-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-26-at-07.03.19-3-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-26-at-07.03.19-2-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-26-at-07.03.19-1-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-26-at-07.03.19-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-26-at-07.03.18-850x550.jpeg"]' data-img="https://cwlagos.com/wp-content/uploads/2025/03/Group-2-63-850x550.png" data-latitude="6.456061" data-longitude="3.442218">
#  <div class="top-info">
#  <div class="property-thumbnail-wrapper flex-middle justify-content-center">
#  <div class="image-thumbnail">
#  <a class="property-image" href="https://cwlagos.com/property/luxury-3-bedroom-maisonette-with-bq/">
#  <div class="image-wrapper">
#  <img alt="" class="attachment-homeo-property-grid size-homeo-property-grid unveil-image" data-src="https://cwlagos.com/wp-content/uploads/2025/03/Group-2-63-850x550.png" height="550" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 850 550'%2F%3E" width="850"/>
#  </div>
#  </a>
#  </div>
#  <div class="top-label">
#  <a class="status-property-label" href="https://cwlagos.com/property-status/for-sale/" style="">
#                    For Sale
#                   </a>
#  <span class="featured-property">
#                    Featured
#                   </span>
#  <a class="label-property-label" href="https://cwlagos.com/property-label/available-for-sale/" style="">
#                    Available for sale
#                   </a>
#  </div>
#  <div class="bottom-label flex-middle">
#  <div class="property-price">
#                    #900,000,000
#                   </div>
#  <div class="ali-right">
#  <a class="btn-add-property-favorite" data-nonce="db292f5b35" data-property_id="80951" data-toggle="tooltip" href="javascript:void(0)" title="Add Favorite">
#  <i class="flaticon-heart">
#  </i>
#  </a>
#  <a class="btn-add-property-compare" data-nonce="c27294dbde" data-property_id="80951" data-toggle="tooltip" href="javascript:void(0)" title="Add Compare">
#  <i class="flaticon-transfer-1">
#  </i>
#  </a>
#  </div>
#  </div>
#  </div>
#  <div class="property-information">
#  <div class="property-type">
#  <div class="property-type with-no-title">
#  <a class="type-property" href="https://cwlagos.com/property-type/maisonette/" style="">
#                     Maisonette
#                    </a>
#  </div>
#  </div>
#  <h2 class="property-title">
#  <a href="https://cwlagos.com/property/luxury-3-bedroom-maisonette-with-bq/" rel="bookmark">
#                    Luxury 3 Bedroom Maisonette with BQ
#                   </a>
#  </h2>
#  <div class="property-location with-icon">
#  <i class="flaticon-maps-and-flags">
#  </i>
#  <a href="//maps.google.com/maps?q=Ikoyi%2C+Lagos.&amp;zoom=14&amp;size=512x512&amp;maptype=roadmap&amp;sensor=false" target="_blank">
#                    Ikoyi, Lagos.
#                   </a>
#  </div>
#  <div class="property-metas flex-middle flex-wrap">
#  <div class="property-meta with-icon-title">
#  <div class="property-meta">
#  <span class="title-meta">
#                      Beds:
#                     </span>
#                     3
#                    </div>
#  </div>
#  <div class="property-meta with-icon-title">
#  <div class="property-meta">
#  <span class="title-meta">
#                      Baths:
#                     </span>
#                     3
#                    </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="property-metas-bottom flex-middle">
#  <div class="avatar-wrapper flex-middle">
#  <div class="avatar-img">
#  <a href="https://cwlagos.com/agent/adeyemi-fowosire/">
#  <div class="image-wrapper">
#  <img alt="" class="attachment-thumbnail size-thumbnail unveil-image" data-src="https://cwlagos.com/wp-content/uploads/2024/12/DSC01354-150x150.jpg" height="150" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 150 150'%2F%3E" width="150"/>
#  </div>
#  </a>
#  </div>
#  <div class="name-author">
#  <a href="https://cwlagos.com/agent/adeyemi-fowosire/">
#                    Adeyemi Fowosire
#                   </a>
#  </div>
#  </div>
#  <div class="ali-right">
#  <div class="property-postdate">
#                   8 months ago
#                  </div>
#  </div>
#  </div>
#  </article>
#  </div>
#  <div class="col-sm-6 col-md-4 col-ct-12 col-xs-12 lg-clearfix md-clearfix">
#  <article class="map-item property-grid property-item post-80854 property type-property status-publish has-post-thumbnail hentry property_type-detached property_location-banana-island-ikoyi property_location-ikoyi property_status-for-rent property_label-available-for-sale property_amenity-24hrs-power property_amenity-30kva-generator property_amenity-5kva-inverter property_amenity-balcony property_amenity-bq property_amenity-car-park property_amenity-cctv property_amenity-children-playground property_amenity-cinema property_amenity-fitted-bathrooms property_amenity-fitted-kitchen property_amenity-garden property_amenity-gated-estate property_amenity-gym property_amenity-home-automation property_amenity-home-entertainment-unit property_amenity-jacuzzi property_amenity-maids-room property_amenity-rooftop-terrace property_amenity-study property_amenity-swimming-pool property_amenity-walk-in-closet property_amenity-wifi property_material-brick property_material-concrete property_material-marble property_material-wood" data-images='["https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/Group-2-59-850x550.png","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/Group-2-59-850x550.png","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-24-at-06.04.26-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-24-at-06.04.25-1-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-24-at-06.04.25-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-24-at-06.04.22-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-24-at-06.04.21-1-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-24-at-06.04.21-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-24-at-06.04.19-1-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-24-at-06.04.19-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-24-at-06.04.18-2-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-24-at-06.04.18-1-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-24-at-06.04.18-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-24-at-06.04.17-2-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-24-at-06.04.17-1-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-24-at-06.04.17-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-24-at-06.04.16-1-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-24-at-06.04.16-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-24-at-06.04.14-850x550.jpeg"]' data-img="https://cwlagos.com/wp-content/uploads/2025/03/Group-2-59-850x550.png" data-latitude="6.4629584" data-longitude="3.4570214">
#  <div class="top-info">
#  <div class="property-thumbnail-wrapper flex-middle justify-content-center">
#  <div class="image-thumbnail">
#  <a class="property-image" href="https://cwlagos.com/property/luxury-5-bedroom-detached-house-with-en-suite-bq/">
#  <div class="image-wrapper">
#  <img alt="" class="attachment-homeo-property-grid size-homeo-property-grid unveil-image" data-src="https://cwlagos.com/wp-content/uploads/2025/03/Group-2-59-850x550.png" height="550" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 850 550'%2F%3E" width="850"/>
#  </div>
#  </a>
#  </div>
#  <div class="top-label">
#  <a class="status-property-label" href="https://cwlagos.com/property-status/for-rent/" style="">
#                    For Rent
#                   </a>
#  <span class="featured-property">
#                    Featured
#                   </span>
#  <a class="label-property-label" href="https://cwlagos.com/property-label/available-for-sale/" style="">
#                    Available for sale
#                   </a>
#  </div>
#  <div class="bottom-label flex-middle">
#  <div class="property-price">
#                    N100,000,000
#                   </div>
#  <div class="ali-right">
#  <a class="btn-add-property-favorite" data-nonce="db292f5b35" data-property_id="80854" data-toggle="tooltip" href="javascript:void(0)" title="Add Favorite">
#  <i class="flaticon-heart">
#  </i>
#  </a>
#  <a class="btn-add-property-compare" data-nonce="c27294dbde" data-property_id="80854" data-toggle="tooltip" href="javascript:void(0)" title="Add Compare">
#  <i class="flaticon-transfer-1">
#  </i>
#  </a>
#  </div>
#  </div>
#  </div>
#  <div class="property-information">
#  <div class="property-type">
#  <div class="property-type with-no-title">
#  <a class="type-property" href="https://cwlagos.com/property-type/detached/" style="">
#                     Detached
#                    </a>
#  </div>
#  </div>
#  <h2 class="property-title">
#  <a href="https://cwlagos.com/property/luxury-5-bedroom-detached-house-with-en-suite-bq/" rel="bookmark">
#                    Luxury 5 Bedroom Detached House
#                   </a>
#  </h2>
#  <div class="property-location with-icon">
#  <i class="flaticon-maps-and-flags">
#  </i>
#  <a href="//maps.google.com/maps?q=Banana+Island%2C+Ikoyi%2C+Lagos.&amp;zoom=14&amp;size=512x512&amp;maptype=roadmap&amp;sensor=false" target="_blank">
#                    Banana Island, Ikoyi, Lagos.
#                   </a>
#  </div>
#  <div class="property-metas flex-middle flex-wrap">
#  <div class="property-meta with-icon-title">
#  <div class="property-meta">
#  <span class="title-meta">
#                      Beds:
#                     </span>
#                     5
#                    </div>
#  </div>
#  <div class="property-meta with-icon-title">
#  <div class="property-meta">
#  <span class="title-meta">
#                      Baths:
#                     </span>
#                     5
#                    </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="property-metas-bottom flex-middle">
#  <div class="avatar-wrapper flex-middle">
#  <div class="avatar-img">
#  <a href="https://cwlagos.com/agent/adeyemi-fowosire/">
#  <div class="image-wrapper">
#  <img alt="" class="attachment-thumbnail size-thumbnail unveil-image" data-src="https://cwlagos.com/wp-content/uploads/2024/12/DSC01354-150x150.jpg" height="150" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 150 150'%2F%3E" width="150"/>
#  </div>
#  </a>
#  </div>
#  <div class="name-author">
#  <a href="https://cwlagos.com/agent/adeyemi-fowosire/">
#                    Adeyemi Fowosire
#                   </a>
#  </div>
#  </div>
#  <div class="ali-right">
#  <div class="property-postdate">
#                   8 months ago
#                  </div>
#  </div>
#  </div>
#  </article>
#  </div>
#  <div class="col-sm-6 col-md-4 col-ct-12 col-xs-12 sm-clearfix">
#  <article class="map-item property-grid property-item post-80706 property type-property status-publish has-post-thumbnail hentry property_type-maisonette property_location-ikoyi property_status-for-sale property_label-available-for-sale property_amenity-24hrs-power property_amenity-30kva-generator property_amenity-5kva-inverter property_amenity-balcony property_amenity-car-park property_amenity-cctv property_amenity-children-playground property_amenity-fitted-bathrooms property_amenity-fitted-kitchen property_amenity-fully-furnished property_amenity-garden property_amenity-gated-estate property_amenity-home-automation property_amenity-home-entertainment-unit property_amenity-jacuzzi property_amenity-private-elevator property_amenity-rooftop-terrace property_amenity-study property_amenity-swimming-pool property_amenity-walk-in-closet property_amenity-wifi property_material-brick property_material-concrete property_material-marble property_material-wood" data-images='["https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/Group-2-52-696x550.png","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/Group-2-52-696x550.png","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-18-at-09.45.28-1-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-18-at-09.45.28-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-18-at-09.45.27-4-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-18-at-09.45.27-3-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-18-at-09.45.27-2-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-18-at-09.45.27-1-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-18-at-09.45.27-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-18-at-09.45.26-2-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-18-at-09.45.26-1-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-18-at-09.45.26-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-18-at-09.45.25-1-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-18-at-09.45.25-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-18-at-09.45.24-1-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-18-at-09.45.24-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-18-at-09.45.23-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-18-at-09.45.22-1-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-18-at-09.45.22-850x550.jpeg"]' data-img="https://cwlagos.com/wp-content/uploads/2025/03/Group-2-52-696x550.png" data-latitude="6.456061" data-longitude="3.442218">
#  <div class="top-info">
#  <div class="property-thumbnail-wrapper flex-middle justify-content-center">
#  <div class="image-thumbnail">
#  <a class="property-image" href="https://cwlagos.com/property/exclusive-4-bedroom-maisonette-with-swimming-pool-2/">
#  <div class="image-wrapper">
#  <img alt="" class="attachment-homeo-property-grid size-homeo-property-grid unveil-image" data-sizes="(max-width: 696px) 100vw, 696px" data-src="https://cwlagos.com/wp-content/uploads/2025/03/Group-2-52-696x550.png" data-srcset="https://cwlagos.com/wp-content/uploads/2025/03/Group-2-52-696x550.png 696w, https://cwlagos.com/wp-content/uploads/2025/03/Group-2-52-165x130.png 165w" height="550" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 696 550'%2F%3E" width="696"/>
#  </div>
#  </a>
#  </div>
#  <div class="top-label">
#  <a class="status-property-label" href="https://cwlagos.com/property-status/for-sale/" style="">
#                    For Sale
#                   </a>
#  <span class="featured-property">
#                    Featured
# ...
#                                   Gym
#                                  </label>
#  </div>
#  </li>
#  <li class="list-item level-0">
#  <div class="list-item-inner">
#  <input id="filter-amenity-home-automation-30012" name="filter-amenity[]" type="checkbox" value="118"/>
#  <label for="filter-amenity-home-automation-30012">
#                                   Home Automation
#                                  </label>
#  </div>
#  </li>
#  <li class="list-item level-0">
#  <div class="list-item-inner">
#  <input id="filter-amenity-home-entertainment-unit-30012" name="filter-amenity[]" type="checkbox" value="119"/>
#  <label for="filter-amenity-home-entertainment-unit-30012">
#                                   Home Entertainment Unit
#                                  </label>
#  </div>
#  </li>
#  <li class="list-item level-0">
#  <div class="list-item-inner">
#  <input id="filter-amenity-jacuzzi-30012" name="filter-amenity[]" type="checkbox" value="157"/>
#  <label for="filter-amenity-jacuzzi-30012">
#                                   Jacuzzi
#                                  </label>
#  </div>
#  </li>
#  <li class="list-item level-0">
#  <div class="list-item-inner">
#  <input id="filter-amenity-maids-room-30012" name="filter-amenity[]" type="checkbox" value="229"/>
#  <label for="filter-amenity-maids-room-30012">
#                                   Maid's Room
#                                  </label>
#  </div>
#  </li>
#  <li class="list-item level-0">
#  <div class="list-item-inner">
#  <input id="filter-amenity-private-cinema-30012" name="filter-amenity[]" type="checkbox" value="107"/>
#  <label for="filter-amenity-private-cinema-30012">
#                                   Private Cinema
#                                  </label>
#  </div>
#  </li>
#  <li class="list-item level-0">
#  <div class="list-item-inner">
#  <input id="filter-amenity-private-elevator-30012" name="filter-amenity[]" type="checkbox" value="113"/>
#  <label for="filter-amenity-private-elevator-30012">
#                                   Private Elevator
#                                  </label>
#  </div>
#  </li>
#  <li class="list-item level-0">
#  <div class="list-item-inner">
#  <input id="filter-amenity-rooftop-terrace-30012" name="filter-amenity[]" type="checkbox" value="114"/>
#  <label for="filter-amenity-rooftop-terrace-30012">
#                                   Rooftop Terrace
#                                  </label>
#  </div>
#  </li>
#  <li class="list-item level-0">
#  <div class="list-item-inner">
#  <input id="filter-amenity-sauna-30012" name="filter-amenity[]" type="checkbox" value="74"/>
#  <label for="filter-amenity-sauna-30012">
#                                   Sauna
#                                  </label>
#  </div>
#  </li>
#  <li class="list-item level-0">
#  <div class="list-item-inner">
#  <input id="filter-amenity-study-30012" name="filter-amenity[]" type="checkbox" value="206"/>
#  <label for="filter-amenity-study-30012">
#                                   Study
#                                  </label>
#  </div>
#  </li>
#  <li class="list-item level-0">
#  <div class="list-item-inner">
#  <input id="filter-amenity-swimming-pool-30012" name="filter-amenity[]" type="checkbox" value="77"/>
#  <label for="filter-amenity-swimming-pool-30012">
#                                   Swimming Pool
#                                  </label>
#  </div>
#  </li>
#  <li class="list-item level-0">
#  <div class="list-item-inner">
#  <input id="filter-amenity-tennis-court-30012" name="filter-amenity[]" type="checkbox" value="144"/>
#  <label for="filter-amenity-tennis-court-30012">
#                                   Tennis Court
#                                  </label>
#  </div>
#  </li>
#  <li class="list-item level-0">
#  <div class="list-item-inner">
#  <input id="filter-amenity-walk-in-closet-30012" name="filter-amenity[]" type="checkbox" value="120"/>
#  <label for="filter-amenity-walk-in-closet-30012">
#                                   Walk-in Closet
#                                  </label>
#  </div>
#  </li>
#  <li class="list-item level-0">
#  <div class="list-item-inner">
#  <input id="filter-amenity-water-front-30012" name="filter-amenity[]" type="checkbox" value="199"/>
#  <label for="filter-amenity-water-front-30012">
#                                   Water Front
#                                  </label>
#  </div>
#  </li>
#  <li class="list-item level-0">
#  <div class="list-item-inner">
#  <input id="filter-amenity-water-view-30012" name="filter-amenity[]" type="checkbox" value="121"/>
#  <label for="filter-amenity-water-view-30012">
#                                   Water View
#                                  </label>
#  </div>
#  </li>
#  <li class="list-item level-0">
#  <div class="list-item-inner">
#  <input id="filter-amenity-wifi-30012" name="filter-amenity[]" type="checkbox" value="83"/>
#  <label for="filter-amenity-wifi-30012">
#                                   WiFi
#                                  </label>
#  </div>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="row">
#  <div class="col-xs-12 col-md-12 form-group-search">
#  <button class="btn-submit btn-block btn btn-theme btn-inverse" type="submit">
#                           Find Property
#                          </button>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </form>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </section>,
#  <section class="elementor-section elementor-top-section elementor-element elementor-element-85e2edf elementor-section-stretched ftmobile elementor-section-boxed elementor-section-height-default elementor-section-height-default" data-element_type="section" data-id="85e2edf" data-settings='{"stretch_section":"section-stretched","background_background":"classic"}'>
#  <div class="elementor-container elementor-column-gap-extended">
#  <div class="elementor-column elementor-col-25 elementor-top-column elementor-element elementor-element-22e1858" data-element_type="column" data-id="22e1858">
#  <div class="elementor-widget-wrap elementor-element-populated">
#  <div class="elementor-element elementor-element-006804c elementor-widget elementor-widget-apus_element_nav_menu" data-element_type="widget" data-id="006804c" data-widget_type="apus_element_nav_menu.default">
#  <div class="elementor-widget-container">
#  <div class="widget-nav-menu no-margin widget">
#  <h2 class="widget-title">
#                Quick Links
#               </h2>
#  <div class="widget-content">
#  <div class="menu-quick-links-1-container">
#  <ul class="menu" id="menu-quick-links-1">
#  <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-5626" id="menu-item-5626">
#  <a href="#">
#                    Awards
#                   </a>
#  </li>
#  <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-5631" id="menu-item-5631">
#  <a href="https://cwlagos.com/careers/">
#                    Careers – Join Our Team
#                   </a>
#  </li>
#  <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-5628" id="menu-item-5628">
#  <a href="https://cwlagos.com/theikoyireporth1/">
#                    Market Knowledge
#                   </a>
#  </li>
#  <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-5632" id="menu-item-5632">
#  <a href="https://cwlagos.com/referral-program/">
#                    Referral Program
#                   </a>
#  </li>
#  <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-5630" id="menu-item-5630">
#  <a href="#">
#                    Press &amp; Publications
#                   </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="elementor-column elementor-col-25 elementor-top-column elementor-element elementor-element-30d9101" data-element_type="column" data-id="30d9101">
#  <div class="elementor-widget-wrap elementor-element-populated">
#  <div class="elementor-element elementor-element-e68414e elementor-widget elementor-widget-apus_element_nav_menu" data-element_type="widget" data-id="e68414e" data-widget_type="apus_element_nav_menu.default">
#  <div class="elementor-widget-container">
#  <div class="widget-nav-menu no-margin widget">
#  <h2 class="widget-title">
#  </h2>
#  <div class="widget-content">
#  <div class="menu-quick-links-2-container">
#  <ul class="menu" id="menu-quick-links-2">
#  <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-3288" id="menu-item-3288">
#  <a href="https://cwlagos.com/faq/">
#                    FAQs
#                   </a>
#  </li>
#  <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-3290" id="menu-item-3290">
#  <a href="https://cwlagos.com/agents/">
#                    Find an Agent
#                   </a>
#  </li>
#  <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-3291" id="menu-item-3291">
#  <a href="https://cwlagos.com/blog/">
#                    Our Blogs
#                   </a>
#  </li>
#  <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-3289" id="menu-item-3289">
#  <a href="#">
#                    Media
#                   </a>
#  </li>
#  <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-3293" id="menu-item-3293">
#  <a href="#">
#                    List with us
#                   </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="elementor-column elementor-col-25 elementor-top-column elementor-element elementor-element-83f5af2" data-element_type="column" data-id="83f5af2">
#  <div class="elementor-widget-wrap elementor-element-populated">
#  <div class="elementor-element elementor-element-be13cec elementor-widget elementor-widget-heading" data-element_type="widget" data-id="be13cec" data-widget_type="heading.default">
#  <div class="elementor-widget-container">
#  <h2 class="elementor-heading-title elementor-size-default">
#               Contact Us
#              </h2>
#  </div>
#  </div>
#  <div class="elementor-element elementor-element-69fcfe4 elementor-widget elementor-widget-heading" data-element_type="widget" data-id="69fcfe4" data-widget_type="heading.default">
#  <div class="elementor-widget-container">
#  <div class="elementor-heading-title elementor-size-default">
#  <a href="mailto:hello@cwlagos.com">
#                hello@cwlagos.com
#               </a>
#  </div>
#  </div>
#  </div>
#  <div class="elementor-element elementor-element-b817dee elementor-widget elementor-widget-heading" data-element_type="widget" data-id="b817dee" data-widget_type="heading.default">
#  <div class="elementor-widget-container">
#  <div class="elementor-heading-title elementor-size-default">
#               3/5 Modupe Alakija, Ikoyi , Lagos
#              </div>
#  </div>
#  </div>
#  <div class="elementor-element elementor-element-dba7eb1 elementor-widget elementor-widget-heading" data-element_type="widget" data-id="dba7eb1" data-widget_type="heading.default">
#  <div class="elementor-widget-container">
#  <div class="elementor-heading-title elementor-size-default">
#               +234 906 251 1343
#               <br/>
#  <br/>
#               +234 704 808 9362
#              </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="elementor-column elementor-col-25 elementor-top-column elementor-element elementor-element-6bf184d" data-element_type="column" data-id="6bf184d">
#  <div class="elementor-widget-wrap elementor-element-populated">
#  <div class="elementor-element elementor-element-e863863 elementor-widget elementor-widget-heading" data-element_type="widget" data-id="e863863" data-widget_type="heading.default">
#  <div class="elementor-widget-container">
#  <h2 class="elementor-heading-title elementor-size-default">
#               Newsletter
#              </h2>
#  </div>
#  </div>
#  <div class="elementor-element elementor-element-25d9a05 elementor-widget elementor-widget-apus_element_mailchimp" data-element_type="widget" data-id="25d9a05" data-widget_type="apus_element_mailchimp.default">
#  <div class="elementor-widget-container">
#  <div class="widget-mailchimp widget no-margin">
#  <script defer="" src="...">
#  </script>
#  <form class="mc4wp-form mc4wp-form-74" data-id="74" data-name="Download Report" id="mc4wp-form-1" method="post">
#  <div class="mc4wp-form-fields">
#  <div class="flex">
#  <input name="EMAIL" placeholder="Your email" required="" type="email"/>
#  <span class="ali-right">
#  <button class="btn-submit" type="submit">
#  <i class="flaticon-next">
#  </i>
#  </button>
#  </span>
#  </div>
#  </div>
#  <label style="display: none !important;">
#                 Leave this field empty if you're human:
#                 <input autocomplete="off" name="_mc4wp_honeypot" tabindex="-1" type="text" value=""/>
#  </label>
#  <input name="_mc4wp_timestamp" type="hidden" value="1763026543"/>
#  <input name="_mc4wp_form_id" type="hidden" value="74"/>
#  <input name="_mc4wp_form_element_id" type="hidden" value="mc4wp-form-1"/>
#  <div class="mc4wp-response">
#  </div>
#  </form>
#  </div>
#  </div>
#  </div>
#  <div class="elementor-element elementor-element-69b5332 elementor-widget elementor-widget-apus_element_social_links" data-element_type="widget" data-id="69b5332" data-widget_type="apus_element_social_links.default">
#  <div class="elementor-widget-container">
#  <div class="widget-socials widget no-margin">
#  <h2 class="widget-title">
#                Follow us
#               </h2>
#  <ul class="social list-inline">
#  <li>
#  <a href="https://www.facebook.com/cwrelagos/" target="_blank">
#  <i class="fab fa-facebook-f">
#  </i>
#  </a>
#  </li>
#  <li>
#  <a href="https://www.instagram.com/cwrelagos/" target="_blank">
#  <i class="fab fa-instagram">
#  </i>
#  </a>
#  </li>
#  <li>
#  <a href="https://twitter.com/cwrelagos" target="_blank">
#  <i class="fab fa-twitter">
#  </i>
#  </a>
#  </li>
#  <li>
#  <a href="https://www.tiktok.com/@cwrelagos" target="_blank">
#  <i class="fab fa-tiktok">
#  </i>
#  </a>
#  </li>
#  <li>
#  <a href="https://www.linkedin.com/company/cwre-lagos" target="_blank">
#  <i class="fab fa-linkedin">
#  </i>
#  </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </section>,
#  <section class="elementor-section elementor-top-section elementor-element elementor-element-3a40404 elementor-section-stretched elementor-section-content-middle elementor-section-boxed elementor-section-height-default elementor-section-height-default" data-element_type="section" data-id="3a40404" data-settings='{"stretch_section":"section-stretched","background_background":"classic"}'>
#  <div class="elementor-container elementor-column-gap-extended">
#  <div class="elementor-column elementor-col-50 elementor-top-column elementor-element elementor-element-5b4698f" data-element_type="column" data-id="5b4698f">
#  <div class="elementor-widget-wrap elementor-element-populated">
#  <div class="elementor-element elementor-element-b639d99 elementor-widget elementor-widget-apus_element_nav_menu" data-element_type="widget" data-id="b639d99" data-widget_type="apus_element_nav_menu.default">
#  <div class="elementor-widget-container">
#  <div class="widget-nav-menu no-margin widget st_line">
#  <div class="widget-content">
#  <div class="menu-copyright-container">
#  <ul class="menu" id="menu-copyright">
#  <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-79" id="menu-item-79">
#  <a href="https://cwlagos.com/privacy-policy/" rel="privacy-policy">
#                    Privacy Policy
#                   </a>
#  </li>
#  <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-80" id="menu-item-80">
#  <a href="#">
#                    Sitemap
#                   </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="elementor-column elementor-col-50 elementor-top-column elementor-element elementor-element-e0b27cb" data-element_type="column" data-id="e0b27cb">
#  <div class="elementor-widget-wrap elementor-element-populated">
#  <div class="elementor-element elementor-element-8c1de1c elementor-widget elementor-widget-heading" data-element_type="widget" data-id="8c1de1c" data-widget_type="heading.default">
#  <div class="elementor-widget-container">
#  <div class="elementor-heading-title elementor-size-default">
#               © 2022 CW Real Estate. All rights reserved.
#              </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </section>]

# %%
len(list(loaded_soup.children))
# Out:
# 5

# %%
len(list(loaded_soup.descendants))
# Out:
# 4637

# %%
len(list(loaded_soup.section.descendants))
# Out:
# 455

# %%
loaded_soup.find_all('section')
# Out:
# [<section class="elementor-section elementor-top-section elementor-element elementor-element-b0d1715 elementor-section-content-middle elementor-section-boxed elementor-section-height-default elementor-section-height-default" data-element_type="section" data-id="b0d1715" data-settings='{"background_background":"classic"}'>
#  <div class="elementor-container elementor-column-gap-default">
#  <div class="elementor-column elementor-col-50 elementor-top-column elementor-element elementor-element-c0ddf24" data-element_type="column" data-id="c0ddf24">
#  <div class="elementor-widget-wrap elementor-element-populated">
#  <div class="elementor-element elementor-element-42f998e elementor-widget elementor-widget-apus_element_logo" data-element_type="widget" data-id="42f998e" data-widget_type="apus_element_logo.default">
#  <div class="elementor-widget-container">
#  <div class="logo">
#  <a href="https://cwlagos.com/">
#  <span class="logo-main">
#  <img alt="" class="attachment-full size-full wp-image-14442" decoding="async" fetchpriority="high" height="348" src="https://cwlagos.com/wp-content/uploads/2022/01/Website-Logo.svg" width="1293"/>
#  </span>
#  </a>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="elementor-column elementor-col-50 elementor-top-column elementor-element elementor-element-bafb47f" data-element_type="column" data-id="bafb47f">
#  <div class="elementor-widget-wrap elementor-element-populated">
#  <div class="elementor-element elementor-element-df9c6b1 elementor-widget__width-auto elementor-widget elementor-widget-apus_element_primary_menu" data-element_type="widget" data-id="df9c6b1" data-widget_type="apus_element_primary_menu.default">
#  <div class="elementor-widget-container">
#  <div class="main-menu">
#  <nav class="apus-megamenu slide animate navbar" data-duration="400" role="navigation">
#  <div class="collapse navbar-collapse no-padding">
#  <ul class="nav navbar-nav megamenu effect2" id="primary-menu">
#  <li class="dropdown menu-item-3206 aligned-left">
#  <a class="dropdown-toggle" data-hover="dropdown" data-toggle="dropdown" href="https://cwlagos.com/">
#                   Cities
#                   <b class="caret">
#  </b>
#  </a>
#  <ul class="dropdown-menu">
#  <li class="menu-item-13142 aligned-left">
#  <a href="http://cwlagos.com">
#                     Lagos
#                    </a>
#  </li>
#  <li class="menu-item-29058 aligned-left">
#  <a href="https://cwlagos.com/cwre-dubai-offer/" target="_blank">
#                     Dubai
#                    </a>
#  </li>
#  <li class="menu-item-13140 aligned-left">
#  <a href="http://theresidenceabuja.com/" target="_blank">
#                     Abuja
#                    </a>
#  </li>
#  <li class="menu-item-13141 aligned-left">
#  <a href="#">
#                     Ghana (Coming Soon)
#                    </a>
#  </li>
#  </ul>
#  </li>
#  <li class="dropdown menu-item-3207 aligned-left">
#  <a class="dropdown-toggle" data-hover="dropdown" data-toggle="dropdown" href="https://cwlagos.com/about/">
#                   About
#                   <b class="caret">
#  </b>
#  </a>
#  <ul class="dropdown-menu">
#  <li class="menu-item-3296 aligned-left">
#  <a href="https://cwlagos.com/meet-our-team/">
#                     Meet Our Team
#                    </a>
#  </li>
#  <li class="menu-item-3297 aligned-left">
#  <a href="#">
#                     Awards
#                    </a>
#  </li>
#  </ul>
#  </li>
#  <li class="menu-item-3209 aligned-left">
#  <a href="https://cwlagos.com/listings/">
#                   Listings
#                  </a>
#  </li>
#  <li class="menu-item-8630 aligned-left">
#  <a href="https://shortstays.cwlagos.com" target="_blank">
#                   Short Stays
#                  </a>
#  </li>
#  <li class="menu-item-3210 aligned-left">
#  <a href="https://cwlagos.com/new-development/">
#                   New Developments
#                  </a>
#  </li>
#  <li class="menu-item-3211 aligned-left">
#  <a href="https://cwlagos.com/blog/">
#                   Blog
#                  </a>
#  </li>
#  <li class="menu-item-3212 aligned-left">
#  <a href="https://cwlagos.com/contact/">
#                   Contact us
#                  </a>
#  </li>
#  </ul>
#  </div>
#  </nav>
#  </div>
#  </div>
#  </div>
#  <div class="elementor-element elementor-element-e1a7e2b elementor-widget__width-auto elementor-hidden-desktop elementor-hidden-tablet elementor-hidden-mobile elementor-widget elementor-widget-apus_element_user_info" data-element_type="widget" data-id="e1a7e2b" data-widget_type="apus_element_user_info.default">
#  <div class="elementor-widget-container">
#  <div class="top-wrapper-menu not-login">
#  <span class="login-icon">
#  <i class="flaticon-user">
#  </i>
#  </span>
#  <a class="btn-login apus-user-login" href="#apus_login_forgot_form" title="Login">
#               Login
#              </a>
#  <span class="space text-link">
#               /
#              </span>
#  <a class="btn-login register apus-user-register" href="#apus_register_form" title="Register">
#               Register
#              </a>
#  <div class="apus_login_register_form mfp-hide" data-effect="fadeIn" id="apus_login_forgot_form">
#  <div class="form-login-register-inner">
#  <div class="row">
#  <div class="col-sm-6 hidden-xs banner-image">
#  <div class="image-wrapper">
#  <img alt="" class="attachment-full size-full unveil-image" data-sizes="(max-width: 390px) 100vw, 390px" data-src="https://cwlagos.com/wp-content/uploads/2020/02/bg-login.jpg" data-srcset="https://cwlagos.com/wp-content/uploads/2020/02/bg-login.jpg 390w, https://cwlagos.com/wp-content/uploads/2020/02/bg-login-217x300.jpg 217w" height="540" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 390 540'%2F%3E" width="390"/>
#  </div>
#  </div>
#  <div class="col-sm-6 col-xs-12">
#  <div class="inner-right">
#  <h3 class="title">
#                    Login
#                   </h3>
#  <div class="login-form-wrapper">
#  <div class="form-container box-white-dashboard form-login-register-inner" id="login-form-wrapper">
#  <form action="https://cwlagos.com/" class="login-form" method="post">
#  <div class="wrapper-social-login">
#  <div class="inner-social">
#  <div class="facebook-login-btn-wrapper">
#  <a class="facebook-login-btn" href="https://www.facebook.com/v2.10/dialog/oauth?client_id=1&amp;state=43addc8a56c91eeabf7fc60447169cb9&amp;response_type=code&amp;sdk=php-sdk-5.6.1&amp;redirect_uri=https%3A%2F%2Fcwlagos.com%2Fwp-admin%2Fadmin-ajax.php%3Faction%3Dwp_realestate_facebook_login&amp;scope=email">
#  <i class="fab fa-facebook-f">
#  </i>
#  <span>
#                           Login with Facebook
#                          </span>
#  </a>
#  </div>
#  <div class="google-login-btn-wrapper">
#  <a class="google-login-btn" href="https://accounts.google.com/o/oauth2/auth?response_type=code&amp;redirect_uri=https%3A%2F%2Fcwlagos.com%2F&amp;client_id=1&amp;scope=email&amp;access_type=online&amp;approval_prompt=auto">
#  <i class="fab fa-google">
#  </i>
#  <span>
#                           Login with Google
#                          </span>
#  </a>
#  </div>
#  <div class="line-header">
#  <span>
#                          or
#                         </span>
#  </div>
#  </div>
#  </div>
#  <div class="form-group">
#  <i class="flaticon-user">
#  </i>
#  <label class="hidden" for="username_or_email">
#                        Username Or Email
#                       </label>
#  <sup class="required-field">
#                        *
#                       </sup>
#  <input autocomplete="off" class="form-control" id="username_or_email" name="username" placeholder="Enter username or email" type="text"/>
#  </div>
#  <div class="form-group">
#  <i class="flaticon-password">
#  </i>
#  <label class="hidden" for="login_password">
#                        Password
#                       </label>
#  <sup class="required-field">
#                        *
#                       </sup>
#  <input class="password required form-control" id="login_password" name="password" placeholder="Enter Password" type="password"/>
#  </div>
#  <div class="row space-15">
#  <div class="col-sm-6">
#  <label for="user-remember-field">
#  <input id="user-remember-field" name="remember" type="checkbox" value="true"/>
#                         Keep me signed in
#                        </label>
#  </div>
#  <div class="col-sm-6 text-right">
#  <a class="back-link" href="#forgot-password-form-wrapper" title="Forgot Password">
#                         Lost Your Password?
#                        </a>
#  </div>
#  </div>
#  <div class="form-group no-margin">
#  <input class="btn btn-theme btn-block" name="submit" type="submit" value="Login"/>
#  <div class="register-info">
#                         Don't you have an account?
#                         <a class="apus-user-register" href="#apus_register_form">
#                          Register
#                         </a>
#  </div>
#  </div>
#  <input id="security_login" name="security_login" type="hidden" value="8f3854784d"/>
#  <input name="_wp_http_referer" type="hidden" value="/property-location/ikoyi/"/>
#  </form>
#  </div>
#  <div class="form-container" id="forgot-password-form-wrapper">
#  <form action="https://cwlagos.com/secure-login/?action=lostpassword" class="forgotpassword-form" method="post" name="forgotpasswordform">
#  <h3>
#                       Reset Password
#                      </h3>
#  <div class="lostpassword-fields">
#  <div class="form-group">
#  <label for="lostpassword_username">
#                         Username or E-mail
#                        </label>
#  <sup class="required-field">
#                         *
#                        </sup>
#  <input class="user_login form-control" id="lostpassword_username" name="user_login" placeholder="Enter Username or E-mail" type="text"/>
#  </div>
#  <input id="security_lostpassword" name="security_lostpassword" type="hidden" value="1da962d83d"/>
#  <input name="_wp_http_referer" type="hidden" value="/property-location/ikoyi/"/>
#  <div class="form-group">
#  <input class="btn btn-theme btn-block" name="wp-submit" tabindex="100" type="submit" value="Get New Password"/>
#  <input class="btn btn-danger btn-block btn-cancel" tabindex="101" type="button" value="Cancel"/>
#  </div>
#  </div>
#  <div class="lostpassword-link">
#  <a class="back-link" href="#login-form-wrapper">
#                        Back To Login
#                       </a>
#  </div>
#  </form>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="apus_login_register_form mfp-hide" data-effect="fadeIn" id="apus_register_form">
#  <div class="form-login-register-inner">
#  <div class="row">
#  <div class="col-sm-6 hidden-xs banner-image">
#  <div class="image-wrapper">
#  <img alt="" class="attachment-full size-full unveil-image" data-sizes="(max-width: 390px) 100vw, 390px" data-src="https://cwlagos.com/wp-content/uploads/2020/02/bg-register.jpg" data-srcset="https://cwlagos.com/wp-content/uploads/2020/02/bg-register.jpg 390w, https://cwlagos.com/wp-content/uploads/2020/02/bg-register-177x300.jpg 177w" height="660" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 390 660'%2F%3E" width="390"/>
#  </div>
#  </div>
#  <div class="col-sm-6 col-xs-12">
#  <div class="inner-right">
#  <h3 class="title">
#                    Register
#                   </h3>
#  <div class="register-form-wrapper">
#  <div class="container-form">
#  <form class="register-form box-white-dashboard form-login-register-inner" method="post" name="registerForm">
#  <div class="form-group">
#  <i class="flaticon-user">
#  </i>
#  <input class="form-control" id="register-username" name="username" placeholder="User Name" type="text"/>
#  </div>
#  <div class="form-group">
#  <i class="flaticon-envelope">
#  </i>
#  <input class="form-control" id="register-email" name="email" placeholder="Email" type="text"/>
#  </div>
#  <div class="form-group">
#  <i class="flaticon-password">
#  </i>
#  <input class="form-control" id="password" name="password" placeholder="Password" type="password"/>
#  </div>
#  <div class="form-group">
#  <i class="flaticon-password">
#  </i>
#  <input class="form-control" id="confirmpassword" name="confirmpassword" placeholder="Re-enter Password" type="password"/>
#  </div>
#  <div class="form-group">
#  <i class="flaticon-user-1">
#  </i>
#  <select class="form-control" name="role">
#  <option value="">
#                         Select Role
#                        </option>
#  <option value="subscriber">
#                         User
#                        </option>
#  <option value="wp_realestate_agent">
#                         Agent
#                        </option>
#  <option value="wp_realestate_agency">
#                         Agency
#                        </option>
#  </select>
#  </div>
#  <input id="security_register" name="security_register" type="hidden" value="d3da6b20df"/>
#  <input name="_wp_http_referer" type="hidden" value="/property-location/ikoyi/"/>
#  <div class="form-group no-margin">
#  <button class="btn btn-theme btn-block" name="submitRegister" type="submit">
#                          Sign Up
#                         </button>
#  </div>
#  </form>
#  <div class="login-info">
#                      Already have an account?
#                      <a class="apus-user-login" href="#apus_login_forgot_form">
#                       Login
#                      </a>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="elementor-element elementor-element-979f336 elementor-widget__width-auto elementor-hidden-desktop elementor-hidden-tablet elementor-hidden-mobile elementor-widget elementor-widget-apus_element_submit_btn" data-element_type="widget" data-id="979f336" data-widget_type="apus_element_submit_btn.default">
#  <div class="elementor-widget-container">
#  <div class="widget-submit-btn">
#  <a class="btn-submit btn user-login-form" href="https://cwlagos.com/submission/">
#  <span class="flaticon-plus button-icon">
#  </span>
#               Submit Property
#              </a>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </section>,
#  <section class="inner layout-type-default" id="main-container">
#  <section class="breadcrumb-page apus-breadscrumb vertical" id="apus-breadscrumb">
#  <div class="container">
#  <div class="wrapper-breads flex-middle-sm">
#  <div class="wrapper-breads-inner">
#  <div class="left-inner">
#  <ol class="breadcrumb">
#  <li>
#  <a href="https://cwlagos.com">
#               Home
#              </a>
#  </li>
#  <li>
#  <a href="https://cwlagos.com/property-location/ikoyi/">
#               Properties
#              </a>
#  </li>
#  <li>
#  <span class="active">
#               ikoyi
#              </span>
#  </li>
#  </ol>
#  </div>
#  <div class="breadscrumb-inner clearfix">
#  <h2 class="bread-title">
#             ikoyi
#            </h2>
#  </div>
#  </div>
#  <div class="ali-right">
#  <div class="flex-middle">
#  <div class="saved-search-form-btn">
#  <a class="btn-saved-search" href="#saved-search-form-btn-wrapper">
#  <i class="flaticon-heart">
#  </i>
#              Save Search
#             </a>
#  </div>
#  <div class="saved-search-form-wrapper mfp-hide" data-effect="fadeIn" id="saved-search-form-btn-wrapper">
#  <form action="" class="saved-search-form" method="get">
#  <div class="form-group">
#  <label for="saved_search_title">
#                Title
#               </label>
#  <input class="form-control" id="saved_search_title" name="name" placeholder="Title" type="text"/>
#  </div>
#  <div class="form-group">
#  <label for="saved_search_email_frequency">
#                Email Frequency
#               </label>
#  <div class="wrapper-select">
#  <select class="form-control" id="saved_search_email_frequency" name="email_frequency">
#  <option value="daily">
#                  Daily
#                 </option>
#  <option value="weekly">
#                  Weekly
#                 </option>
#  <option value="fortnightly">
#                  Fortnightly
#                 </option>
#  <option value="monthly">
#                  Monthly
#                 </option>
#  <option value="biannually">
#                  Biannually
#                 </option>
#  <option value="annually">
#                  Annually
#                 </option>
#  </select>
#  </div>
#  </div>
#  <input id="nonce" name="nonce" type="hidden" value="407535f681"/>
#  <input name="_wp_http_referer" type="hidden" value="/property-location/ikoyi/"/>
#  <div class="form-group no-margin">
#  <button class="button btn btn-theme">
#                  Save
#                 </button>
#  </div>
#  </form>
#  </div>
#  <div class="properties-display-mode-wrapper">
#  <form action="https://cwlagos.com/property-location/ikoyi/" class="properties-display-mode" method="get">
#  <div class="inner">
#  <label for="filter-display-mode-grid">
#  <input checked="checked" id="filter-display-mode-grid" name="filter-display-mode" type="radio" value="grid"/>
#  <i class="flaticon-menu">
#  </i>
#  </label>
#  <label for="filter-display-mode-list">
#  <input id="filter-display-mode-list" name="filter-display-mode" type="radio" value="list"/>
#  <i class="flaticon-menu-1">
#  </i>
#  </label>
#  </div>
#  </form>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </section>
#  <div class="main-content container inner">
#  <a class="mobile-sidebar-btn hidden-lg hidden-md btn-right" href="javascript:void(0)">
#  <i class="ti-menu-alt">
#  </i>
#  </a>
#  <div class="mobile-sidebar-panel-overlay">
#  </div>
#  <div class="row">
#  <div class="col-sm-12 col-md-8 col-lg-8 col-sm-12 col-xs-12" id="main-content">
#  <main class="site-main layout-type-default" id="main" role="main">
#  <div class="properties-listing-wrapper main-items-wrapper" data-display_mode="grid">
#  <div class="properties-ordering-wrapper">
#  <div class="results-count">
#              Showing
#              <span class="first">
#               1
#              </span>
#              –
#              <span class="last">
#               15
#              </span>
#              of 367 results
#             </div>
#  <div class="properties-ordering">
#  <form action="https://cwlagos.com/property-location/ikoyi/" class="properties-ordering" method="get">
#  <div class="label">
#                Sort by:
#               </div>
#  <select class="orderby" data-placeholder="Sort by" name="filter-orderby">
#  <option selected="selected" value="menu_order">
#                 Default
#                </option>
#  <option value="newest">
#                 Newest
#                </option>
#  <option value="oldest">
#                 Oldest
#                </option>
#  <option value="price-lowest">
#                 Lowest Price
#                </option>
#  <option value="price-highest">
#                 Highest Price
#                </option>
#  <option value="random">
#                 Random
#                </option>
#  </select>
#  <input name="paged" type="hidden" value="1"/>
#  </form>
#  </div>
#  </div>
#  <div class="properties-wrapper items-wrapper clearfix">
#  <div class="row">
#  <div class="col-sm-6 col-md-4 col-ct-12 col-xs-12 lg-clearfix md-clearfix sm-clearfix">
#  <article class="map-item property-grid property-item post-86590 property type-property status-publish has-post-thumbnail hentry property_type-maisonette property_location-ikoyi property_location-old-ikoyi property_status-for-rent property_label-available-for-rent" data-images='["https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/07\/Untitled-design-31-2-850x550.png","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/07\/WhatsApp-Image-2025-07-17-at-18.17.32_fc21f349-810x550.jpg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/07\/WhatsApp-Image-2025-07-17-at-18.17.33_65469cbc-810x550.jpg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/07\/WhatsApp-Image-2025-07-17-at-18.17.33_b626ba97-810x550.jpg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/07\/WhatsApp-Image-2025-07-17-at-18.17.34_153770b9-810x550.jpg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/07\/WhatsApp-Image-2025-07-17-at-18.17.34_f43f614b-810x550.jpg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/07\/WhatsApp-Image-2025-07-17-at-18.17.35_2d868fc5-810x550.jpg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/07\/WhatsApp-Image-2025-07-17-at-18.17.35_3abfb231-810x550.jpg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/07\/WhatsApp-Image-2025-07-17-at-18.17.36_68cd999f-810x550.jpg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/07\/WhatsApp-Image-2025-07-17-at-18.17.36_85b118a2-810x550.jpg"]' data-img="https://cwlagos.com/wp-content/uploads/2025/07/Untitled-design-31-2-850x550.png" data-latitude="" data-longitude="">
#  <div class="top-info">
#  <div class="property-thumbnail-wrapper flex-middle justify-content-center">
#  <div class="image-thumbnail">
#  <a class="property-image" href="https://cwlagos.com/property/2-bedroom-maisonette-bq-in-ikoyi/">
#  <div class="image-wrapper">
#  <img alt="" class="attachment-homeo-property-grid size-homeo-property-grid unveil-image" data-src="https://cwlagos.com/wp-content/uploads/2025/07/Untitled-design-31-2-850x550.png" height="550" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 850 550'%2F%3E" width="850"/>
#  </div>
#  </a>
#  </div>
#  <div class="top-label">
#  <a class="status-property-label" href="https://cwlagos.com/property-status/for-rent/" style="">
#                    For Rent
#                   </a>
#  <span class="featured-property">
#                    Featured
#                   </span>
#  <a class="label-property-label" href="https://cwlagos.com/property-label/available-for-rent/" style="">
#                    Available for rent
#                   </a>
#  </div>
#  <div class="bottom-label flex-middle">
#  <div class="property-price">
#  <span class="suffix">
#                     NGN
#                    </span>
#  <span class="price-text">
#                     35,000,000
#                    </span>
#  </div>
#  <div class="ali-right">
#  <a class="btn-add-property-favorite" data-nonce="db292f5b35" data-property_id="86590" data-toggle="tooltip" href="javascript:void(0)" title="Add Favorite">
#  <i class="flaticon-heart">
#  </i>
#  </a>
#  <a class="btn-add-property-compare" data-nonce="c27294dbde" data-property_id="86590" data-toggle="tooltip" href="javascript:void(0)" title="Add Compare">
#  <i class="flaticon-transfer-1">
#  </i>
#  </a>
#  </div>
#  </div>
#  </div>
#  <div class="property-information">
#  <div class="property-type">
#  <div class="property-type with-no-title">
#  <a class="type-property" href="https://cwlagos.com/property-type/maisonette/" style="">
#                     Maisonette
#                    </a>
#  </div>
#  </div>
#  <h2 class="property-title">
#  <a href="https://cwlagos.com/property/2-bedroom-maisonette-bq-in-ikoyi/" rel="bookmark">
#                    2 Bedroom Maisonette + BQ in Ikoyi
#                   </a>
#  </h2>
#  <div class="property-location with-icon">
#  <i class="flaticon-maps-and-flags">
#  </i>
#  <a href="//maps.google.com/maps?q=Ikoyi&amp;zoom=14&amp;size=512x512&amp;maptype=roadmap&amp;sensor=false" target="_blank">
#                    Ikoyi
#                   </a>
#  </div>
#  <div class="property-metas flex-middle flex-wrap">
#  <div class="property-meta with-icon-title">
#  <div class="property-meta">
#  <span class="title-meta">
#                      Beds:
#                     </span>
#                     2
#                    </div>
#  </div>
#  <div class="property-meta with-icon-title">
#  <div class="property-meta">
#  <span class="title-meta">
#                      Baths:
#                     </span>
#                     2
#                    </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="property-metas-bottom flex-middle">
#  <div class="avatar-wrapper flex-middle">
#  <div class="avatar-img">
#  <img alt="" class="avatar avatar-80 photo" decoding="async" height="80" src="https://cwlagos.com/wp-content/litespeed/avatar/2febfac1abd2c64e29ecbd5fa4e1f537.jpg?ver=1762990271" srcset="https://cwlagos.com/wp-content/litespeed/avatar/daabec60c064015bab133694a2557064.jpg?ver=1762990282 2x" width="80"/>
#  </div>
#  <div class="name-author">
#                   admin-cw
#                  </div>
#  </div>
#  <div class="ali-right">
#  <div class="property-postdate">
#                   4 months ago
#                  </div>
#  </div>
#  </div>
#  </article>
#  </div>
#  <div class="col-sm-6 col-md-4 col-ct-12 col-xs-12">
#  <article class="map-item property-grid property-item post-81041 property type-property status-publish has-post-thumbnail hentry property_type-apartment property_location-ikoyi property_status-for-rent property_label-available-for-rent property_amenity-24hrs-power property_amenity-30kva-generator property_amenity-5kva-inverter property_amenity-balcony property_amenity-bq property_amenity-car-park property_amenity-cctv property_amenity-children-playground property_amenity-fitted-bathrooms property_amenity-fitted-kitchen property_amenity-fully-furnished property_amenity-gated-estate property_amenity-gym property_amenity-home-automation property_amenity-home-entertainment-unit property_amenity-jacuzzi property_amenity-maids-room property_amenity-rooftop-terrace property_amenity-swimming-pool property_amenity-walk-in-closet property_amenity-wifi property_material-brick property_material-concrete property_material-marble property_material-wood" data-images='["https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/Group-2-1-3-850x550.png","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/Group-2-1-3-850x550.png","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/Group-2-66-850x550.png","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-19-at-11.46.22-2-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-19-at-11.46.22-1-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-19-at-11.46.22-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-19-at-11.46.21-1-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-19-at-11.46.21-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-19-at-11.46.20-1-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-19-at-11.46.20-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-19-at-11.46.19-1-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-19-at-11.46.19-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-19-at-11.46.18-1-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-19-at-11.46.18-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-19-at-11.46.17-1-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-19-at-11.46.17-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-19-at-11.46.16-1-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-19-at-11.46.16-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-19-at-11.46.15-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-19-at-11.45.49-850x550.jpeg"]' data-img="https://cwlagos.com/wp-content/uploads/2025/03/Group-2-1-3-850x550.png" data-latitude="6.4523431" data-longitude="3.4280523">
#  <div class="top-info">
#  <div class="property-thumbnail-wrapper flex-middle justify-content-center">
#  <div class="image-thumbnail">
#  <a class="property-image" href="https://cwlagos.com/property/4-bedroom-furnished-apartment-bq/">
#  <div class="image-wrapper">
#  <img alt="" class="attachment-homeo-property-grid size-homeo-property-grid unveil-image" data-src="https://cwlagos.com/wp-content/uploads/2025/03/Group-2-1-3-850x550.png" height="550" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 850 550'%2F%3E" width="850"/>
#  </div>
#  </a>
#  </div>
#  <div class="top-label">
#  <a class="status-property-label" href="https://cwlagos.com/property-status/for-rent/" style="">
#                    For Rent
#                   </a>
#  <span class="featured-property">
#                    Featured
#                   </span>
#  <a class="label-property-label" href="https://cwlagos.com/property-label/available-for-rent/" style="">
#                    Available for rent
#                   </a>
#  </div>
#  <div class="bottom-label flex-middle">
#  <div class="property-price">
#                    #35,000,000
#                   </div>
#  <div class="ali-right">
#  <a class="btn-add-property-favorite" data-nonce="db292f5b35" data-property_id="81041" data-toggle="tooltip" href="javascript:void(0)" title="Add Favorite">
#  <i class="flaticon-heart">
#  </i>
#  </a>
#  <a class="btn-add-property-compare" data-nonce="c27294dbde" data-property_id="81041" data-toggle="tooltip" href="javascript:void(0)" title="Add Compare">
#  <i class="flaticon-transfer-1">
#  </i>
#  </a>
#  </div>
#  </div>
#  </div>
#  <div class="property-information">
#  <div class="property-type">
#  <div class="property-type with-no-title">
#  <a class="type-property" href="https://cwlagos.com/property-type/apartment/" style="">
#                     Apartment
#                    </a>
#  </div>
#  </div>
#  <h2 class="property-title">
#  <a href="https://cwlagos.com/property/4-bedroom-furnished-apartment-bq/" rel="bookmark">
#                    4 Bedroom Furnished Apartment + BQ
#                   </a>
#  </h2>
#  <div class="property-location with-icon">
#  <i class="flaticon-maps-and-flags">
#  </i>
#  <a href="//maps.google.com/maps?q=Ikoyi%2C+Lagos.&amp;zoom=14&amp;size=512x512&amp;maptype=roadmap&amp;sensor=false" target="_blank">
#                    Ikoyi, Lagos.
#                   </a>
#  </div>
#  <div class="property-metas flex-middle flex-wrap">
#  <div class="property-meta with-icon-title">
#  <div class="property-meta">
#  <span class="title-meta">
#                      Beds:
#                     </span>
#                     4
#                    </div>
#  </div>
#  <div class="property-meta with-icon-title">
#  <div class="property-meta">
#  <span class="title-meta">
#                      Baths:
#                     </span>
#                     4
#                    </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="property-metas-bottom flex-middle">
#  <div class="avatar-wrapper flex-middle">
#  <div class="avatar-img">
#  <img alt="" class="avatar avatar-80 photo" decoding="async" height="80" src="https://cwlagos.com/wp-content/litespeed/avatar/2febfac1abd2c64e29ecbd5fa4e1f537.jpg?ver=1762990271" srcset="https://cwlagos.com/wp-content/litespeed/avatar/daabec60c064015bab133694a2557064.jpg?ver=1762990282 2x" width="80"/>
#  </div>
#  <div class="name-author">
#                   admin-cw
#                  </div>
#  </div>
#  <div class="ali-right">
#  <div class="property-postdate">
#                   8 months ago
#                  </div>
#  </div>
#  </div>
#  </article>
#  </div>
#  <div class="col-sm-6 col-md-4 col-ct-12 col-xs-12 sm-clearfix">
#  <article class="map-item property-grid property-item post-80951 property type-property status-publish has-post-thumbnail hentry property_type-maisonette property_location-ikoyi property_status-for-sale property_label-available-for-sale property_amenity-24hrs-power property_amenity-30kva-generator property_amenity-5kva-inverter property_amenity-balcony property_amenity-bq property_amenity-car-park property_amenity-cctv property_amenity-children-playground property_amenity-fitted-bathrooms property_amenity-fitted-kitchen property_amenity-fully-furnished property_amenity-gated-estate property_amenity-golf-course-view property_amenity-gym property_amenity-home-automation property_amenity-home-entertainment-unit property_amenity-jacuzzi property_amenity-maids-room property_amenity-private-elevator property_amenity-rooftop-terrace property_amenity-study property_amenity-swimming-pool property_amenity-walk-in-closet property_amenity-wifi property_material-brick property_material-concrete property_material-marble property_material-wood" data-images='["https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/Group-2-63-850x550.png","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/Group-2-63-850x550.png","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-26-at-07.03.20-2-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-26-at-07.03.20-1-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-26-at-07.03.20-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-26-at-07.03.19-5-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-26-at-07.03.19-4-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-26-at-07.03.19-3-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-26-at-07.03.19-2-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-26-at-07.03.19-1-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-26-at-07.03.19-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-26-at-07.03.18-850x550.jpeg"]' data-img="https://cwlagos.com/wp-content/uploads/2025/03/Group-2-63-850x550.png" data-latitude="6.456061" data-longitude="3.442218">
#  <div class="top-info">
#  <div class="property-thumbnail-wrapper flex-middle justify-content-center">
#  <div class="image-thumbnail">
#  <a class="property-image" href="https://cwlagos.com/property/luxury-3-bedroom-maisonette-with-bq/">
#  <div class="image-wrapper">
#  <img alt="" class="attachment-homeo-property-grid size-homeo-property-grid unveil-image" data-src="https://cwlagos.com/wp-content/uploads/2025/03/Group-2-63-850x550.png" height="550" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 850 550'%2F%3E" width="850"/>
#  </div>
#  </a>
#  </div>
#  <div class="top-label">
#  <a class="status-property-label" href="https://cwlagos.com/property-status/for-sale/" style="">
#                    For Sale
#                   </a>
#  <span class="featured-property">
#                    Featured
#                   </span>
#  <a class="label-property-label" href="https://cwlagos.com/property-label/available-for-sale/" style="">
#                    Available for sale
#                   </a>
#  </div>
#  <div class="bottom-label flex-middle">
#  <div class="property-price">
#                    #900,000,000
#                   </div>
#  <div class="ali-right">
#  <a class="btn-add-property-favorite" data-nonce="db292f5b35" data-property_id="80951" data-toggle="tooltip" href="javascript:void(0)" title="Add Favorite">
#  <i class="flaticon-heart">
#  </i>
#  </a>
#  <a class="btn-add-property-compare" data-nonce="c27294dbde" data-property_id="80951" data-toggle="tooltip" href="javascript:void(0)" title="Add Compare">
#  <i class="flaticon-transfer-1">
#  </i>
#  </a>
#  </div>
#  </div>
#  </div>
#  <div class="property-information">
#  <div class="property-type">
#  <div class="property-type with-no-title">
#  <a class="type-property" href="https://cwlagos.com/property-type/maisonette/" style="">
#                     Maisonette
#                    </a>
#  </div>
#  </div>
#  <h2 class="property-title">
#  <a href="https://cwlagos.com/property/luxury-3-bedroom-maisonette-with-bq/" rel="bookmark">
#                    Luxury 3 Bedroom Maisonette with BQ
#                   </a>
#  </h2>
#  <div class="property-location with-icon">
#  <i class="flaticon-maps-and-flags">
#  </i>
#  <a href="//maps.google.com/maps?q=Ikoyi%2C+Lagos.&amp;zoom=14&amp;size=512x512&amp;maptype=roadmap&amp;sensor=false" target="_blank">
#                    Ikoyi, Lagos.
#                   </a>
#  </div>
#  <div class="property-metas flex-middle flex-wrap">
#  <div class="property-meta with-icon-title">
#  <div class="property-meta">
#  <span class="title-meta">
#                      Beds:
#                     </span>
#                     3
#                    </div>
#  </div>
#  <div class="property-meta with-icon-title">
#  <div class="property-meta">
#  <span class="title-meta">
#                      Baths:
#                     </span>
#                     3
#                    </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="property-metas-bottom flex-middle">
#  <div class="avatar-wrapper flex-middle">
#  <div class="avatar-img">
#  <a href="https://cwlagos.com/agent/adeyemi-fowosire/">
#  <div class="image-wrapper">
#  <img alt="" class="attachment-thumbnail size-thumbnail unveil-image" data-src="https://cwlagos.com/wp-content/uploads/2024/12/DSC01354-150x150.jpg" height="150" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 150 150'%2F%3E" width="150"/>
#  </div>
#  </a>
#  </div>
#  <div class="name-author">
#  <a href="https://cwlagos.com/agent/adeyemi-fowosire/">
#                    Adeyemi Fowosire
#                   </a>
#  </div>
#  </div>
#  <div class="ali-right">
#  <div class="property-postdate">
#                   8 months ago
#                  </div>
#  </div>
#  </div>
#  </article>
#  </div>
#  <div class="col-sm-6 col-md-4 col-ct-12 col-xs-12 lg-clearfix md-clearfix">
#  <article class="map-item property-grid property-item post-80854 property type-property status-publish has-post-thumbnail hentry property_type-detached property_location-banana-island-ikoyi property_location-ikoyi property_status-for-rent property_label-available-for-sale property_amenity-24hrs-power property_amenity-30kva-generator property_amenity-5kva-inverter property_amenity-balcony property_amenity-bq property_amenity-car-park property_amenity-cctv property_amenity-children-playground property_amenity-cinema property_amenity-fitted-bathrooms property_amenity-fitted-kitchen property_amenity-garden property_amenity-gated-estate property_amenity-gym property_amenity-home-automation property_amenity-home-entertainment-unit property_amenity-jacuzzi property_amenity-maids-room property_amenity-rooftop-terrace property_amenity-study property_amenity-swimming-pool property_amenity-walk-in-closet property_amenity-wifi property_material-brick property_material-concrete property_material-marble property_material-wood" data-images='["https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/Group-2-59-850x550.png","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/Group-2-59-850x550.png","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-24-at-06.04.26-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-24-at-06.04.25-1-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-24-at-06.04.25-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-24-at-06.04.22-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-24-at-06.04.21-1-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-24-at-06.04.21-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-24-at-06.04.19-1-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-24-at-06.04.19-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-24-at-06.04.18-2-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-24-at-06.04.18-1-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-24-at-06.04.18-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-24-at-06.04.17-2-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-24-at-06.04.17-1-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-24-at-06.04.17-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-24-at-06.04.16-1-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-24-at-06.04.16-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-24-at-06.04.14-850x550.jpeg"]' data-img="https://cwlagos.com/wp-content/uploads/2025/03/Group-2-59-850x550.png" data-latitude="6.4629584" data-longitude="3.4570214">
#  <div class="top-info">
#  <div class="property-thumbnail-wrapper flex-middle justify-content-center">
#  <div class="image-thumbnail">
#  <a class="property-image" href="https://cwlagos.com/property/luxury-5-bedroom-detached-house-with-en-suite-bq/">
#  <div class="image-wrapper">
#  <img alt="" class="attachment-homeo-property-grid size-homeo-property-grid unveil-image" data-src="https://cwlagos.com/wp-content/uploads/2025/03/Group-2-59-850x550.png" height="550" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 850 550'%2F%3E" width="850"/>
#  </div>
#  </a>
#  </div>
#  <div class="top-label">
#  <a class="status-property-label" href="https://cwlagos.com/property-status/for-rent/" style="">
#                    For Rent
#                   </a>
#  <span class="featured-property">
#                    Featured
#                   </span>
#  <a class="label-property-label" href="https://cwlagos.com/property-label/available-for-sale/" style="">
#                    Available for sale
#                   </a>
#  </div>
#  <div class="bottom-label flex-middle">
#  <div class="property-price">
#                    N100,000,000
#                   </div>
#  <div class="ali-right">
#  <a class="btn-add-property-favorite" data-nonce="db292f5b35" data-property_id="80854" data-toggle="tooltip" href="javascript:void(0)" title="Add Favorite">
#  <i class="flaticon-heart">
#  </i>
#  </a>
#  <a class="btn-add-property-compare" data-nonce="c27294dbde" data-property_id="80854" data-toggle="tooltip" href="javascript:void(0)" title="Add Compare">
#  <i class="flaticon-transfer-1">
#  </i>
#  </a>
#  </div>
#  </div>
#  </div>
#  <div class="property-information">
#  <div class="property-type">
#  <div class="property-type with-no-title">
#  <a class="type-property" href="https://cwlagos.com/property-type/detached/" style="">
#                     Detached
#                    </a>
#  </div>
#  </div>
#  <h2 class="property-title">
#  <a href="https://cwlagos.com/property/luxury-5-bedroom-detached-house-with-en-suite-bq/" rel="bookmark">
#                    Luxury 5 Bedroom Detached House
#                   </a>
#  </h2>
#  <div class="property-location with-icon">
#  <i class="flaticon-maps-and-flags">
#  </i>
#  <a href="//maps.google.com/maps?q=Banana+Island%2C+Ikoyi%2C+Lagos.&amp;zoom=14&amp;size=512x512&amp;maptype=roadmap&amp;sensor=false" target="_blank">
#                    Banana Island, Ikoyi, Lagos.
#                   </a>
#  </div>
#  <div class="property-metas flex-middle flex-wrap">
#  <div class="property-meta with-icon-title">
#  <div class="property-meta">
#  <span class="title-meta">
#                      Beds:
#                     </span>
#                     5
#                    </div>
#  </div>
#  <div class="property-meta with-icon-title">
#  <div class="property-meta">
#  <span class="title-meta">
#                      Baths:
#                     </span>
#                     5
#                    </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="property-metas-bottom flex-middle">
#  <div class="avatar-wrapper flex-middle">
#  <div class="avatar-img">
#  <a href="https://cwlagos.com/agent/adeyemi-fowosire/">
#  <div class="image-wrapper">
#  <img alt="" class="attachment-thumbnail size-thumbnail unveil-image" data-src="https://cwlagos.com/wp-content/uploads/2024/12/DSC01354-150x150.jpg" height="150" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 150 150'%2F%3E" width="150"/>
#  </div>
#  </a>
#  </div>
#  <div class="name-author">
#  <a href="https://cwlagos.com/agent/adeyemi-fowosire/">
#                    Adeyemi Fowosire
#                   </a>
#  </div>
#  </div>
#  <div class="ali-right">
#  <div class="property-postdate">
#                   8 months ago
#                  </div>
#  </div>
#  </div>
#  </article>
#  </div>
#  <div class="col-sm-6 col-md-4 col-ct-12 col-xs-12 sm-clearfix">
#  <article class="map-item property-grid property-item post-80706 property type-property status-publish has-post-thumbnail hentry property_type-maisonette property_location-ikoyi property_status-for-sale property_label-available-for-sale property_amenity-24hrs-power property_amenity-30kva-generator property_amenity-5kva-inverter property_amenity-balcony property_amenity-car-park property_amenity-cctv property_amenity-children-playground property_amenity-fitted-bathrooms property_amenity-fitted-kitchen property_amenity-fully-furnished property_amenity-garden property_amenity-gated-estate property_amenity-home-automation property_amenity-home-entertainment-unit property_amenity-jacuzzi property_amenity-private-elevator property_amenity-rooftop-terrace property_amenity-study property_amenity-swimming-pool property_amenity-walk-in-closet property_amenity-wifi property_material-brick property_material-concrete property_material-marble property_material-wood" data-images='["https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/Group-2-52-696x550.png","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/Group-2-52-696x550.png","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-18-at-09.45.28-1-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-18-at-09.45.28-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-18-at-09.45.27-4-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-18-at-09.45.27-3-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-18-at-09.45.27-2-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-18-at-09.45.27-1-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-18-at-09.45.27-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-18-at-09.45.26-2-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-18-at-09.45.26-1-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-18-at-09.45.26-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-18-at-09.45.25-1-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-18-at-09.45.25-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-18-at-09.45.24-1-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-18-at-09.45.24-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-18-at-09.45.23-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-18-at-09.45.22-1-850x550.jpeg","https:\/\/cwlagos.com\/wp-content\/uploads\/2025\/03\/WhatsApp-Image-2025-03-18-at-09.45.22-850x550.jpeg"]' data-img="https://cwlagos.com/wp-content/uploads/2025/03/Group-2-52-696x550.png" data-latitude="6.456061" data-longitude="3.442218">
#  <div class="top-info">
#  <div class="property-thumbnail-wrapper flex-middle justify-content-center">
#  <div class="image-thumbnail">
#  <a class="property-image" href="https://cwlagos.com/property/exclusive-4-bedroom-maisonette-with-swimming-pool-2/">
#  <div class="image-wrapper">
#  <img alt="" class="attachment-homeo-property-grid size-homeo-property-grid unveil-image" data-sizes="(max-width: 696px) 100vw, 696px" data-src="https://cwlagos.com/wp-content/uploads/2025/03/Group-2-52-696x550.png" data-srcset="https://cwlagos.com/wp-content/uploads/2025/03/Group-2-52-696x550.png 696w, https://cwlagos.com/wp-content/uploads/2025/03/Group-2-52-165x130.png 165w" height="550" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 696 550'%2F%3E" width="696"/>
#  </div>
#  </a>
#  </div>
#  <div class="top-label">
#  <a class="status-property-label" href="https://cwlagos.com/property-status/for-sale/" style="">
#                    For Sale
#                   </a>
#  <span class="featured-property">
#                    Featured
# ...
#                                   Gym
#                                  </label>
#  </div>
#  </li>
#  <li class="list-item level-0">
#  <div class="list-item-inner">
#  <input id="filter-amenity-home-automation-30012" name="filter-amenity[]" type="checkbox" value="118"/>
#  <label for="filter-amenity-home-automation-30012">
#                                   Home Automation
#                                  </label>
#  </div>
#  </li>
#  <li class="list-item level-0">
#  <div class="list-item-inner">
#  <input id="filter-amenity-home-entertainment-unit-30012" name="filter-amenity[]" type="checkbox" value="119"/>
#  <label for="filter-amenity-home-entertainment-unit-30012">
#                                   Home Entertainment Unit
#                                  </label>
#  </div>
#  </li>
#  <li class="list-item level-0">
#  <div class="list-item-inner">
#  <input id="filter-amenity-jacuzzi-30012" name="filter-amenity[]" type="checkbox" value="157"/>
#  <label for="filter-amenity-jacuzzi-30012">
#                                   Jacuzzi
#                                  </label>
#  </div>
#  </li>
#  <li class="list-item level-0">
#  <div class="list-item-inner">
#  <input id="filter-amenity-maids-room-30012" name="filter-amenity[]" type="checkbox" value="229"/>
#  <label for="filter-amenity-maids-room-30012">
#                                   Maid's Room
#                                  </label>
#  </div>
#  </li>
#  <li class="list-item level-0">
#  <div class="list-item-inner">
#  <input id="filter-amenity-private-cinema-30012" name="filter-amenity[]" type="checkbox" value="107"/>
#  <label for="filter-amenity-private-cinema-30012">
#                                   Private Cinema
#                                  </label>
#  </div>
#  </li>
#  <li class="list-item level-0">
#  <div class="list-item-inner">
#  <input id="filter-amenity-private-elevator-30012" name="filter-amenity[]" type="checkbox" value="113"/>
#  <label for="filter-amenity-private-elevator-30012">
#                                   Private Elevator
#                                  </label>
#  </div>
#  </li>
#  <li class="list-item level-0">
#  <div class="list-item-inner">
#  <input id="filter-amenity-rooftop-terrace-30012" name="filter-amenity[]" type="checkbox" value="114"/>
#  <label for="filter-amenity-rooftop-terrace-30012">
#                                   Rooftop Terrace
#                                  </label>
#  </div>
#  </li>
#  <li class="list-item level-0">
#  <div class="list-item-inner">
#  <input id="filter-amenity-sauna-30012" name="filter-amenity[]" type="checkbox" value="74"/>
#  <label for="filter-amenity-sauna-30012">
#                                   Sauna
#                                  </label>
#  </div>
#  </li>
#  <li class="list-item level-0">
#  <div class="list-item-inner">
#  <input id="filter-amenity-study-30012" name="filter-amenity[]" type="checkbox" value="206"/>
#  <label for="filter-amenity-study-30012">
#                                   Study
#                                  </label>
#  </div>
#  </li>
#  <li class="list-item level-0">
#  <div class="list-item-inner">
#  <input id="filter-amenity-swimming-pool-30012" name="filter-amenity[]" type="checkbox" value="77"/>
#  <label for="filter-amenity-swimming-pool-30012">
#                                   Swimming Pool
#                                  </label>
#  </div>
#  </li>
#  <li class="list-item level-0">
#  <div class="list-item-inner">
#  <input id="filter-amenity-tennis-court-30012" name="filter-amenity[]" type="checkbox" value="144"/>
#  <label for="filter-amenity-tennis-court-30012">
#                                   Tennis Court
#                                  </label>
#  </div>
#  </li>
#  <li class="list-item level-0">
#  <div class="list-item-inner">
#  <input id="filter-amenity-walk-in-closet-30012" name="filter-amenity[]" type="checkbox" value="120"/>
#  <label for="filter-amenity-walk-in-closet-30012">
#                                   Walk-in Closet
#                                  </label>
#  </div>
#  </li>
#  <li class="list-item level-0">
#  <div class="list-item-inner">
#  <input id="filter-amenity-water-front-30012" name="filter-amenity[]" type="checkbox" value="199"/>
#  <label for="filter-amenity-water-front-30012">
#                                   Water Front
#                                  </label>
#  </div>
#  </li>
#  <li class="list-item level-0">
#  <div class="list-item-inner">
#  <input id="filter-amenity-water-view-30012" name="filter-amenity[]" type="checkbox" value="121"/>
#  <label for="filter-amenity-water-view-30012">
#                                   Water View
#                                  </label>
#  </div>
#  </li>
#  <li class="list-item level-0">
#  <div class="list-item-inner">
#  <input id="filter-amenity-wifi-30012" name="filter-amenity[]" type="checkbox" value="83"/>
#  <label for="filter-amenity-wifi-30012">
#                                   WiFi
#                                  </label>
#  </div>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="row">
#  <div class="col-xs-12 col-md-12 form-group-search">
#  <button class="btn-submit btn-block btn btn-theme btn-inverse" type="submit">
#                           Find Property
#                          </button>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </form>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </section>,
#  <section class="elementor-section elementor-top-section elementor-element elementor-element-85e2edf elementor-section-stretched ftmobile elementor-section-boxed elementor-section-height-default elementor-section-height-default" data-element_type="section" data-id="85e2edf" data-settings='{"stretch_section":"section-stretched","background_background":"classic"}'>
#  <div class="elementor-container elementor-column-gap-extended">
#  <div class="elementor-column elementor-col-25 elementor-top-column elementor-element elementor-element-22e1858" data-element_type="column" data-id="22e1858">
#  <div class="elementor-widget-wrap elementor-element-populated">
#  <div class="elementor-element elementor-element-006804c elementor-widget elementor-widget-apus_element_nav_menu" data-element_type="widget" data-id="006804c" data-widget_type="apus_element_nav_menu.default">
#  <div class="elementor-widget-container">
#  <div class="widget-nav-menu no-margin widget">
#  <h2 class="widget-title">
#                Quick Links
#               </h2>
#  <div class="widget-content">
#  <div class="menu-quick-links-1-container">
#  <ul class="menu" id="menu-quick-links-1">
#  <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-5626" id="menu-item-5626">
#  <a href="#">
#                    Awards
#                   </a>
#  </li>
#  <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-5631" id="menu-item-5631">
#  <a href="https://cwlagos.com/careers/">
#                    Careers – Join Our Team
#                   </a>
#  </li>
#  <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-5628" id="menu-item-5628">
#  <a href="https://cwlagos.com/theikoyireporth1/">
#                    Market Knowledge
#                   </a>
#  </li>
#  <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-5632" id="menu-item-5632">
#  <a href="https://cwlagos.com/referral-program/">
#                    Referral Program
#                   </a>
#  </li>
#  <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-5630" id="menu-item-5630">
#  <a href="#">
#                    Press &amp; Publications
#                   </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="elementor-column elementor-col-25 elementor-top-column elementor-element elementor-element-30d9101" data-element_type="column" data-id="30d9101">
#  <div class="elementor-widget-wrap elementor-element-populated">
#  <div class="elementor-element elementor-element-e68414e elementor-widget elementor-widget-apus_element_nav_menu" data-element_type="widget" data-id="e68414e" data-widget_type="apus_element_nav_menu.default">
#  <div class="elementor-widget-container">
#  <div class="widget-nav-menu no-margin widget">
#  <h2 class="widget-title">
#  </h2>
#  <div class="widget-content">
#  <div class="menu-quick-links-2-container">
#  <ul class="menu" id="menu-quick-links-2">
#  <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-3288" id="menu-item-3288">
#  <a href="https://cwlagos.com/faq/">
#                    FAQs
#                   </a>
#  </li>
#  <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-3290" id="menu-item-3290">
#  <a href="https://cwlagos.com/agents/">
#                    Find an Agent
#                   </a>
#  </li>
#  <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-3291" id="menu-item-3291">
#  <a href="https://cwlagos.com/blog/">
#                    Our Blogs
#                   </a>
#  </li>
#  <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-3289" id="menu-item-3289">
#  <a href="#">
#                    Media
#                   </a>
#  </li>
#  <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-3293" id="menu-item-3293">
#  <a href="#">
#                    List with us
#                   </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="elementor-column elementor-col-25 elementor-top-column elementor-element elementor-element-83f5af2" data-element_type="column" data-id="83f5af2">
#  <div class="elementor-widget-wrap elementor-element-populated">
#  <div class="elementor-element elementor-element-be13cec elementor-widget elementor-widget-heading" data-element_type="widget" data-id="be13cec" data-widget_type="heading.default">
#  <div class="elementor-widget-container">
#  <h2 class="elementor-heading-title elementor-size-default">
#               Contact Us
#              </h2>
#  </div>
#  </div>
#  <div class="elementor-element elementor-element-69fcfe4 elementor-widget elementor-widget-heading" data-element_type="widget" data-id="69fcfe4" data-widget_type="heading.default">
#  <div class="elementor-widget-container">
#  <div class="elementor-heading-title elementor-size-default">
#  <a href="mailto:hello@cwlagos.com">
#                hello@cwlagos.com
#               </a>
#  </div>
#  </div>
#  </div>
#  <div class="elementor-element elementor-element-b817dee elementor-widget elementor-widget-heading" data-element_type="widget" data-id="b817dee" data-widget_type="heading.default">
#  <div class="elementor-widget-container">
#  <div class="elementor-heading-title elementor-size-default">
#               3/5 Modupe Alakija, Ikoyi , Lagos
#              </div>
#  </div>
#  </div>
#  <div class="elementor-element elementor-element-dba7eb1 elementor-widget elementor-widget-heading" data-element_type="widget" data-id="dba7eb1" data-widget_type="heading.default">
#  <div class="elementor-widget-container">
#  <div class="elementor-heading-title elementor-size-default">
#               +234 906 251 1343
#               <br/>
#  <br/>
#               +234 704 808 9362
#              </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="elementor-column elementor-col-25 elementor-top-column elementor-element elementor-element-6bf184d" data-element_type="column" data-id="6bf184d">
#  <div class="elementor-widget-wrap elementor-element-populated">
#  <div class="elementor-element elementor-element-e863863 elementor-widget elementor-widget-heading" data-element_type="widget" data-id="e863863" data-widget_type="heading.default">
#  <div class="elementor-widget-container">
#  <h2 class="elementor-heading-title elementor-size-default">
#               Newsletter
#              </h2>
#  </div>
#  </div>
#  <div class="elementor-element elementor-element-25d9a05 elementor-widget elementor-widget-apus_element_mailchimp" data-element_type="widget" data-id="25d9a05" data-widget_type="apus_element_mailchimp.default">
#  <div class="elementor-widget-container">
#  <div class="widget-mailchimp widget no-margin">
#  <script defer="" src="...">
#  </script>
#  <form class="mc4wp-form mc4wp-form-74" data-id="74" data-name="Download Report" id="mc4wp-form-1" method="post">
#  <div class="mc4wp-form-fields">
#  <div class="flex">
#  <input name="EMAIL" placeholder="Your email" required="" type="email"/>
#  <span class="ali-right">
#  <button class="btn-submit" type="submit">
#  <i class="flaticon-next">
#  </i>
#  </button>
#  </span>
#  </div>
#  </div>
#  <label style="display: none !important;">
#                 Leave this field empty if you're human:
#                 <input autocomplete="off" name="_mc4wp_honeypot" tabindex="-1" type="text" value=""/>
#  </label>
#  <input name="_mc4wp_timestamp" type="hidden" value="1763026543"/>
#  <input name="_mc4wp_form_id" type="hidden" value="74"/>
#  <input name="_mc4wp_form_element_id" type="hidden" value="mc4wp-form-1"/>
#  <div class="mc4wp-response">
#  </div>
#  </form>
#  </div>
#  </div>
#  </div>
#  <div class="elementor-element elementor-element-69b5332 elementor-widget elementor-widget-apus_element_social_links" data-element_type="widget" data-id="69b5332" data-widget_type="apus_element_social_links.default">
#  <div class="elementor-widget-container">
#  <div class="widget-socials widget no-margin">
#  <h2 class="widget-title">
#                Follow us
#               </h2>
#  <ul class="social list-inline">
#  <li>
#  <a href="https://www.facebook.com/cwrelagos/" target="_blank">
#  <i class="fab fa-facebook-f">
#  </i>
#  </a>
#  </li>
#  <li>
#  <a href="https://www.instagram.com/cwrelagos/" target="_blank">
#  <i class="fab fa-instagram">
#  </i>
#  </a>
#  </li>
#  <li>
#  <a href="https://twitter.com/cwrelagos" target="_blank">
#  <i class="fab fa-twitter">
#  </i>
#  </a>
#  </li>
#  <li>
#  <a href="https://www.tiktok.com/@cwrelagos" target="_blank">
#  <i class="fab fa-tiktok">
#  </i>
#  </a>
#  </li>
#  <li>
#  <a href="https://www.linkedin.com/company/cwre-lagos" target="_blank">
#  <i class="fab fa-linkedin">
#  </i>
#  </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </section>,
#  <section class="elementor-section elementor-top-section elementor-element elementor-element-3a40404 elementor-section-stretched elementor-section-content-middle elementor-section-boxed elementor-section-height-default elementor-section-height-default" data-element_type="section" data-id="3a40404" data-settings='{"stretch_section":"section-stretched","background_background":"classic"}'>
#  <div class="elementor-container elementor-column-gap-extended">
#  <div class="elementor-column elementor-col-50 elementor-top-column elementor-element elementor-element-5b4698f" data-element_type="column" data-id="5b4698f">
#  <div class="elementor-widget-wrap elementor-element-populated">
#  <div class="elementor-element elementor-element-b639d99 elementor-widget elementor-widget-apus_element_nav_menu" data-element_type="widget" data-id="b639d99" data-widget_type="apus_element_nav_menu.default">
#  <div class="elementor-widget-container">
#  <div class="widget-nav-menu no-margin widget st_line">
#  <div class="widget-content">
#  <div class="menu-copyright-container">
#  <ul class="menu" id="menu-copyright">
#  <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-79" id="menu-item-79">
#  <a href="https://cwlagos.com/privacy-policy/" rel="privacy-policy">
#                    Privacy Policy
#                   </a>
#  </li>
#  <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-80" id="menu-item-80">
#  <a href="#">
#                    Sitemap
#                   </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="elementor-column elementor-col-50 elementor-top-column elementor-element elementor-element-e0b27cb" data-element_type="column" data-id="e0b27cb">
#  <div class="elementor-widget-wrap elementor-element-populated">
#  <div class="elementor-element elementor-element-8c1de1c elementor-widget elementor-widget-heading" data-element_type="widget" data-id="8c1de1c" data-widget_type="heading.default">
#  <div class="elementor-widget-container">
#  <div class="elementor-heading-title elementor-size-default">
#               © 2022 CW Real Estate. All rights reserved.
#              </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </section>]

# %%
for section in loaded_soup.find_all('section'):
    for descendant in section.descendants:
        if descendant.name == 'a':
            print(descendant)
# Out:
# <a href="https://cwlagos.com/">
# <span class="logo-main">
# <img alt="" class="attachment-full size-full wp-image-14442" decoding="async" fetchpriority="high" height="348" src="https://cwlagos.com/wp-content/uploads/2022/01/Website-Logo.svg" width="1293"/>
# </span>
# </a>
# <a class="dropdown-toggle" data-hover="dropdown" data-toggle="dropdown" href="https://cwlagos.com/">
#                  Cities
#                  <b class="caret">
# </b>
# </a>
# <a href="http://cwlagos.com">
#                    Lagos
#                   </a>
# <a href="https://cwlagos.com/cwre-dubai-offer/" target="_blank">
#                    Dubai
#                   </a>
# <a href="http://theresidenceabuja.com/" target="_blank">
#                    Abuja
#                   </a>
# <a href="#">
#                    Ghana (Coming Soon)
#                   </a>
# <a class="dropdown-toggle" data-hover="dropdown" data-toggle="dropdown" href="https://cwlagos.com/about/">
#                  About
#                  <b class="caret">
# </b>
# </a>
# <a href="https://cwlagos.com/meet-our-team/">
#                    Meet Our Team
#                   </a>
# <a href="#">
#                    Awards
#                   </a>
# <a href="https://cwlagos.com/listings/">
#                  Listings
#                 </a>
# <a href="https://shortstays.cwlagos.com" target="_blank">
#                  Short Stays
#                 </a>
# <a href="https://cwlagos.com/new-development/">
#                  New Developments
#                 </a>
# <a href="https://cwlagos.com/blog/">
#                  Blog
#                 </a>
# <a href="https://cwlagos.com/contact/">
#                  Contact us
#                 </a>
# <a class="btn-login apus-user-login" href="#apus_login_forgot_form" title="Login">
#              Login
#             </a>
# <a class="btn-login register apus-user-register" href="#apus_register_form" title="Register">
#              Register
#             </a>
# <a class="facebook-login-btn" href="https://www.facebook.com/v2.10/dialog/oauth?client_id=1&amp;state=43addc8a56c91eeabf7fc60447169cb9&amp;response_type=code&amp;sdk=php-sdk-5.6.1&amp;redirect_uri=https%3A%2F%2Fcwlagos.com%2Fwp-admin%2Fadmin-ajax.php%3Faction%3Dwp_realestate_facebook_login&amp;scope=email">
# <i class="fab fa-facebook-f">
# </i>
# <span>
#                          Login with Facebook
#                         </span>
# </a>
# <a class="google-login-btn" href="https://accounts.google.com/o/oauth2/auth?response_type=code&amp;redirect_uri=https%3A%2F%2Fcwlagos.com%2F&amp;client_id=1&amp;scope=email&amp;access_type=online&amp;approval_prompt=auto">
# <i class="fab fa-google">
# </i>
# <span>
#                          Login with Google
#                         </span>
# </a>
# <a class="back-link" href="#forgot-password-form-wrapper" title="Forgot Password">
#                        Lost Your Password?
#                       </a>
# <a class="apus-user-register" href="#apus_register_form">
#                         Register
#                        </a>
# <a class="back-link" href="#login-form-wrapper">
#                       Back To Login
#                      </a>
# <a class="apus-user-login" href="#apus_login_forgot_form">
#                      Login
#                     </a>
# <a class="btn-submit btn user-login-form" href="https://cwlagos.com/submission/">
# <span class="flaticon-plus button-icon">
# </span>
#              Submit Property
#             </a>
# <a href="https://cwlagos.com">
#              Home
#             </a>
# <a href="https://cwlagos.com/property-location/ikoyi/">
#              Properties
#             </a>
# <a class="btn-saved-search" href="#saved-search-form-btn-wrapper">
# <i class="flaticon-heart">
# </i>
#             Save Search
#            </a>
# <a class="mobile-sidebar-btn hidden-lg hidden-md btn-right" href="javascript:void(0)">
# <i class="ti-menu-alt">
# </i>
# </a>
# <a class="property-image" href="https://cwlagos.com/property/2-bedroom-maisonette-bq-in-ikoyi/">
# <div class="image-wrapper">
# <img alt="" class="attachment-homeo-property-grid size-homeo-property-grid unveil-image" data-src="https://cwlagos.com/wp-content/uploads/2025/07/Untitled-design-31-2-850x550.png" height="550" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 850 550'%2F%3E" width="850"/>
# </div>
# </a>
# <a class="status-property-label" href="https://cwlagos.com/property-status/for-rent/" style="">
#                   For Rent
#                  </a>
# <a class="label-property-label" href="https://cwlagos.com/property-label/available-for-rent/" style="">
#                   Available for rent
#                  </a>
# <a class="btn-add-property-favorite" data-nonce="db292f5b35" data-property_id="86590" data-toggle="tooltip" href="javascript:void(0)" title="Add Favorite">
# <i class="flaticon-heart">
# </i>
# </a>
# <a class="btn-add-property-compare" data-nonce="c27294dbde" data-property_id="86590" data-toggle="tooltip" href="javascript:void(0)" title="Add Compare">
# <i class="flaticon-transfer-1">
# </i>
# </a>
# <a class="type-property" href="https://cwlagos.com/property-type/maisonette/" style="">
#                    Maisonette
#                   </a>
# <a href="https://cwlagos.com/property/2-bedroom-maisonette-bq-in-ikoyi/" rel="bookmark">
#                   2 Bedroom Maisonette + BQ in Ikoyi
#                  </a>
# <a href="//maps.google.com/maps?q=Ikoyi&amp;zoom=14&amp;size=512x512&amp;maptype=roadmap&amp;sensor=false" target="_blank">
#                   Ikoyi
#                  </a>
# <a class="property-image" href="https://cwlagos.com/property/4-bedroom-furnished-apartment-bq/">
# <div class="image-wrapper">
# <img alt="" class="attachment-homeo-property-grid size-homeo-property-grid unveil-image" data-src="https://cwlagos.com/wp-content/uploads/2025/03/Group-2-1-3-850x550.png" height="550" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 850 550'%2F%3E" width="850"/>
# </div>
# </a>
# <a class="status-property-label" href="https://cwlagos.com/property-status/for-rent/" style="">
#                   For Rent
#                  </a>
# <a class="label-property-label" href="https://cwlagos.com/property-label/available-for-rent/" style="">
#                   Available for rent
#                  </a>
# <a class="btn-add-property-favorite" data-nonce="db292f5b35" data-property_id="81041" data-toggle="tooltip" href="javascript:void(0)" title="Add Favorite">
# <i class="flaticon-heart">
# </i>
# </a>
# <a class="btn-add-property-compare" data-nonce="c27294dbde" data-property_id="81041" data-toggle="tooltip" href="javascript:void(0)" title="Add Compare">
# <i class="flaticon-transfer-1">
# </i>
# </a>
# <a class="type-property" href="https://cwlagos.com/property-type/apartment/" style="">
#                    Apartment
#                   </a>
# <a href="https://cwlagos.com/property/4-bedroom-furnished-apartment-bq/" rel="bookmark">
#                   4 Bedroom Furnished Apartment + BQ
#                  </a>
# <a href="//maps.google.com/maps?q=Ikoyi%2C+Lagos.&amp;zoom=14&amp;size=512x512&amp;maptype=roadmap&amp;sensor=false" target="_blank">
#                   Ikoyi, Lagos.
#                  </a>
# <a class="property-image" href="https://cwlagos.com/property/luxury-3-bedroom-maisonette-with-bq/">
# <div class="image-wrapper">
# <img alt="" class="attachment-homeo-property-grid size-homeo-property-grid unveil-image" data-src="https://cwlagos.com/wp-content/uploads/2025/03/Group-2-63-850x550.png" height="550" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 850 550'%2F%3E" width="850"/>
# </div>
# </a>
# <a class="status-property-label" href="https://cwlagos.com/property-status/for-sale/" style="">
#                   For Sale
#                  </a>
# <a class="label-property-label" href="https://cwlagos.com/property-label/available-for-sale/" style="">
#                   Available for sale
#                  </a>
# <a class="btn-add-property-favorite" data-nonce="db292f5b35" data-property_id="80951" data-toggle="tooltip" href="javascript:void(0)" title="Add Favorite">
# <i class="flaticon-heart">
# </i>
# </a>
# <a class="btn-add-property-compare" data-nonce="c27294dbde" data-property_id="80951" data-toggle="tooltip" href="javascript:void(0)" title="Add Compare">
# <i class="flaticon-transfer-1">
# </i>
# </a>
# <a class="type-property" href="https://cwlagos.com/property-type/maisonette/" style="">
#                    Maisonette
#                   </a>
# <a href="https://cwlagos.com/property/luxury-3-bedroom-maisonette-with-bq/" rel="bookmark">
#                   Luxury 3 Bedroom Maisonette with BQ
#                  </a>
# <a href="//maps.google.com/maps?q=Ikoyi%2C+Lagos.&amp;zoom=14&amp;size=512x512&amp;maptype=roadmap&amp;sensor=false" target="_blank">
#                   Ikoyi, Lagos.
#                  </a>
# <a href="https://cwlagos.com/agent/adeyemi-fowosire/">
# <div class="image-wrapper">
# <img alt="" class="attachment-thumbnail size-thumbnail unveil-image" data-src="https://cwlagos.com/wp-content/uploads/2024/12/DSC01354-150x150.jpg" height="150" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 150 150'%2F%3E" width="150"/>
# </div>
# </a>
# <a href="https://cwlagos.com/agent/adeyemi-fowosire/">
#                   Adeyemi Fowosire
#                  </a>
# <a class="property-image" href="https://cwlagos.com/property/luxury-5-bedroom-detached-house-with-en-suite-bq/">
# <div class="image-wrapper">
# <img alt="" class="attachment-homeo-property-grid size-homeo-property-grid unveil-image" data-src="https://cwlagos.com/wp-content/uploads/2025/03/Group-2-59-850x550.png" height="550" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 850 550'%2F%3E" width="850"/>
# </div>
# </a>
# <a class="status-property-label" href="https://cwlagos.com/property-status/for-rent/" style="">
#                   For Rent
#                  </a>
# <a class="label-property-label" href="https://cwlagos.com/property-label/available-for-sale/" style="">
#                   Available for sale
#                  </a>
# <a class="btn-add-property-favorite" data-nonce="db292f5b35" data-property_id="80854" data-toggle="tooltip" href="javascript:void(0)" title="Add Favorite">
# <i class="flaticon-heart">
# </i>
# </a>
# <a class="btn-add-property-compare" data-nonce="c27294dbde" data-property_id="80854" data-toggle="tooltip" href="javascript:void(0)" title="Add Compare">
# <i class="flaticon-transfer-1">
# </i>
# </a>
# <a class="type-property" href="https://cwlagos.com/property-type/detached/" style="">
#                    Detached
#                   </a>
# <a href="https://cwlagos.com/property/luxury-5-bedroom-detached-house-with-en-suite-bq/" rel="bookmark">
#                   Luxury 5 Bedroom Detached House
#                  </a>
# <a href="//maps.google.com/maps?q=Banana+Island%2C+Ikoyi%2C+Lagos.&amp;zoom=14&amp;size=512x512&amp;maptype=roadmap&amp;sensor=false" target="_blank">
#                   Banana Island, Ikoyi, Lagos.
#                  </a>
# <a href="https://cwlagos.com/agent/adeyemi-fowosire/">
# <div class="image-wrapper">
# <img alt="" class="attachment-thumbnail size-thumbnail unveil-image" data-src="https://cwlagos.com/wp-content/uploads/2024/12/DSC01354-150x150.jpg" height="150" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 150 150'%2F%3E" width="150"/>
# </div>
# </a>
# <a href="https://cwlagos.com/agent/adeyemi-fowosire/">
#                   Adeyemi Fowosire
#                  </a>
# <a class="property-image" href="https://cwlagos.com/property/exclusive-4-bedroom-maisonette-with-swimming-pool-2/">
# <div class="image-wrapper">
# <img alt="" class="attachment-homeo-property-grid size-homeo-property-grid unveil-image" data-sizes="(max-width: 696px) 100vw, 696px" data-src="https://cwlagos.com/wp-content/uploads/2025/03/Group-2-52-696x550.png" data-srcset="https://cwlagos.com/wp-content/uploads/2025/03/Group-2-52-696x550.png 696w, https://cwlagos.com/wp-content/uploads/2025/03/Group-2-52-165x130.png 165w" height="550" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 696 550'%2F%3E" width="696"/>
# </div>
# </a>
# <a class="status-property-label" href="https://cwlagos.com/property-status/for-sale/" style="">
#                   For Sale
#                  </a>
# <a class="label-property-label" href="https://cwlagos.com/property-label/available-for-sale/" style="">
#                   Available for sale
#                  </a>
# <a class="btn-add-property-favorite" data-nonce="db292f5b35" data-property_id="80706" data-toggle="tooltip" href="javascript:void(0)" title="Add Favorite">
# <i class="flaticon-heart">
# </i>
# </a>
# <a class="btn-add-property-compare" data-nonce="c27294dbde" data-property_id="80706" data-toggle="tooltip" href="javascript:void(0)" title="Add Compare">
# <i class="flaticon-transfer-1">
# </i>
# </a>
# <a class="type-property" href="https://cwlagos.com/property-type/maisonette/" style="">
#                    Maisonette
#                   </a>
# <a href="https://cwlagos.com/property/exclusive-4-bedroom-maisonette-with-swimming-pool-2/" rel="bookmark">
#                   Exclusive 4 Bedroom Maisonette with Swimming Pool
#                  </a>
# <a href="//maps.google.com/maps?q=Ikoyi%2C+Lagos.&amp;zoom=14&amp;size=512x512&amp;maptype=roadmap&amp;sensor=false" target="_blank">
#                   Ikoyi, Lagos.
#                  </a>
# <a href="https://cwlagos.com/agent/adaeze-ajomiwe/">
# <div class="image-wrapper">
# <img alt="" class="attachment-thumbnail size-thumbnail unveil-image" data-src="https://cwlagos.com/wp-content/uploads/2024/12/CLI05323-Enhanced-NR-150x150.jpg" height="150" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 150 150'%2F%3E" width="150"/>
# </div>
# </a>
# <a href="https://cwlagos.com/agent/adaeze-ajomiwe/">
#                   Adaeze Ajomiwe
#                  </a>
# <a class="property-image" href="https://cwlagos.com/property/2-units-of-4-bedroom-terrace-with-a-bq-each/">
# <div class="image-wrapper">
# <img alt="" class="attachment-homeo-property-grid size-homeo-property-grid unveil-image" data-src="https://cwlagos.com/wp-content/uploads/2025/03/Group-2-42-850x550.png" height="550" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 850 550'%2F%3E" width="850"/>
# </div>
# </a>
# <a class="status-property-label" href="https://cwlagos.com/property-status/for-sale/" style="">
#                   For Sale
#                  </a>
# <a class="label-property-label" href="https://cwlagos.com/property-label/available-for-sale/" style="">
#                   Available for sale
#                  </a>
# <a class="btn-add-property-favorite" data-nonce="db292f5b35" data-property_id="80481" data-toggle="tooltip" href="javascript:void(0)" title="Add Favorite">
# <i class="flaticon-heart">
# </i>
# </a>
# <a class="btn-add-property-compare" data-nonce="c27294dbde" data-property_id="80481" data-toggle="tooltip" href="javascript:void(0)" title="Add Compare">
# <i class="flaticon-transfer-1">
# </i>
# </a>
# <a class="type-property" href="https://cwlagos.com/property-type/terraced/" style="">
#                    Terraced
#                   </a>
# <a href="https://cwlagos.com/property/2-units-of-4-bedroom-terrace-with-a-bq-each/" rel="bookmark">
#                   2 units of 4 Bedroom Terrace with a BQ Each
#                  </a>
# <a href="//maps.google.com/maps?q=Ikoyi%2C+Lagos.&amp;zoom=14&amp;size=512x512&amp;maptype=roadmap&amp;sensor=false" target="_blank">
#                   Ikoyi, Lagos.
#                  </a>
# <a href="https://cwlagos.com/agent/adeyemi-fowosire/">
# <div class="image-wrapper">
# <img alt="" class="attachment-thumbnail size-thumbnail unveil-image" data-src="https://cwlagos.com/wp-content/uploads/2024/12/DSC01354-150x150.jpg" height="150" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 150 150'%2F%3E" width="150"/>
# </div>
# </a>
# <a href="https://cwlagos.com/agent/adeyemi-fowosire/">
#                   Adeyemi Fowosire
#                  </a>
# <a class="property-image" href="https://cwlagos.com/property/luxury-4-bedroom-terrace-with-private-rooftop-swimming-pool/">
# <div class="image-wrapper">
# <img alt="" class="attachment-homeo-property-grid size-homeo-property-grid unveil-image" data-src="https://cwlagos.com/wp-content/uploads/2025/03/Group-2-40-850x550.png" height="550" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 850 550'%2F%3E" width="850"/>
# </div>
# </a>
# <a class="status-property-label" href="https://cwlagos.com/property-status/for-sale/" style="">
#                   For Sale
#                  </a>
# <a class="label-property-label" href="https://cwlagos.com/property-label/available-for-sale/" style="">
#                   Available for sale
#                  </a>
# <a class="btn-add-property-favorite" data-nonce="db292f5b35" data-property_id="80409" data-toggle="tooltip" href="javascript:void(0)" title="Add Favorite">
# <i class="flaticon-heart">
# </i>
# </a>
# <a class="btn-add-property-compare" data-nonce="c27294dbde" data-property_id="80409" data-toggle="tooltip" href="javascript:void(0)" title="Add Compare">
# <i class="flaticon-transfer-1">
# </i>
# </a>
# <a class="type-property" href="https://cwlagos.com/property-type/terraced/" style="">
#                    Terraced
#                   </a>
# <a href="https://cwlagos.com/property/luxury-4-bedroom-terrace-with-private-rooftop-swimming-pool/" rel="bookmark">
#                   Luxury 4 Bedroom Terrace with Private Rooftop Swimming Pool
#                  </a>
# <a href="//maps.google.com/maps?q=Old+Ikoyi%2C+Ikoyi%2C+Lagos.&amp;zoom=14&amp;size=512x512&amp;maptype=roadmap&amp;sensor=false" target="_blank">
#                   Old Ikoyi, Ikoyi, Lagos.
#                  </a>
# <a href="https://cwlagos.com/agent/rose/">
# <div class="image-wrapper">
# <img alt="" class="attachment-thumbnail size-thumbnail unveil-image" data-src="https://cwlagos.com/wp-content/uploads/2023/11/CLI05340-150x150.jpg" height="150" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 150 150'%2F%3E" width="150"/>
# </div>
# </a>
# <a href="https://cwlagos.com/agent/rose/">
#                   Rose
#                  </a>
# <a class="property-image" href="https://cwlagos.com/property/new-developments-in-ikoyi/">
# <div class="image-wrapper">
# <img alt="" class="attachment-homeo-property-grid size-homeo-property-grid unveil-image" data-src="https://cwlagos.com/wp-content/uploads/2025/11/Untitled-design-11-1-850x550.png" height="550" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 850 550'%2F%3E" width="850"/>
# </div>
# </a>
# <a class="status-property-label" href="https://cwlagos.com/property-status/for-sale/" style="">
#                   For Sale
#                  </a>
# <a class="status-property-label" href="https://cwlagos.com/property-status/new-developments/" style="">
#                   New Developments
#                  </a>
# <a class="label-property-label" href="https://cwlagos.com/property-label/available-for-sale/" style="">
#                   Available for sale
#                  </a>
# <a class="btn-add-property-favorite" data-nonce="db292f5b35" data-property_id="97048" data-toggle="tooltip" href="javascript:void(0)" title="Add Favorite">
# <i class="flaticon-heart">
# </i>
# </a>
# <a class="btn-add-property-compare" data-nonce="c27294dbde" data-property_id="97048" data-toggle="tooltip" href="javascript:void(0)" title="Add Compare">
# <i class="flaticon-transfer-1">
# </i>
# </a>
# <a class="type-property" href="https://cwlagos.com/property-type/maisonette/" style="">
#                    Maisonette
#                   </a>
# <a href="https://cwlagos.com/property/new-developments-in-ikoyi/" rel="bookmark">
#                   NEW DEVELOPMENTS IN IKOYI
#                  </a>
# <a href="//maps.google.com/maps?q=Ikoyi&amp;zoom=14&amp;size=512x512&amp;maptype=roadmap&amp;sensor=false" target="_blank">
#                   Ikoyi
#                  </a>
# <a class="property-image" href="https://cwlagos.com/property/prime-land-in-banana-island/">
# <div class="image-wrapper">
# <img alt="" class="attachment-homeo-property-grid size-homeo-property-grid unveil-image" data-src="https://cwlagos.com/wp-content/uploads/2025/11/Full-Logo-Whitre-1-4-850x550.png" height="550" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 850 550'%2F%3E" width="850"/>
# </div>
# </a>
# <a class="status-property-label" href="https://cwlagos.com/property-status/for-sale/" style="">
#                   For Sale
#                  </a>
# <a class="status-property-label" href="https://cwlagos.com/property-status/land/" style="">
#                   Land
#                  </a>
# <a class="label-property-label" href="https://cwlagos.com/property-label/available-for-sale/" style="">
#                   Available for sale
#                  </a>
# <a class="btn-add-property-favorite" data-nonce="db292f5b35" data-property_id="97041" data-toggle="tooltip" href="javascript:void(0)" title="Add Favorite">
# <i class="flaticon-heart">
# </i>
# </a>
# <a class="btn-add-property-compare" data-nonce="c27294dbde" data-property_id="97041" data-toggle="tooltip" href="javascript:void(0)" title="Add Compare">
# <i class="flaticon-transfer-1">
# </i>
# </a>
# <a href="https://cwlagos.com/property/prime-land-in-banana-island/" rel="bookmark">
#                   Prime Land in Banana Island
#                  </a>
# <a href="//maps.google.com/maps?q=Ikoyi&amp;zoom=14&amp;size=512x512&amp;maptype=roadmap&amp;sensor=false" target="_blank">
#                   Ikoyi
#                  </a>
# <a class="property-image" href="https://cwlagos.com/property/residential-land-banana-island/">
# <div class="image-wrapper">
# <img alt="" class="attachment-homeo-property-grid size-homeo-property-grid unveil-image" data-src="https://cwlagos.com/wp-content/uploads/2025/11/Full-Logo-Whitre-1-4-850x550.png" height="550" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 850 550'%2F%3E" width="850"/>
# </div>
# </a>
# <a class="status-property-label" href="https://cwlagos.com/property-status/for-sale/" style="">
#                   For Sale
#                  </a>
# <a class="status-property-label" href="https://cwlagos.com/property-status/land/" style="">
#                   Land
#                  </a>
# <a class="label-property-label" href="https://cwlagos.com/property-label/available-for-sale/" style="">
#                   Available for sale
#                  </a>
# <a class="btn-add-property-favorite" data-nonce="db292f5b35" data-property_id="97039" data-toggle="tooltip" href="javascript:void(0)" title="Add Favorite">
# <i class="flaticon-heart">
# </i>
# </a>
# <a class="btn-add-property-compare" data-nonce="c27294dbde" data-property_id="97039" data-toggle="tooltip" href="javascript:void(0)" title="Add Compare">
# <i class="flaticon-transfer-1">
# </i>
# </a>
# <a href="https://cwlagos.com/property/residential-land-banana-island/" rel="bookmark">
#                   Residential Land- Banana Island
#                  </a>
# <a href="//maps.google.com/maps?q=Ikoyi&amp;zoom=14&amp;size=512x512&amp;maptype=roadmap&amp;sensor=false" target="_blank">
#                   Ikoyi
#                  </a>
# <a class="property-image" href="https://cwlagos.com/property/land-measuring-3300sqm-ikoyi/">
# <div class="image-wrapper">
# <img alt="" class="attachment-homeo-property-grid size-homeo-property-grid unveil-image" data-src="https://cwlagos.com/wp-content/uploads/2025/11/Full-Logo-Whitre-1-3-850x550.png" height="550" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 850 550'%2F%3E" width="850"/>
# </div>
# </a>
# <a class="status-property-label" href="https://cwlagos.com/property-status/for-sale/" style="">
#                   For Sale
#                  </a>
# <a class="status-property-label" href="https://cwlagos.com/property-status/land/" style="">
#                   Land
#                  </a>
# <a class="label-property-label" href="https://cwlagos.com/property-label/available-for-sale/" style="">
#                   Available for sale
#                  </a>
# <a class="btn-add-property-favorite" data-nonce="db292f5b35" data-property_id="97037" data-toggle="tooltip" href="javascript:void(0)" title="Add Favorite">
# <i class="flaticon-heart">
# </i>
# </a>
# <a class="btn-add-property-compare" data-nonce="c27294dbde" data-property_id="97037" data-toggle="tooltip" href="javascript:void(0)" title="Add Compare">
# <i class="flaticon-transfer-1">
# </i>
# </a>
# <a href="https://cwlagos.com/property/land-measuring-3300sqm-ikoyi/" rel="bookmark">
#                   Land Measuring 3300sqm- Ikoyi
#                  </a>
# <a href="//maps.google.com/maps?q=Ikoyi&amp;zoom=14&amp;size=512x512&amp;maptype=roadmap&amp;sensor=false" target="_blank">
#                   Ikoyi
#                  </a>
# <a class="property-image" href="https://cwlagos.com/property/waterfront-land-in-ikoyi-2/">
# <div class="image-wrapper">
# <img alt="" class="attachment-homeo-property-grid size-homeo-property-grid unveil-image" data-src="https://cwlagos.com/wp-content/uploads/2025/11/Full-Logo-Whitre-1-2-850x550.png" height="550" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 850 550'%2F%3E" width="850"/>
# </div>
# </a>
# <a class="status-property-label" href="https://cwlagos.com/property-status/for-sale/" style="">
#                   For Sale
#                  </a>
# <a class="status-property-label" href="https://cwlagos.com/property-status/land/" style="">
#                   Land
#                  </a>
# <a class="label-property-label" href="https://cwlagos.com/property-label/available-for-sale/" style="">
#                   Available for sale
#                  </a>
# <a class="btn-add-property-favorite" data-nonce="db292f5b35" data-property_id="97035" data-toggle="tooltip" href="javascript:void(0)" title="Add Favorite">
# <i class="flaticon-heart">
# </i>
# </a>
# <a class="btn-add-property-compare" data-nonce="c27294dbde" data-property_id="97035" data-toggle="tooltip" href="javascript:void(0)" title="Add Compare">
# <i class="flaticon-transfer-1">
# </i>
# </a>
# <a href="https://cwlagos.com/property/waterfront-land-in-ikoyi-2/" rel="bookmark">
#                   Waterfront Land in Ikoyi
#                  </a>
# <a href="//maps.google.com/maps?q=Ikoyi&amp;zoom=14&amp;size=512x512&amp;maptype=roadmap&amp;sensor=false" target="_blank">
#                   Ikoyi
#                  </a>
# <a class="property-image" href="https://cwlagos.com/property/land-measuring-750sqm-ikoyi-2/">
# <div class="image-wrapper">
# <img alt="" class="attachment-homeo-property-grid size-homeo-property-grid unveil-image" data-src="https://cwlagos.com/wp-content/uploads/2025/11/Full-Logo-Whitre-1-2-850x550.png" height="550" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 850 550'%2F%3E" width="850"/>
# </div>
# </a>
# <a class="status-property-label" href="https://cwlagos.com/property-status/for-sale/" style="">
#                   For Sale
#                  </a>
# <a class="status-property-label" href="https://cwlagos.com/property-status/land/" style="">
#                   Land
#                  </a>
# <a class="label-property-label" href="https://cwlagos.com/property-label/available-for-sale/" style="">
#                   Available for sale
#                  </a>
# <a class="btn-add-property-favorite" data-nonce="db292f5b35" data-property_id="97032" data-toggle="tooltip" href="javascript:void(0)" title="Add Favorite">
# <i class="flaticon-heart">
# </i>
# </a>
# <a class="btn-add-property-compare" data-nonce="c27294dbde" data-property_id="97032" data-toggle="tooltip" href="javascript:void(0)" title="Add Compare">
# <i class="flaticon-transfer-1">
# </i>
# </a>
# <a href="https://cwlagos.com/property/land-measuring-750sqm-ikoyi-2/" rel="bookmark">
#                   Land Measuring 750sqm- Ikoyi
#                  </a>
# <a href="//maps.google.com/maps?q=Ikoyi&amp;zoom=14&amp;size=512x512&amp;maptype=roadmap&amp;sensor=false" target="_blank">
#                   Ikoyi
#                  </a>
# <a class="property-image" href="https://cwlagos.com/property/land-measuring-875sqm-ikoyi/">
# <div class="image-wrapper">
# <img alt="" class="attachment-homeo-property-grid size-homeo-property-grid unveil-image" data-src="https://cwlagos.com/wp-content/uploads/2025/11/Full-Logo-Whitre-1-2-850x550.png" height="550" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 850 550'%2F%3E" width="850"/>
# </div>
# </a>
# <a class="status-property-label" href="https://cwlagos.com/property-status/for-sale/" style="">
#                   For Sale
#                  </a>
# <a class="status-property-label" href="https://cwlagos.com/property-status/land/" style="">
#                   Land
#                  </a>
# <a class="label-property-label" href="https://cwlagos.com/property-label/available-for-sale/" style="">
#                   Available for sale
#                  </a>
# <a class="btn-add-property-favorite" data-nonce="db292f5b35" data-property_id="97029" data-toggle="tooltip" href="javascript:void(0)" title="Add Favorite">
# <i class="flaticon-heart">
# </i>
# </a>
# <a class="btn-add-property-compare" data-nonce="c27294dbde" data-property_id="97029" data-toggle="tooltip" href="javascript:void(0)" title="Add Compare">
# <i class="flaticon-transfer-1">
# </i>
# </a>
# <a href="https://cwlagos.com/property/land-measuring-875sqm-ikoyi/" rel="bookmark">
#                   Land Measuring 875sqm- Ikoyi
#                  </a>
# <a href="//maps.google.com/maps?q=Ikoyi&amp;zoom=14&amp;size=512x512&amp;maptype=roadmap&amp;sensor=false" target="_blank">
#                   Ikoyi
#                  </a>
# <a class="property-image" href="https://cwlagos.com/property/prime-land-in-ikoyi/">
# <div class="image-wrapper">
# <img alt="" class="attachment-homeo-property-grid size-homeo-property-grid unveil-image" data-src="https://cwlagos.com/wp-content/uploads/2025/11/Full-Logo-Whitre-1-1-850x550.png" height="550" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 850 550'%2F%3E" width="850"/>
# </div>
# </a>
# <a class="status-property-label" href="https://cwlagos.com/property-status/for-sale/" style="">
#                   For Sale
#                  </a>
# <a class="status-property-label" href="https://cwlagos.com/property-status/land/" style="">
#                   Land
#                  </a>
# <a class="label-property-label" href="https://cwlagos.com/property-label/available-for-sale/" style="">
#                   Available for sale
#                  </a>
# <a class="btn-add-property-favorite" data-nonce="db292f5b35" data-property_id="97027" data-toggle="tooltip" href="javascript:void(0)" title="Add Favorite">
# <i class="flaticon-heart">
# </i>
# </a>
# <a class="btn-add-property-compare" data-nonce="c27294dbde" data-property_id="97027" data-toggle="tooltip" href="javascript:void(0)" title="Add Compare">
# <i class="flaticon-transfer-1">
# </i>
# </a>
# <a href="https://cwlagos.com/property/prime-land-in-ikoyi/" rel="bookmark">
#                   Prime Land in Ikoyi
#                  </a>
# <a href="//maps.google.com/maps?q=Ikoyi&amp;zoom=14&amp;size=512x512&amp;maptype=roadmap&amp;sensor=false" target="_blank">
#                   Ikoyi
#                  </a>
# <a class="page-numbers" href="https://cwlagos.com/property-location/ikoyi/page/2/">
#              2
#             </a>
# <a class="page-numbers" href="https://cwlagos.com/property-location/ikoyi/page/3/">
#              3
#             </a>
# <a class="page-numbers" href="https://cwlagos.com/property-location/ikoyi/page/25/">
#              25
#             </a>
# <a class="next page-numbers" href="https://cwlagos.com/property-location/ikoyi/page/2/">
# <i class="ti-angle-right">
# </i>
# </a>
# <a class="advance-search-btn" href="javascript:void(0);">
#                            Advanced
#                            <i class="flaticon-more">
# </i>
# </a>
# <a class="property-image" href="https://cwlagos.com/property/new-developments-in-ikoyi/">
# <div class="image-wrapper">
# <img alt="" class="attachment-thumbnail size-thumbnail unveil-image" data-sizes="(max-width: 150px) 100vw, 150px" data-src="https://cwlagos.com/wp-content/uploads/2025/11/Untitled-design-11-1-150x150.png" data-srcset="https://cwlagos.com/wp-content/uploads/2025/11/Untitled-design-11-1-150x150.png 150w, https://cwlagos.com/wp-content/uploads/2025/11/Untitled-design-11-1-300x300.png 300w, https://cwlagos.com/wp-content/uploads/2025/11/Untitled-design-11-1-1024x1024.png 1024w, https://cwlagos.com/wp-content/uploads/2025/11/Untitled-design-11-1-768x768.png 768w, https://cwlagos.com/wp-content/uploads/2025/11/Untitled-design-11-1.png 1080w" height="150" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 150 150'%2F%3E" width="150"/>
# </div>
# </a>
# <a href="https://cwlagos.com/property/new-developments-in-ikoyi/" rel="bookmark">
#                 NEW DEVELOPMENTS IN IKOYI
#                </a>
# <a class="property-image" href="https://cwlagos.com/property/commercial-plot-in-victoria-island/">
# <div class="image-wrapper">
# <img alt="" class="attachment-thumbnail size-thumbnail unveil-image" data-src="https://cwlagos.com/wp-content/uploads/2025/11/Full-Logo-Whitre-1-4-150x150.png" height="150" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 150 150'%2F%3E" width="150"/>
# </div>
# </a>
# <a href="https://cwlagos.com/property/commercial-plot-in-victoria-island/" rel="bookmark">
#                 COMMERCIAL PLOT IN VICTORIA ISLAND
#                </a>
# <a class="property-image" href="https://cwlagos.com/property/4000sqm-bareland-victoria-island/">
# <div class="image-wrapper">
# <img alt="" class="attachment-thumbnail size-thumbnail unveil-image" data-src="https://cwlagos.com/wp-content/uploads/2025/11/Full-Logo-Whitre-1-5-150x150.png" height="150" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 150 150'%2F%3E" width="150"/>
# </div>
# </a>
# <a href="https://cwlagos.com/property/4000sqm-bareland-victoria-island/" rel="bookmark">
#                 4,000sqm Bareland- Victoria Island
#                </a>
# <a class="property-image" href="https://cwlagos.com/property/waterfront-land-victoria-island/">
# <div class="image-wrapper">
# <img alt="" class="attachment-thumbnail size-thumbnail unveil-image" data-src="https://cwlagos.com/wp-content/uploads/2025/11/Full-Logo-Whitre-1-5-150x150.png" height="150" loading="lazy" src="data:image/svg+xml;charset=utf-8,%3Csvg xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg' viewBox%3D'0 0 150 150'%2F%3E" width="150"/>
# </div>
# </a>
# <a href="https://cwlagos.com/property/waterfront-land-victoria-island/" rel="bookmark">
#                 Waterfront Land- Victoria Island
#                </a>
# <a href="https://cwlagos.com">
#              Home
#             </a>
# <a href="https://cwlagos.com/property-location/ikoyi/">
#              Properties
#             </a>
# <a class="btn-saved-search" href="#saved-search-form-btn-wrapper">
# <i class="flaticon-heart">
# </i>
#             Save Search
#            </a>
# <a class="advance-search-btn" href="javascript:void(0);">
#                            Advanced
#                            <i class="flaticon-more">
# </i>
# </a>
# <a href="#">
#                   Awards
#                  </a>
# <a href="https://cwlagos.com/careers/">
#                   Careers – Join Our Team
#                  </a>
# <a href="https://cwlagos.com/theikoyireporth1/">
#                   Market Knowledge
#                  </a>
# <a href="https://cwlagos.com/referral-program/">
#                   Referral Program
#                  </a>
# <a href="#">
#                   Press &amp; Publications
#                  </a>
# <a href="https://cwlagos.com/faq/">
#                   FAQs
#                  </a>
# <a href="https://cwlagos.com/agents/">
#                   Find an Agent
#                  </a>
# <a href="https://cwlagos.com/blog/">
#                   Our Blogs
#                  </a>
# <a href="#">
#                   Media
#                  </a>
# <a href="#">
#                   List with us
#                  </a>
# <a href="mailto:hello@cwlagos.com">
#               hello@cwlagos.com
#              </a>
# <a href="https://www.facebook.com/cwrelagos/" target="_blank">
# <i class="fab fa-facebook-f">
# </i>
# </a>
# <a href="https://www.instagram.com/cwrelagos/" target="_blank">
# <i class="fab fa-instagram">
# </i>
# </a>
# <a href="https://twitter.com/cwrelagos" target="_blank">
# <i class="fab fa-twitter">
# </i>
# </a>
# <a href="https://www.tiktok.com/@cwrelagos" target="_blank">
# <i class="fab fa-tiktok">
# </i>
# </a>
# <a href="https://www.linkedin.com/company/cwre-lagos" target="_blank">
# <i class="fab fa-linkedin">
# </i>
# </a>
# <a href="https://cwlagos.com/privacy-policy/" rel="privacy-policy">
#                   Privacy Policy
#                  </a>
# <a href="#">
#                   Sitemap
#                  </a>

# %%
for section in loaded_soup.find_all('section'):
    for descendant in section.descendants:
        if descendant.name == 'a':
            if 'class' in descendant.attrs:
                if 'label-property-label' in descendant['class']:
                   print(descendant.attrs)
# Out:
# {'class': ['label-property-label'], 'href': 'https://cwlagos.com/property-label/available-for-rent/', 'style': ''}
# {'class': ['label-property-label'], 'href': 'https://cwlagos.com/property-label/available-for-rent/', 'style': ''}
# {'class': ['label-property-label'], 'href': 'https://cwlagos.com/property-label/available-for-sale/', 'style': ''}
# {'class': ['label-property-label'], 'href': 'https://cwlagos.com/property-label/available-for-sale/', 'style': ''}
# {'class': ['label-property-label'], 'href': 'https://cwlagos.com/property-label/available-for-sale/', 'style': ''}
# {'class': ['label-property-label'], 'href': 'https://cwlagos.com/property-label/available-for-sale/', 'style': ''}
# {'class': ['label-property-label'], 'href': 'https://cwlagos.com/property-label/available-for-sale/', 'style': ''}
# {'class': ['label-property-label'], 'href': 'https://cwlagos.com/property-label/available-for-sale/', 'style': ''}
# {'class': ['label-property-label'], 'href': 'https://cwlagos.com/property-label/available-for-sale/', 'style': ''}
# {'class': ['label-property-label'], 'href': 'https://cwlagos.com/property-label/available-for-sale/', 'style': ''}
# {'class': ['label-property-label'], 'href': 'https://cwlagos.com/property-label/available-for-sale/', 'style': ''}
# {'class': ['label-property-label'], 'href': 'https://cwlagos.com/property-label/available-for-sale/', 'style': ''}
# {'class': ['label-property-label'], 'href': 'https://cwlagos.com/property-label/available-for-sale/', 'style': ''}
# {'class': ['label-property-label'], 'href': 'https://cwlagos.com/property-label/available-for-sale/', 'style': ''}
# {'class': ['label-property-label'], 'href': 'https://cwlagos.com/property-label/available-for-sale/', 'style': ''}

# %%
property_labels = []
for section in loaded_soup.find_all('section'):
    for descendant in section.descendants:
        if descendant.name == 'a':
            if 'class' in descendant.attrs:
                if 'status-property-label' in descendant['class']:
                   property_labels.append(''.join(descendant.stripped_strings))
print(property_labels)
print(len(property_labels))
# Out:
# ['For Rent', 'For Rent', 'For Sale', 'For Rent', 'For Sale', 'For Sale', 'For Sale', 'For Sale', 'New Developments', 'For Sale', 'Land', 'For Sale', 'Land', 'For Sale', 'Land', 'For Sale', 'Land', 'For Sale', 'Land', 'For Sale', 'Land', 'For Sale', 'Land']
# 23

# %%
availability_labels = []
for section in loaded_soup.find_all('section'):
    for descendant in section.descendants:
        if descendant.name == 'a':
            if 'class' in descendant.attrs:
                if 'label-property-label' in descendant['class']:
                   availability_labels.append(''.join(descendant.stripped_strings))
print(availability_labels)    
print(len(availability_labels))
# Out:
# ['Available for rent', 'Available for rent', 'Available for sale', 'Available for sale', 'Available for sale', 'Available for sale', 'Available for sale', 'Available for sale', 'Available for sale', 'Available for sale', 'Available for sale', 'Available for sale', 'Available for sale', 'Available for sale', 'Available for sale']
# 15

# %%
price_labels = []
for section in loaded_soup.find_all('section'):
    for descendant in section.descendants:
        if descendant.name == 'div':
            if 'class' in descendant.attrs:
                if 'property-price' in descendant['class']:
                   price_labels.append(''.join(descendant.stripped_strings))
print(price_labels)    
print(len(price_labels))
# Out:
# ['NGN35,000,000', '#35,000,000', '#900,000,000', 'N100,000,000', '$1,100,000', '#950,000,000', '#1,500,000,000', 'NGN950,000,000', 'NGN4,300,000,000', 'NGN3,700,000', 'NGN3,500,000', 'NGN3,000,000', 'NGN3,500,000,000', 'NGN4,500,000,000', 'NGN4,000,000', 'NGN950,000,000', 'NGN25,000,000,000', 'NGN8,500,000,000', '$25000000']
# 19

# %%
property_type_labels = []
for section in loaded_soup.find_all('section'):
    for descendant in section.descendants:
        if descendant.name == 'a':
            if 'class' in descendant.attrs:
                if 'type-property' in descendant['class']:
                   property_type_labels.append(''.join(descendant.stripped_strings))
print(property_type_labels)    
print(len(property_type_labels))
# Out:
# ['Maisonette', 'Apartment', 'Maisonette', 'Detached', 'Maisonette', 'Terraced', 'Terraced', 'Maisonette']
# 8

# %%
location_labels = []
for section in loaded_soup.find_all('section'):
    for descendant in section.descendants:
        if descendant.name == 'a':
            if 'target' in descendant.attrs:
                if "_blank" in descendant['target']:
                   location_labels.append(''.join(descendant.stripped_strings))
print(location_labels)    
print(len(location_labels))
# Out:
# ['Dubai', 'Abuja', 'Short Stays', 'Ikoyi', 'Ikoyi, Lagos.', 'Ikoyi, Lagos.', 'Banana Island, Ikoyi, Lagos.', 'Ikoyi, Lagos.', 'Ikoyi, Lagos.', 'Old Ikoyi, Ikoyi, Lagos.', 'Ikoyi', 'Ikoyi', 'Ikoyi', 'Ikoyi', 'Ikoyi', 'Ikoyi', 'Ikoyi', 'Ikoyi', '', '', '', '', '']
# 23

# %%
property_labels = []
availability_labels = []
price_labels = []
property_type_labels = []
location_labels = []

for section in loaded_soup.find_all('section'):
    for descendant in section.descendants:
        if descendant.name == 'a':
            if 'class' in descendant.attrs:
                if 'status-property-label' in descendant['class']:
                   property_labels.append(''.join(descendant.stripped_strings))
                   
                   
for section in loaded_soup.find_all('section'):
    for descendant in section.descendants:
        if descendant.name == 'a':
            if 'class' in descendant.attrs:
                if 'label-property-label' in descendant['class']:
                   availability_labels.append(''.join(descendant.stripped_strings))
                   
                   
price_labels = []
for section in loaded_soup.find_all('section'):
    for descendant in section.descendants:
        if descendant.name == 'div':
            if 'class' in descendant.attrs:
                if 'property-price' in descendant['class']:
                   price_labels.append(''.join(descendant.stripped_strings))
                   
                   
property_type_labels = []
for section in loaded_soup.find_all('section'):
    for descendant in section.descendants:
        if descendant.name == 'a':
            if 'class' in descendant.attrs:
                if 'type-property' in descendant['class']:
                   property_type_labels.append(''.join(descendant.stripped_strings))
                   
                   
                   
location_labels = []
for section in loaded_soup.find_all('section'):
    for descendant in section.descendants:
        if descendant.name == 'a':
            if 'target' in descendant.attrs:
                if "_blank" in descendant['target']:
                   location_labels.append(''.join(descendant.stripped_strings))
   

print(property_labels)
print(len(property_labels))    

print(availability_labels)    
print(len(availability_labels))  

print(price_labels)    
print(len(price_labels)) 

print(property_type_labels)    
print(len(property_type_labels))  

print(location_labels)    
print(len(location_labels))
# Out:
# ['For Rent', 'For Rent', 'For Sale', 'For Rent', 'For Sale', 'For Sale', 'For Sale', 'For Sale', 'New Developments', 'For Sale', 'Land', 'For Sale', 'Land', 'For Sale', 'Land', 'For Sale', 'Land', 'For Sale', 'Land', 'For Sale', 'Land', 'For Sale', 'Land']
# 23
# ['Available for rent', 'Available for rent', 'Available for sale', 'Available for sale', 'Available for sale', 'Available for sale', 'Available for sale', 'Available for sale', 'Available for sale', 'Available for sale', 'Available for sale', 'Available for sale', 'Available for sale', 'Available for sale', 'Available for sale']
# 15
# ['NGN35,000,000', '#35,000,000', '#900,000,000', 'N100,000,000', '$1,100,000', '#950,000,000', '#1,500,000,000', 'NGN950,000,000', 'NGN4,300,000,000', 'NGN3,700,000', 'NGN3,500,000', 'NGN3,000,000', 'NGN3,500,000,000', 'NGN4,500,000,000', 'NGN4,000,000', 'NGN950,000,000', 'NGN25,000,000,000', 'NGN8,500,000,000', '$25000000']
# 19
# ['Maisonette', 'Apartment', 'Maisonette', 'Detached', 'Maisonette', 'Terraced', 'Terraced', 'Maisonette']
# 8
# ['Dubai', 'Abuja', 'Short Stays', 'Ikoyi', 'Ikoyi, Lagos.', 'Ikoyi, Lagos.', 'Banana Island, Ikoyi, Lagos.', 'Ikoyi, Lagos.', 'Ikoyi, Lagos.', 'Old Ikoyi, Ikoyi, Lagos.', 'Ikoyi', 'Ikoyi', 'Ikoyi', 'Ikoyi', 'Ikoyi', 'Ikoyi', 'Ikoyi', 'Ikoyi', '', '', '', '', '']
# 23

# %%
rows = []
for card in loaded_soup.select("article.property-item"):
    row = {}
    # price
    price = card.select_one("div.property-price")
    row["price_raw"] = price.get_text(strip=True) if price else None
    
    title = card.select_one("h2.property-title")
    row["title"] = title.get_text(strip=True) if title else None
        
    # location
    loc = card.select_one("span.property-location")
    if not loc:  # fallback to the <a target="_blank">
        loc = card.select_one("a[target=_blank]")
    row["location"] = loc.get_text(strip=True) if loc else None        
        
    # status 
    status = card.select_one("a.status-property-label")
    row["status"] = status.get_text(strip=True) if status else None
    
    # availability label
    avail = card.select_one("a.label-property-label")
    row["availability"] = avail.get_text(strip=True) if avail else None
    
    # property type
    ptype = card.select_one("a.type-property")
    row["property_type"] = ptype.get_text(strip=True) if ptype else None
    
    info  = card.select("div.property-meta")
    for div in info:
        text = div.get_text(strip=True)
        if "Beds" in text:
            row["beds"] = text.replace("Beds:", "").strip() if text.replace("Beds:", "").strip() != '-' else None
        elif "Baths" in text:
            row["baths"] = text.replace("Baths:", "").strip() if text.replace("Baths:", "").strip() != '-' else None
        elif "sqm" in text:
            row["area(sqm)"] = text.replace("sqm:", "").strip() if text.replace("sqm:", "").strip() != '-' else None
    
    
    # author
    author = card.select_one("div.name-author")
    row['author'] = author.get_text(strip=True) if author else None
    
    #post date
    date = card.select_one("div.property-postdate")
    date['post-date'] = date.get_text(strip=True) if date else None
    
    # detail page url
    detail = card.select_one("a")
    row["detail_url"] = detail["href"] if detail and detail.has_attr("href") else None
    
    rows.append(row)

print(len(rows))
# Out:
# 15

# %%
df = pd.DataFrame(rows)
df
# Out:
#            price_raw                                              title  \
# 0      NGN35,000,000                 2 Bedroom Maisonette + BQ in Ikoyi
# 1        #35,000,000                 4 Bedroom Furnished Apartment + BQ
# 2       #900,000,000                Luxury 3 Bedroom Maisonette with BQ
# 3       N100,000,000                    Luxury 5 Bedroom Detached House
# 4         $1,100,000  Exclusive 4 Bedroom Maisonette with Swimming Pool
# 5       #950,000,000        2 units of 4 Bedroom Terrace with a BQ Each
# 6     #1,500,000,000  Luxury 4 Bedroom Terrace with Private Rooftop ...
# 7     NGN950,000,000                          NEW DEVELOPMENTS IN IKOYI
# 8   NGN4,300,000,000                        Prime Land in Banana Island
# 9       NGN3,700,000                    Residential Land- Banana Island
# 10      NGN3,500,000                      Land Measuring 3300sqm- Ikoyi
# 11      NGN3,000,000                           Waterfront Land in Ikoyi
# 12  NGN3,500,000,000                       Land Measuring 750sqm- Ikoyi
# 13  NGN4,500,000,000                       Land Measuring 875sqm- Ikoyi
# 14      NGN4,000,000                                Prime Land in Ikoyi
#
#       status        availability property_type beds baths  \
# 0   For Rent  Available for rent    Maisonette    2     2
# 1   For Rent  Available for rent     Apartment    4     4
# 2   For Sale  Available for sale    Maisonette    3     3
# 3   For Rent  Available for sale      Detached    5     5
# 4   For Sale  Available for sale    Maisonette    4     4
# 5   For Sale  Available for sale      Terraced    4     4
# 6   For Sale  Available for sale      Terraced    4     4
# 7   For Sale  Available for sale    Maisonette    4     4
# 8   For Sale  Available for sale          None  NaN   NaN
# 9   For Sale  Available for sale          None  NaN   NaN
# 10  For Sale  Available for sale          None  NaN   NaN
# 11  For Sale  Available for sale          None  NaN   NaN
# 12  For Sale  Available for sale          None  NaN   NaN
# 13  For Sale  Available for sale          None  NaN   NaN
# 14  For Sale  Available for sale          None  NaN   NaN
#
#                         location            author  \
# 0                          Ikoyi          admin-cw
# 1                  Ikoyi, Lagos.          admin-cw
# 2                  Ikoyi, Lagos.  Adeyemi Fowosire
# 3   Banana Island, Ikoyi, Lagos.  Adeyemi Fowosire
# 4                  Ikoyi, Lagos.    Adaeze Ajomiwe
# 5                  Ikoyi, Lagos.  Adeyemi Fowosire
# 6       Old Ikoyi, Ikoyi, Lagos.              Rose
# 7                          Ikoyi          admin-cw
# 8                          Ikoyi          admin-cw
# 9                          Ikoyi          admin-cw
# 10                         Ikoyi          admin-cw
# 11                         Ikoyi          admin-cw
# 12                         Ikoyi          admin-cw
# 13                         Ikoyi          admin-cw
# 14                         Ikoyi          admin-cw
#
#                                            detail_url area(sqm)
# 0   https://cwlagos.com/property/2-bedroom-maisone...       NaN
# 1   https://cwlagos.com/property/4-bedroom-furnish...       NaN
# 2   https://cwlagos.com/property/luxury-3-bedroom-...       NaN
# 3   https://cwlagos.com/property/luxury-5-bedroom-...       NaN
# 4   https://cwlagos.com/property/exclusive-4-bedro...       NaN
# 5   https://cwlagos.com/property/2-units-of-4-bedr...       NaN
# 6   https://cwlagos.com/property/luxury-4-bedroom-...       NaN
# 7   https://cwlagos.com/property/new-developments-...       NaN
# 8   https://cwlagos.com/property/prime-land-in-ban...       852
# 9   https://cwlagos.com/property/residential-land-...      1000
# 10  https://cwlagos.com/property/land-measuring-33...      3300
# 11  https://cwlagos.com/property/waterfront-land-i...       NaN
# 12  https://cwlagos.com/property/land-measuring-75...       750
# 13  https://cwlagos.com/property/land-measuring-87...       875
# 14  https://cwlagos.com/property/prime-land-in-ikoyi/       NaN

# %%
df.to_csv('../data/raw/ikoyi_properties_sample.csv', index=False)

# %%
# getting specific insight from the individual listings page.

# first gettimng a detail page
url = 'https://cwlagos.com/property/4-bedroom-furnished-apartment-bq/'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

with open('../data/raw/property_detail_page.html', 'w', encoding='utf-8') as file:
    file.write(soup.prettify())


"""for card in loaded_soup.select("article.property-item"):
    
    detail = card.select_one("a")
    detail_url = detail["href"] if detail and detail.has_attr("href") else None
    print(detail_url)"""
# Out:
# 'for card in loaded_soup.select("article.property-item"):\n    \n    detail = card.select_one("a")\n    detail_url = detail["href"] if detail and detail.has_attr("href") else None\n    print(detail_url)'

# %%
with open('/Users/mac/Projects/Data Science projects/Lagos-Real-Estate-Market-Analysis/data/raw/property_detail_page.html', 'rb') as file:
    property_soup = BeautifulSoup(file)

# %%
if property_soup:
    print ("Successfully loaded the property detail page soup.")
else:
    print("This is never gonna happen cos i know my shii")
# Out:
# Successfully loaded the property detail page soup.

# %%
for amenity in property_soup.select('ul.list-check'):
    print(list(amenity.stripped_strings))
# Out:
# ['24hrs Power', '30kva generator', '5kva inverter', 'Balcony', 'BQ', 'Car Park', 'CCTV', 'Children Playground', 'Fitted Bathrooms', 'Fitted Kitchen', 'Fully Furnished', 'Gated Estate', 'Gym', 'Home Automation', 'Home Entertainment Unit', 'Jacuzzi', "Maid's Room", 'Rooftop Terrace', 'Swimming Pool', 'Walk-in Closet', 'WiFi']

# %% [markdown]
# ### Scraping the inner details of the listings

# %%
urls = []
for card in loaded_soup.select("article.property-item"):
    detail = card.select_one("a.property-image")
    detail_url = detail["href"] if detail and detail.has_attr("href") else None
    urls.append(detail_url)
print(len(urls))
# Out:
# 15

# %%
property_amenities = []

# %%
rows = []
for card in loaded_soup.select("article.property-item"):
    row = {}
    # price
    price = card.select_one("div.property-price")
    row["price_raw"] = price.get_text(strip=True) if price else None
    
    title = card.select_one("h2.property-title")
    row["title"] = title.get_text(strip=True) if title else None
        
    # location
    loc = card.select_one("span.property-location")
    if not loc:  # fallback to the <a target="_blank">
        loc = card.select_one("a[target=_blank]")
    row["location"] = loc.get_text(strip=True) if loc else None        
        
    # status 
    status = card.select_one("a.status-property-label")
    row["status"] = status.get_text(strip=True) if status else None
    
    # availability label
    avail = card.select_one("a.label-property-label")
    row["availability"] = avail.get_text(strip=True) if avail else None
    
    # property type
    ptype = card.select_one("a.type-property")
    row["property_type"] = ptype.get_text(strip=True) if ptype else None
    
    info  = card.select("div.property-meta")
    for div in info:
        text = div.get_text(strip=True)
        if "Beds" in text:
            row["beds"] = text.replace("Beds:", "").strip() if text.replace("Beds:", "").strip() != '-' else None
        elif "Baths" in text:
            row["baths"] = text.replace("Baths:", "").strip() if text.replace("Baths:", "").strip() != '-' else None
        elif "sqm" in text:
            row["area(sqm)"] = text.replace("sqm:", "").strip() if text.replace("sqm:", "").strip() != '-' else None
    
    # property detail page logic
    detail = card.select_one("a.property-image")
    detail_url = detail["href"] if detail and detail.has_attr("href") else None
    response = requests.get(detail_url)
    soup = BeautifulSoup(response.text, 'html.parser')
    for amenity in soup.select('ul.list-check'):
        for amenity in list(amenity.stripped_strings):
            row[amenity] = True

    # author
    author = card.select_one("div.name-author")
    row['author'] = author.get_text(strip=True) if author else None
    
    #post date
    date = card.select_one("div.property-postdate")
    date['post-date'] = date.get_text(strip=True) if date else None
    
    # detail page url
    detail = card.select_one("a")
    row["detail_url"] = detail["href"] if detail and detail.has_attr("href") else None
    
    rows.append(row)

print(len(rows))
# Out:
# 15

# %%
rows[3]
# Out:
# {'price_raw': 'N100,000,000',
#  'title': 'Luxury 5 Bedroom Detached House',
#  'location': 'Banana Island, Ikoyi, Lagos.',
#  'status': 'For Rent',
#  'availability': 'Available for sale',
#  'property_type': 'Detached',
#  'beds': '5',
#  'baths': '5',
#  '24hrs Power': True,
#  '30kva generator': True,
#  '5kva inverter': True,
#  'Balcony': True,
#  'BQ': True,
#  'Car Park': True,
#  'CCTV': True,
#  'Children Playground': True,
#  'Cinema': True,
#  'Fitted Bathrooms': True,
#  'Fitted Kitchen': True,
#  'Garden': True,
#  'Gated Estate': True,
#  'Gym': True,
#  'Home Automation': True,
#  'Home Entertainment Unit': True,
#  'Jacuzzi': True,
#  "Maid's Room": True,
#  'Rooftop Terrace': True,
#  'Study': True,
#  'Swimming Pool': True,
#  'Walk-in Closet': True,
#  'WiFi': True,
#  'author': 'Adeyemi Fowosire',
#  'detail_url': 'https://cwlagos.com/property/luxury-5-bedroom-detached-house-with-en-suite-bq/'}

# %%
detailed_df = pd.DataFrame(rows)
detailed_df
# Out:
#            price_raw                                              title  \
# 0      NGN35,000,000                 2 Bedroom Maisonette + BQ in Ikoyi
# 1        #35,000,000                 4 Bedroom Furnished Apartment + BQ
# 2       #900,000,000                Luxury 3 Bedroom Maisonette with BQ
# 3       N100,000,000                    Luxury 5 Bedroom Detached House
# 4         $1,100,000  Exclusive 4 Bedroom Maisonette with Swimming Pool
# 5       #950,000,000        2 units of 4 Bedroom Terrace with a BQ Each
# 6     #1,500,000,000  Luxury 4 Bedroom Terrace with Private Rooftop ...
# 7     NGN108,000,000                         3 BEDROOM APARTMENT- IKOYI
# 8      NGN25,000,000                          4-Bedroom Terrace – Ikoyi
# 9     NGN250,000,000                        3-Bedroom Apartment – Ikoyi
# 10    NGN950,000,000                          NEW DEVELOPMENTS IN IKOYI
# 11  NGN4,300,000,000                        Prime Land in Banana Island
# 12      NGN3,700,000                    Residential Land- Banana Island
# 13      NGN3,500,000                      Land Measuring 3300sqm- Ikoyi
# 14      NGN3,000,000                           Waterfront Land in Ikoyi
#
#                         location    status        availability property_type  \
# 0                          Ikoyi  For Rent  Available for rent    Maisonette
# 1                  Ikoyi, Lagos.  For Rent  Available for rent     Apartment
# 2                  Ikoyi, Lagos.  For Sale  Available for sale    Maisonette
# 3   Banana Island, Ikoyi, Lagos.  For Rent  Available for sale      Detached
# 4                  Ikoyi, Lagos.  For Sale  Available for sale    Maisonette
# 5                  Ikoyi, Lagos.  For Sale  Available for sale      Terraced
# 6       Old Ikoyi, Ikoyi, Lagos.  For Sale  Available for sale      Terraced
# 7                          Ikoyi  For Rent  Available for rent     Apartment
# 8                          Ikoyi  For Rent  Available for rent      Terraced
# 9                          Ikoyi  For Sale  Available for sale     Apartment
# 10                         Ikoyi  For Sale  Available for sale    Maisonette
# 11                         Ikoyi  For Sale  Available for sale          None
# 12                         Ikoyi  For Sale  Available for sale          None
# 13                         Ikoyi  For Sale  Available for sale          None
# 14                         Ikoyi  For Sale  Available for sale          None
#
#    beds baths            author  \
# 0     2     2          admin-cw
# 1     4     4          admin-cw
# 2     3     3  Adeyemi Fowosire
# 3     5     5  Adeyemi Fowosire
# 4     4     4    Adaeze Ajomiwe
# 5     4     4  Adeyemi Fowosire
# 6     4     4              Rose
# 7     3     3          admin-cw
# 8     4     4          admin-cw
# 9     3     3          admin-cw
# 10    4     4          admin-cw
# 11  NaN   NaN          admin-cw
# 12  NaN   NaN          admin-cw
# 13  NaN   NaN          admin-cw
# 14  NaN   NaN          admin-cw
#
#                                            detail_url  ... Rooftop Terrace  \
# 0   https://cwlagos.com/property/2-bedroom-maisone...  ...             NaN
# 1   https://cwlagos.com/property/4-bedroom-furnish...  ...            True
# 2   https://cwlagos.com/property/luxury-3-bedroom-...  ...            True
# 3   https://cwlagos.com/property/luxury-5-bedroom-...  ...            True
# 4   https://cwlagos.com/property/exclusive-4-bedro...  ...            True
# 5   https://cwlagos.com/property/2-units-of-4-bedr...  ...            True
# 6   https://cwlagos.com/property/luxury-4-bedroom-...  ...            True
# 7   https://cwlagos.com/property/3-bedroom-apartme...  ...             NaN
# 8   https://cwlagos.com/property/4-bedroom-terrace...  ...             NaN
# 9   https://cwlagos.com/property/3-bedroom-apartme...  ...             NaN
# 10  https://cwlagos.com/property/new-developments-...  ...             NaN
# 11  https://cwlagos.com/property/prime-land-in-ban...  ...             NaN
# 12  https://cwlagos.com/property/residential-land-...  ...             NaN
# 13  https://cwlagos.com/property/land-measuring-33...  ...             NaN
# 14  https://cwlagos.com/property/waterfront-land-i...  ...             NaN
#
#    Swimming Pool Walk-in Closet  WiFi Golf Course View Private Elevator Study  \
# 0            NaN            NaN   NaN              NaN              NaN   NaN
# 1           True           True  True              NaN              NaN   NaN
# 2           True           True  True             True             True  True
# 3           True           True  True              NaN              NaN  True
# 4           True           True  True              NaN             True  True
# 5           True           True  True              NaN              NaN   NaN
# 6           True           True  True              NaN             True   NaN
# 7            NaN            NaN   NaN              NaN              NaN   NaN
# 8            NaN            NaN   NaN              NaN              NaN   NaN
# 9            NaN            NaN   NaN              NaN              NaN   NaN
# 10           NaN            NaN   NaN              NaN              NaN   NaN
# 11           NaN            NaN   NaN              NaN              NaN   NaN
# 12           NaN            NaN   NaN              NaN              NaN   NaN
# 13           NaN            NaN   NaN              NaN              NaN   NaN
# 14           NaN            NaN   NaN              NaN              NaN   NaN
#
#    Cinema Garden area(sqm)
# 0     NaN    NaN       NaN
# 1     NaN    NaN       NaN
# 2     NaN    NaN       NaN
# 3    True   True       NaN
# 4     NaN   True       NaN
# 5     NaN    NaN       NaN
# 6     NaN    NaN       NaN
# 7     NaN    NaN       NaN
# 8     NaN    NaN       NaN
# 9     NaN    NaN       NaN
# 10    NaN    NaN       NaN
# 11    NaN    NaN       852
# 12    NaN    NaN      1000
# 13    NaN    NaN      3300
# 14    NaN    NaN       NaN
#
# [15 rows x 37 columns]

# %%
detailed_df.to_csv('../data/raw/ikoyi_properties_detail_sample.csv', index=False)

# %% [markdown]
# ### Pagination and scraping multiple pages

# %%
START_URL = "https://cwlagos.com/property-location/ikoyi/" 
NEXT_PAGE_SELECTOR = "a.next.page-numbers"

rows = []
current_page_url = START_URL

while current_page_url:
    
    print(f"Scraping list page: {current_page_url}\n")
    
    try:
        page_response = requests.get(current_page_url)
        page_response.raise_for_status() 
    except requests.RequestException as e:
        print(f"Error fetching list page {current_page_url}: {e}")
        break 

    loaded_soup = BeautifulSoup(page_response.text, 'html.parser')

    #  4. Loop Through Property Cards on Current Page
    cards_on_page = loaded_soup.select("article.property-item")
    if not cards_on_page:
        print("No property cards found on this page. Ending scrape.")
        break 

    for card in cards_on_page:
        row = {}
        
        # Scrape List Page Data
        price = card.select_one("div.property-price")
        row["price_raw"] = price.get_text(strip=True) if price else None
        
        title = card.select_one("h2.property-title")
        row["title"] = title.get_text(strip=True) if title else None
            
        loc = card.select_one("div.property-location a")
        row["location"] = loc.get_text(strip=True) if loc else None        
            
        status = card.select_one("a.status-property-label")
        row["status"] = status.get_text(strip=True) if status else None
        
        avail = card.select_one("a.label-property-label")
        row["availability"] = avail.get_text(strip=True) if avail else None
        
        ptype = card.select_one("a.type-property")
        row["property_type"] = ptype.get_text(strip=True) if ptype else None
        
        info = card.select("div.property-meta")
        for div in info:
            text = div.get_text(strip=True)
            if "Beds" in text:
                row["beds"] = text.replace("Beds:", "").strip() if text.replace("Beds:", "").strip() != '-' else None
            elif "Baths" in text:
                row["baths"] = text.replace("Baths:", "").strip() if text.replace("Baths:", "").strip() != '-' else None
            elif "sqm" in text:
                row["area(sqm)"] = text.replace("sqm:", "").strip() if text.replace("sqm:", "").strip() != '-' else None
        
        author = card.select_one("div.name-author")
        row['author'] = author.get_text(strip=True) if author else None
        
        date = card.select_one("div.property-postdate")
        row['post-date'] = date.get_text(strip=True) if date else None
        

        detail = card.select_one("a.property-image")
        detail_url = detail["href"] if detail and detail.has_attr("href") else None
        
        row["detail_url"] = detail_url
        
        if detail_url:
            print(f"Scraping detail page: {row['title']}")
            try:
                time.sleep(1) 
                response = requests.get(detail_url)
                response.raise_for_status()
                time.sleep(1)
                soup = BeautifulSoup(response.text, 'html.parser')
                
                for amenity_list_ul in soup.select('ul.list-check'):
                    for amenity_name in list(amenity_list_ul.stripped_strings):
                        if amenity_name:
                            row[amenity_name] = True
                            
            except requests.RequestException as e:
                print(f" Could not scrape detail page {detail_url}: {e}")

        
        detail = card.select_one("a.property-image")
        row["detail_url"] = detail_url
        rows.append(row)
        
    next_page_link = loaded_soup.select_one(NEXT_PAGE_SELECTOR)
    
    if next_page_link:
        current_page_url = next_page_link['href'] 
        
        print(f"\n Found next page: {current_page_url}")
        time.sleep(3)
    else:
        print("\n No more 'next page' links found. Scrape complete.")
        current_page_url = None 


print(f"Scraping finished. Total properties found: {len(rows)}")
# Out:
# Scraping list page: https://cwlagos.com/property-location/ikoyi/
#
# Scraping detail page: 2 Bedroom Maisonette + BQ in Ikoyi
# Scraping detail page: 4 Bedroom Furnished Apartment + BQ
# Scraping detail page: Luxury 3 Bedroom Maisonette with BQ
# Scraping detail page: Luxury 5 Bedroom Detached House
# Scraping detail page: Exclusive 4 Bedroom Maisonette with Swimming Pool
# Scraping detail page: 2 units of 4 Bedroom Terrace with a BQ Each
# Scraping detail page: Luxury 4 Bedroom Terrace with Private Rooftop Swimming Pool
# Scraping detail page: 3 BEDROOM APARTMENT- IKOYI
# Scraping detail page: 4-Bedroom Terrace – Ikoyi
# Scraping detail page: 3-Bedroom Apartment – Ikoyi
# Scraping detail page: NEW DEVELOPMENTS IN IKOYI
# Scraping detail page: Prime Land in Banana Island
# Scraping detail page: Residential Land- Banana Island
# Scraping detail page: Land Measuring 3300sqm- Ikoyi
# Scraping detail page: Waterfront Land in Ikoyi
#
#  Found next page: https://cwlagos.com/property-location/ikoyi/page/2/
# Scraping list page: https://cwlagos.com/property-location/ikoyi/page/2/
#
# Scraping detail page: Land Measuring 750sqm- Ikoyi
# Scraping detail page: Land Measuring 875sqm- Ikoyi
# Scraping detail page: Prime Land in Ikoyi
# Scraping detail page: 4-Bedroom Terrace with BQ- Ikoyi
# Scraping detail page: 3 BEDROOM TERRACE HOUSE- IKOYI
# Scraping detail page: WATERFRONT PENTHOUSE | IKOYI
# Scraping detail page: 5-BEDROOM TERRACE + BQ- IKOYI
# Scraping detail page: 5-BEDROOM DETACHED DUPLEX- IKOYI
# Scraping detail page: 5-BEDROOM LUXURY TERRACE- IKOYI
# Scraping detail page: 5-BEDROOM DETACHED DUPLEX-IKOYI
# Scraping detail page: 4-BEDROOM TERRACE DUPLEX- IKOYI
# Scraping detail page: 6 Units of 3-Bed Apartment- Ikoyi
# Scraping detail page: LUXURY APARTMENTS- IKOYI
# Scraping detail page: JOINT VENTURE OPPORTUNITY | IKOYI
# Scraping detail page: Land Measuring 2419sqm- Ikoyi
#
#  Found next page: https://cwlagos.com/property-location/ikoyi/page/3/
# Scraping list page: https://cwlagos.com/property-location/ikoyi/page/3/
#
# Scraping detail page: Land Measuring 1580sqm in Ikoyi
# Scraping detail page: Land Measuring 3200sqm in Ikoyi
# Scraping detail page: MINI FLAT | LEKKI PHASE 1
# Scraping detail page: 3-BEDROOM APARTMENT| IKOYI
# Scraping detail page: 3-BEDROOM APARTMENTS | OLD IKOYI
# Scraping detail page: 3-BEDROOM APARTMENT +BQ | IKOYI
# Scraping detail page: 3-BEDROOM APARTMENT– IKOYI
# Scraping detail page: 3-BED APARTMENT – BANANA ISLAND, IKOYI
# Scraping detail page: 5-BEDROOM DETACHED DUPLEX – IKOYI
# Scraping detail page: 3-BED TERRACE APARTMENT – BANANA ISLAND, IKOYI
# Scraping detail page: 3-BEDROOM APARTMENT – OLD IKOYI
# Scraping detail page: Land Measuring 1080sqm- Ikoyi
# Scraping detail page: Land Measuring 750sqm- Ikoyi
# Scraping detail page: 4-Bedroom Apartment in Ikoyi
# Scraping detail page: 3-Bedroom Penthouse Apartment + BQ-Ikoyi
#
#  Found next page: https://cwlagos.com/property-location/ikoyi/page/4/
# Scraping list page: https://cwlagos.com/property-location/ikoyi/page/4/
#
# Scraping detail page: 3-Bedroom Apartment + BQ-Ikoyi
# Scraping detail page: New Development Apartments- Ikoyi
# Scraping detail page: JOINT VENTURE LAND- IKOYI
# Scraping detail page: Land Measuring 1580sqm- Ikoyi
# Scraping detail page: New Development Apartments- Ikoyi
# Scraping detail page: 9-BED MANSION FOR COMMERCIAL USE | OLD IKOYI
# Scraping detail page: 1 BEDROOM MINI FLAT | OLD IKOYI
# Scraping detail page: 3 BEDROOM APARTMENT + BQ | OLD IKOYI
# Scraping detail page: Residential Development- Banana Island, Ikoyi
# Scraping detail page: 3-Bedroom Apartment + BQ- Ikoyi
# Scraping detail page: 3-Bedroom Maisonette+BQ – Old Ikoyi
# Scraping detail page: Land Measuring 2419sqm- Ikoyi
# Scraping detail page: JOINT VENTURE OPPORTUNITY — IKOYI
# Scraping detail page: 4 BEDROOM TERRACE — IKOYI
# Scraping detail page: 5 BEDROOM SEMI-DETACHED || OLD IKOYI
#
#  Found next page: https://cwlagos.com/property-location/ikoyi/page/5/
# Scraping list page: https://cwlagos.com/property-location/ikoyi/page/5/
#
# Scraping detail page: 5-Bedroom Terrace| Old Ikoyi
# Scraping detail page: 4-Bedroom Maisonette |Ikoyi
# Scraping detail page: 5-Bedroom Fully Detached House| Ikoyi
# Scraping detail page: 3-Bedroom Apartment| Ikoyi
# Scraping detail page: 4-Bedroom Terrace Duplex+BQ| Old Ikoyi
# Scraping detail page: 3-Bedroom Apartment| Ikoyi
# Scraping detail page: 3-Bedroom Apartment| Old Ikoyi
# Scraping detail page: 4-Bedroom Maisonette | Ikoyi
# Scraping detail page: 5-Bed Detached Duplex+2 BQs| Old Ikoyi
# Scraping detail page: Multiple Office| Old Ikoyi
# Scraping detail page: 4-Bedroom Terrace Duplex+BQ –Ikoyi
# Scraping detail page: 4 BEDROOM APARTMENT+BQ | BANANA ISLAND, IKOYI
# Scraping detail page: 3 BEDROOM APARTMENT |IKOYI
# Scraping detail page: 8 UNITS OF 3 & 5-BEDROOM |IKOYI
# Scraping detail page: 4-BED SEMI-DETACHED DUPLEX |IKOYI
#
#  Found next page: https://cwlagos.com/property-location/ikoyi/page/6/
# Scraping list page: https://cwlagos.com/property-location/ikoyi/page/6/
#
# Scraping detail page: 3-BEDROOM APARTMENT | IKOYI
# Scraping detail page: 5-BED FULLY DETACHED DUPLEX | IKOYI
# Scraping detail page: 9-BEDROOM MANSION | OLD IKOYI
# Scraping detail page: FULLY FURNISHED 3-BEDROOM FLAT- IKOYI
# Scraping detail page: 1-BEDROOM APARTMENT- IKOYI
# Scraping detail page: 12 UNITS OF 3-BED APARTMENTS- IKOYI
# Scraping detail page: 1-BEDROOM APARTMENT- IKOYI
# Scraping detail page: Land Measuring 3159sqm in Ikoyi
# Scraping detail page: 4-BED MAISONETTE PENTHOUSE- IKOYI
# Scraping detail page: 4-BEDROOM TERRACE+STUDY & BQ |IKOYI
# Scraping detail page: 3-BEDROOM APARTMENT| IKOYI
# Scraping detail page: SELF-CONTAIN FLAT | OLD IKOYI
# Scraping detail page: 4-BED PENTHOUSE MAISONETTE+BQ|IKOYI
# Scraping detail page: 1-BEDROOM FLAT| OLD IKOYI
# Scraping detail page: 4-BED SEMI-DETACHED HOUSE+2 BQs| IKOYI
#
#  Found next page: https://cwlagos.com/property-location/ikoyi/page/7/
# Scraping list page: https://cwlagos.com/property-location/ikoyi/page/7/
#
# Scraping detail page: 4-BEDROOM APARTMENT| IKOYI
# Scraping detail page: 4-BED MAISONETTE + BQ | IKOYI
# Scraping detail page: Land Measuring 1000sqm in Ikoyi
# Scraping detail page: Land Measuring 2805sqm in Ikoyi
# Scraping detail page: Prime Lands in Ikoyi
# Scraping detail page: Land Measuring 1300sqm in Ikoyi
# Scraping detail page: 5-Bedroom Semi-Detached Duplex – Ikoyi
# Scraping detail page: 4-Bed Terrace+BQ – Banana Island, Ikoyi
# Scraping detail page: 5-Bedroom Property with 3 BQs
# Scraping detail page: Zurii Residence — New Mixed-Unit Development
# Scraping detail page: Studio Apartment– Banana Island, Ikoyi
# Scraping detail page: Residential Land – Old Ikoyi
# Scraping detail page: 4-Floor Office Block
# Scraping detail page: 3-Bedroom Apartment | Ikoyi
# Scraping detail page: 5-Bed Semi-Detached Duplex in Ikoyi
#
#  Found next page: https://cwlagos.com/property-location/ikoyi/page/8/
# Scraping list page: https://cwlagos.com/property-location/ikoyi/page/8/
#
# Scraping detail page: 4-Bedroom Apartment in Ikoyi
# Scraping detail page: 4-Bedroom Shortlet Apartment in Ikoyi
# Scraping detail page: 5-Bedroom Penthouse– Ikoyi
# Scraping detail page: 6-Bed Fully Detached Duplex in Ikoyi
# Scraping detail page: 13 Units of 3-Bedroom Apartments– Ikoyi
# Scraping detail page: Land Measuring 5000sqm in Ikoyi
# Scraping detail page: 3-Bedroom Maisonette (4th Floor) — Ikoyi
# Scraping detail page: 3-Bedroom Maisonette – Ikoyi
# Scraping detail page: Joint Venture (JV) Opportunity in Prime Ikoyi
# Scraping detail page: 3-Bed Furnished Apartment + BQ| Old Ikoyi
# Scraping detail page: 2-Bed Penthouse Apartment + BQ | Ikoyi
# Scraping detail page: 4-Bedroom Terrace Duplex + BQ | Ikoyi
# Scraping detail page: 4-Bedroom Terrace Duplex + BQ | Ikoyi
# Scraping detail page: 3-Bed Apartment + BQ | Old Ikoyi
# Scraping detail page: 1-Bedroom Apartment  – Ikoyi
#
#  Found next page: https://cwlagos.com/property-location/ikoyi/page/9/
# Scraping list page: https://cwlagos.com/property-location/ikoyi/page/9/
#
# Scraping detail page: Waterfront Land– Banana Island, Ikoyi
# Scraping detail page: Land Measuring 900sqm in Ikoyi
# Scraping detail page: Land Measuring 875sqm in Ikoyi
# Scraping detail page: 4-Bed Detached House with BQs – Ikoyi
# Scraping detail page: 2-Bedroom Maisonette in Ikoyi
# Scraping detail page: 4-Bedroom + BQ | Banana Island
# Scraping detail page: 3-Bedroom Terrace | Ikoyi
# Scraping detail page: 3-Bed + BQ Apartment | Old Ikoyi
# Scraping detail page: 4 Bedroom Terrace Duplex for sale ikoyi
# Scraping detail page: 3-Bedroom Apartment for in Ikoyi
# Scraping detail page: 4-Bed Semi-Detached Duplex + 2 BQ | Ikoyi
# Scraping detail page: Land Measuring 1000sqm in Ikoyi
# Scraping detail page: Five-Bed Duplex in Banana Island, Ikoyi
# Scraping detail page: Commercial Lease145 SQM Office Space in Ikoyi
# Scraping detail page: 4Bed Maisonette Penthouse+2BQs in Old Ikoyi
#
#  Found next page: https://cwlagos.com/property-location/ikoyi/page/10/
# Scraping list page: https://cwlagos.com/property-location/ikoyi/page/10/
#
# Scraping detail page: Luxury Units at Ikoyi
# Scraping detail page: 1-Bedroom Penthouse in Old Ikoyi
# Scraping detail page: 3-Bedroom Terrace Duplex in Old Ikoyi
# Scraping detail page: 3-Bedroom Penthouse in Ikoyi
# Scraping detail page: 3-Bedroom Apartment in Banana Island, Ikoyi
# Scraping detail page: 4-Bed Semi-Detached House in Ikoyi
# Scraping detail page: 4-Bed Waterfront Maisonette in Ikoyi
# Scraping detail page: 4-Bedroom Maisonette in Ikoyi
# Scraping detail page: 5-Bedroom Detached House in Banana Island
# Scraping detail page: 6-Bedroom Detached House in Banana Island
# Scraping detail page: 145sqm Commercial Space in Ikoyi
# Scraping detail page: 145sqm Office Space
# Scraping detail page: 2-Bedroom Apartment in Ikoyi
# Scraping detail page: 2-Bedroom Apartment in Ikoyi
# Scraping detail page: 29 Units of 3-Bedroom Flats in Ikoyi
#
#  Found next page: https://cwlagos.com/property-location/ikoyi/page/11/
# Scraping list page: https://cwlagos.com/property-location/ikoyi/page/11/
#
# Scraping detail page: Two plots of Land Measuring 500sqm in Ikoyi
# Scraping detail page: Land Measuring 1500sqm in Ikoyi
# Scraping detail page: 4-Bedroom Apartment in Ikoyi
# Scraping detail page: 1, 2 & 3 Bedroom Apartments in Ikoyi
# Scraping detail page: 3-Bedroom Apartments in Ikoyi
# Scraping detail page: 2-Bedroom Service Flat in Ikoyi
# Scraping detail page: 4-Bedroom Terrace in Ikoyi
# Scraping detail page: Land Measuring 1440sqm in Ikoyi
# Scraping detail page: Land Measuring 600sqm in Banana Island
# Scraping detail page: 2-Bedroom Apartment in Ikoyi
# Scraping detail page: 3 Bedroom Apartment, Ikoyi
# Scraping detail page: 4 Bedroom Terrace in Ikoyi
# Scraping detail page: 3 Bedroom Apartment in Old Ikoyi
# Scraping detail page: 3 Bedroom Apartment in Ikoyi
# Scraping detail page: 3 BEDROOM APARTMENT IN IKOYI
#
#  Found next page: https://cwlagos.com/property-location/ikoyi/page/12/
# Scraping list page: https://cwlagos.com/property-location/ikoyi/page/12/
#
# Scraping detail page: 3 BEDROOM APARTMENT IN IKOYI
# Scraping detail page: 3 BEDROOM APARTMENT IN IKOYI
# Scraping detail page: 4-BEDROOM MAISONETTE IN IKOYI
# Scraping detail page: 3 BEDROOM APARTMENT IN IKOYI
# Scraping detail page: Luxury 5 Bedroom Maisonette  Apartment
# Scraping detail page: 3-Bedroom Apartment with BQ
# Scraping detail page: 5 BEDROOM DETACHED DUPLEX IN IKOYI
# Scraping detail page: DETACHED 5 BEDROOM DUPLEX IN IKOYI
# Scraping detail page: 1 BEDROOM APARTMENT IN IKOYI
# Scraping detail page: 3 BEDROOM APARTMENT IN IKOYI
# Scraping detail page: 2 BEDROOM APARTMENT IN IKOYI
# Scraping detail page: 3-Bedroom Apartment with Bq in Ikoyi
# Scraping detail page: Penthouse 3-Bed Apartment + Bq in Ikoyi
# Scraping detail page: 4-Bedroom Maisonette in Ikoyi
# Scraping detail page: 4-Bedroom Terrace + Bq in Ikoyi
#
#  Found next page: https://cwlagos.com/property-location/ikoyi/page/13/
# Scraping list page: https://cwlagos.com/property-location/ikoyi/page/13/
#
# Scraping detail page: Detached Commercial Building
# Scraping detail page: 4-Bedroom Terrace in Ikoyi
# Scraping detail page: 3-Bedroom Apartment in Ikoyi
# Scraping detail page: 4-Bedroom Apartment in Ikoyi
# Scraping detail page: 4 bedroom apartment in Ikoyi
# Scraping detail page: 5-Bedroom Maisonette in Ikoyi
# Scraping detail page: 87sqm Open- Plan Office Space in Ikoyi
# Scraping detail page: 3-Bedroom Flats
# Scraping detail page: 4-Bedroom Terrace Duplex with BQ
# Scraping detail page: 1 Bedroom Miniflat in Ikoyi
# Scraping detail page: 3 Bedroom Apartment + BQ in Ikoyi
# Scraping detail page: 1 Bedroom Apartment in Ikoyi
# Scraping detail page: Land Measuring 500-3100sqm in Ikoyi
# Scraping detail page: Land Measuring 1500sqm in Ikoyi
# Scraping detail page: Land Measuring 1000sqm in Ikoyi
#
#  Found next page: https://cwlagos.com/property-location/ikoyi/page/14/
# Scraping list page: https://cwlagos.com/property-location/ikoyi/page/14/
#
# Scraping detail page: 6 plots of 1000sqm Land in Ikoyi
# Scraping detail page: Waterfront Land in Ikoyi
# Scraping detail page: Land Measuring 1500sqm in Ikoyi
# Scraping detail page: Land Measuring 7441sqm in Ikoyi
# Scraping detail page: Land Measuring 2797sqm in Ikoyi
# Scraping detail page: Land Measuring 20000sqm in Ikoyi
# Scraping detail page: 2-Bedroom Maisonette + BQ in Ikoyi
# Scraping detail page: 3-Bedroom Flat + BQ in Ikoyi
# Scraping detail page: 3-Bedroom Apartment in Ikoyi
# Scraping detail page: 2 Bedroom Apartment in Old Ikoyi
# Scraping detail page: 4 Bedroom Apartment in Old Ikoyi
# Scraping detail page: 4 Bedroom Maisonette in Old Ikoyi
# Scraping detail page: 4 Bedroom Terrace in Old Ikoyi
# Scraping detail page: 4 Bedroom Terrace in Old Ikoyi
# Scraping detail page: 1 Bedroom Mini flat in Ikoyi
#
#  Found next page: https://cwlagos.com/property-location/ikoyi/page/15/
# Scraping list page: https://cwlagos.com/property-location/ikoyi/page/15/
#
# Scraping detail page: 3 Bedroom Apartment + BQ in Ikoyi
# Scraping detail page: 4 Bedroom Apartment + BQ in Ikoyi
# Scraping detail page: 2 Bedroom Apartment in Ikoyi
# Scraping detail page: 3 Bedroom Apartment + BQ in Ikoyi
# Scraping detail page: Land Measuring 500 and 650sqm in Ikoyi
# Scraping detail page: 500sqm Bareland in ParkView Estate, Ikoyi
# Scraping detail page: Lands Measuring 1201 and 1386sqm in Banana Island
# Scraping detail page: Land Measuring 2709sqm in Ikoyi
# Scraping detail page: 3 Bedroom Flat + BQ in Ikoyi
# Scraping detail page: 2 Bedroom Apartment in Ikoyi
# Scraping detail page: 2-Bedroom Apartment in Ikoyi
# Scraping detail page: 4 Bedroom Semi Detached House in Ikoyi
# Scraping detail page: 4 Bedroom Apartment in Ikoyi
# Scraping detail page: Office Space Measuring 119sqm in Ikoyi
# Scraping detail page: 3 Bedroom Terrace + BQ and Studyroom in Ikoyi
#
#  Found next page: https://cwlagos.com/property-location/ikoyi/page/16/
# Scraping list page: https://cwlagos.com/property-location/ikoyi/page/16/
#
# Scraping detail page: 4 Bedroom Apartment +BQ in Ikoyi
# Scraping detail page: 4 Bedroom Apartment + BQ in Ikoyi
# Scraping detail page: 4 Bedroom Apartment and Penthouse Maisonette in Ikoyi
# Scraping detail page: 3 Bedroom Maisonette in Ikoyi
# Scraping detail page: Land Measuring 1000sqm in Ikoyi
# Scraping detail page: Lands Measuring 500sqm in Ikoyi
# Scraping detail page: Land Measuring 13000sqm in Ikoyi
# Scraping detail page: Land Measuring 7700sqm in Ikoyi
# Scraping detail page: Land Measuring 5913sqm in Ikoyi
# Scraping detail page: Land Measuring 2042sqm in Ikoyi
# Scraping detail page: Land Measuring 1223sqm in Ikoyi
# Scraping detail page: Land Measuring 5,750sqm in Ikoyi
# Scraping detail page: 4 Bedroom Terrace in Ikoyi
# Scraping detail page: 3-Bedroom Apartment for in Ikoyi
# Scraping detail page: 3 Bedroom Furnished Apartment in Ikoyi
#
#  Found next page: https://cwlagos.com/property-location/ikoyi/page/17/
# Scraping list page: https://cwlagos.com/property-location/ikoyi/page/17/
#
# Scraping detail page: 5 Bedroom Fully Detached Duplex in Ikoyi
# Scraping detail page: Commercial/ Residential 5 Bed detached house + BQ in Ikoyi
# Scraping detail page: 2 Bedroom Apartment in Ikoyi
# Scraping detail page: Fully Furnished Twin- Building Complex in Ikoyi
# Scraping detail page: Furnished 3 Bedroom Maisonette + Office Room in Ikoyi
# Scraping detail page: Newly Built 4 Bedroom Maisonette + BQ in Ikoyi
# Scraping detail page: 2 Bedroom Apartment plus BQ in Ikoyi
# Scraping detail page: Land Measuring 4395.875sqm in Ikoyi
# Scraping detail page: Land Measuring 4000sqm in Ikoyi
# Scraping detail page: Land Measuring 2600sqm in Ikoyi
# Scraping detail page: Land Measuring 2100sqm in Ikoyi
# Scraping detail page: 5 Bedroom fully Detached House in Ikoyi
# Scraping detail page: Land Measuring 650sqm in Ikoyi
# Scraping detail page: Land Measuring 1052sqm in Ikoyi
# Scraping detail page: Land Measuring 500sqm in Ikoyi
#
#  Found next page: https://cwlagos.com/property-location/ikoyi/page/18/
# Scraping list page: https://cwlagos.com/property-location/ikoyi/page/18/
#
# Scraping detail page: Land Measuring 1000sqm in Ikoyi
# Scraping detail page: Land Measuring 500sqm in Ikoyi
# Scraping detail page: 4 Bedroom Semi Detached House in Ikoyi
# Scraping detail page: 4 Bedroom Terrace in Ikoyi
# Scraping detail page: 2 Bedroom Apartment in Ikoyi
# Scraping detail page: 3 Bed Penthouse in Ikoyi
# Scraping detail page: 4 Bedroom Maisonette in Ikoyi
# Scraping detail page: Waterfront 3bedroom Apartment + Bq in Ikoyi
# Scraping detail page: 5 Bedroom Apartment in Ikoyi
# Scraping detail page: 4 Bedroom Apartment in Ikoyi
# Scraping detail page: 3 Bedroom Apartment in Ikoyi
# Scraping detail page: 2 Bedroom Apartment Available for Rent in Ikoyi
# Scraping detail page: Six Bedroom Fully Detached house in Banana Island
# Scraping detail page: Land Measuring 529m in Ikoyi
# Scraping detail page: Land measuring 1000sqm in Ikoyi
#
#  Found next page: https://cwlagos.com/property-location/ikoyi/page/19/
# Scraping list page: https://cwlagos.com/property-location/ikoyi/page/19/
#
# Scraping detail page: Land Measuring 700m² in Banana island
# Scraping detail page: TERRACE IN BANANA ISLAND IKOYI
# Scraping detail page: Prime 6,000SQM Bareland in Ikoyi
# Scraping detail page: 4 Bedroom Penthouse
# Scraping detail page: 4 Bedroom Apartment with BQ
# Scraping detail page: 4 Bedroom Maisonette with BQ
# Scraping detail page: 13,000 sqm Empty Corner Piece Land
# Scraping detail page: Land Measuring Two Plots of 500 sqm
# Scraping detail page: Land Measuring Approximately 600 sqm Driveway Plot
# Scraping detail page: Land Measuring Approximately 1000 sqm Driveway Plot
# Scraping detail page: Waterfront Property Measuring Approximately 5000 sqm
# Scraping detail page: Land Measuring 3000 sqm
# Scraping detail page: 2 units of Newly Built 5 Bedroom Terrace with BQ
# Scraping detail page: 2 Bedroom Maisonette
# Scraping detail page: 3 Bedroom Apartment + BQ
#
#  Found next page: https://cwlagos.com/property-location/ikoyi/page/20/
# Scraping list page: https://cwlagos.com/property-location/ikoyi/page/20/
#
# Scraping detail page: 3 Bedroom Apartment + BQ
# Scraping detail page: 4 Bedroom Apartment + BQ
# Scraping detail page: 3 Bedroom Apartment + BQ
# Scraping detail page: 4 Bedroom Terraced Duplex + BQ
# Scraping detail page: 3 Bedroom Apartment
# Scraping detail page: Luxury, Well Maintained 2 Bedroom Upper Floor Apartment
# Scraping detail page: 5 Bedroom Detached House with 3 Room BQ
# Scraping detail page: Land Measuring 1920 sqm
# Scraping detail page: 4 Bedroom Apartment
# Scraping detail page: Luxury 5 Bedroom Fully Detached House with 2 Room BQ
# Scraping detail page: Furnished 2 Bedroom Waterfront Apartment
# Scraping detail page: 3- & 5-Bedroom Apartment Penthouse + BQ
# Scraping detail page: Newly Developed 4 Bedroom Maisonette with BQ
# Scraping detail page: 4 Bedroom with Home Office & 2 Room Boys Quarter on 600 sqm
# Scraping detail page: Newly Built 5 Bedroom Penthouse
#
#  Found next page: https://cwlagos.com/property-location/ikoyi/page/21/
# Scraping list page: https://cwlagos.com/property-location/ikoyi/page/21/
#
# Scraping detail page: Newly Built 4 Bedroom Maisonette with 1 Living Room
# Scraping detail page: Commercial or Residential 5 Bedroom Detached House with 3 Room BQ
# Scraping detail page: Front Facing 700 sqm Plot
# Scraping detail page: 4 Bedroom Fully Detached Duplex + 1 BQ
# Scraping detail page: Prime Waterfront/Waterview 500-3100sqm Land
# Scraping detail page: 75sqm, 41.5sqm, 41.5sqm & 55sqm Commercial Space
# Scraping detail page: 6 Bedroom Fully Detached Waterfront Duplex + BQ
# Scraping detail page: 1 Bedroom Apartment
# Scraping detail page: 2 Bedroom Terraced House
# Scraping detail page: Land Measuring 750 sqm
# Scraping detail page: 4,395.875sqm Cornerpiece Bareland
# Scraping detail page: 4,395 sqm Corner Piece Land
# Scraping detail page: Land Measuring 871 sqm
# Scraping detail page: Land Measuring 803 sqm
# Scraping detail page: 7 – Storey Multi-purpose Building in Prime Ikoyi Location
#
#  Found next page: https://cwlagos.com/property-location/ikoyi/page/22/
# Scraping list page: https://cwlagos.com/property-location/ikoyi/page/22/
#
# Scraping detail page: 4 Bedroom Detached Duplex with Smart Features
# Scraping detail page: 4 Bedroom Home with Expansive Balcony Space
# Scraping detail page: Land measuring 500sqm in a strategic location
# Scraping detail page: Luxury 4 Bedroom Apartment with Incredible Views
# Scraping detail page: Luxury 4 Bedroom Penthouse with Pool
# Scraping detail page: Luxury 2 Bedroom Apartment with Water View
# Scraping detail page: Luxury 5 Bedroom Terrace with Swimming Pool
# Scraping detail page: 3 Bedroom Partly Furnished Apartment with BQ
# Scraping detail page: Brand New 3 Bedroom Apartment plus BQ
# Scraping detail page: Land Measuring 8000 sqm in a Strategic Location
# Scraping detail page: Brand New 5 Bedroom Fully Detached House in a Highly Prestigious Neighborhood
# Scraping detail page: 276.43 sqm Office Space
# Scraping detail page: Land Measuring 350 sqm
# Scraping detail page: Luxury 4 Bedroom Maisonette & 5 Bedroom Penthouse
# Scraping detail page: Land Measuring 350sqm
#
#  Found next page: https://cwlagos.com/property-location/ikoyi/page/23/
# Scraping list page: https://cwlagos.com/property-location/ikoyi/page/23/
#
# Scraping detail page: 3 Plots Measuring 1000sqm Suitable for a Private Residence
# Scraping detail page: Spacious 5 Bedroom Duplex Commercial Property
# Scraping detail page: Ultra Luxury 3 Bedroom Apartment with 2 Room Boys Quarter
# Scraping detail page: Commercial Duplex sitting on 402sqm with 2 Bedroom Charlet at the Back
# Scraping detail page: Massively Standard & New 1,2&3 Bedroom Apartments
# Scraping detail page: Luxurious Newly Built 4 Bedroom Flat with Boys Quarters
# Scraping detail page: Elegant 2 units of Luxury 3 Bedroom Apartment with Stable Electricity
# Scraping detail page: Brand New 4 Bedroom Terraced Duplex + 2 BQ
# Scraping detail page: Luxury Newly Built 3 Bedroom Apartment plus BQ
# Scraping detail page: Luxury 4 Bedroom Townhouse with Swimming Pool
# Scraping detail page: Magnificent 3 Bedroom Apartment with Swimming Pool
# Scraping detail page: Luxurious 3-, 4- & 5-Bedroom Penthouse Maisonette
# Scraping detail page: Brand New 4 Bedroom Terrace with Ample Parking Space
# Scraping detail page: Fully Serviced 6 Bedroom Fully Detached Homes with BQ
# Scraping detail page: Luxury 2, 4 & 5 Bed Pent-Apartment Maisonette with Swimming Pool
#
#  Found next page: https://cwlagos.com/property-location/ikoyi/page/24/
# Scraping list page: https://cwlagos.com/property-location/ikoyi/page/24/
#
# Scraping detail page: Perfectly Carved 4 Bedroom Semi-Detached Duplex with BQ
# Scraping detail page: 90sqm Office Space with Large Co-working Space
# Scraping detail page: 50sqm Office Space with Large Co-working Spaces
# Scraping detail page: 24 Hours Serviced Commercial Office Complex with Elevators
# Scraping detail page: Luxurious + New 4 Bedroom Maisonette with City Views
# Scraping detail page: Luxury 2- & 4-Bedroom Apartments & Maisonettes with Pool
# Scraping detail page: Modern Luxury 4 Bedroom Semi-Detached Duplex + BQ
# Scraping detail page: Serviced 3 Bedroom Apartment + BQ
# Scraping detail page: Luxury 3 Bedroom Apartment + Maid’s Quarters
# Scraping detail page: Luxury 2- & 3-Bedroom Apartments & 3 Bedroom Maisonette
# Scraping detail page: Luxury 4 Bedroom Apartment with 1 BQ
# Scraping detail page: Luxury 3 Bedroom Apartment in a Highly Prestigious Neighborhood
# Scraping detail page: Luxury 4 Bedroom Maisonette with Swimming Pool
# Scraping detail page: Luxury 4 Bedroom Maisonette with a Pool
# Scraping detail page: Luxurious 4 Bedroom Flat with 1 room BQ
#
#  Found next page: https://cwlagos.com/property-location/ikoyi/page/25/
# Scraping list page: https://cwlagos.com/property-location/ikoyi/page/25/
#
# Scraping detail page: Luxury 4 Bedroom Apartment plus BQ
# Scraping detail page: Brand New 5 Bedroom Semi-Detached House with Swimming Pool
# Scraping detail page: Luxury 4 Bedroom Detached Duplex in a Gated Neighborhood
# Scraping detail page: Luxury 5 Bedroom Semi-Detached House with Ample Parking Space
# Scraping detail page: Brand New 5 Bedroom Semi-Detached House with Water View
# Scraping detail page: A Luxuriously Built Fully Detached Waterfront 6 Bedroom Mansion with Waterfall
# Scraping detail page: Luxury 4 Bedroom Apartment + BQ
# Scraping detail page: 4 Bedroom Luxurious and Super Spacious Apartment
# Scraping detail page: Upscale 4 Bedroom Terraced Duplex in a Gated Neighborhood
# Scraping detail page: Luxury 3 Bedroom Apartment with Scenic View Large Terrace
#
#  No more 'next page' links found. Scrape complete.
# Scraping finished. Total properties found: 0

# %%
ikoyi_listings = pd.DataFrame(rows)
ikoyi_listings.to_csv('../data/raw/ikoyi_properties_full.csv', index=False)
